# %% [markdown]
# ### train / validation / test - threshold 기준이 정해져야 tech feature와 GARCH feature 병합가능함 아직 미완

# %%
#기본 파이썬 라이브러리
import pandas as pd
import numpy as np
# Out:
# c:\Users\dddhs\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\dddhs\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (

# %%
data_tech=pd.read_csv(r'C:..\..\data\processed\data_tech_features.csv')

data_GARCH=pd.read_csv(r'C:..\..\data\processed\data_GARCH_GJR-GARCH_VaR_Risk_Label.csv')

# %%
#data_tech와 data_GARCH의 병합해주고 최종 데이터셋을 만들어보자, 그러고 nan값이나 문제가 있는지 확인 하자
merge_final_data = pd.merge(data_tech, data_GARCH, on='Date', how='inner')
merge_final_data.head()
# Out:
#          Date  Shanghai Comp  KODEX 200  TOPIX  Brent Crude Oil   Gold Spot  \
# 0  2009-04-17    2503.935059    17370.0  875.0        51.959999  867.400024
# 1  2009-04-20    2557.456055    17480.0  876.0        51.959999  887.000000
# 2  2009-04-21    2535.827881    17480.0  855.0        51.959999  882.099976
# 3  2009-04-22    2461.345947    17715.0  856.0        51.959999  891.799988
# 4  2009-04-23    2463.954102    17895.0  862.0        51.959999  905.900024
#
#    KRW/JPY      KRW/USD       NASDAQ      KOSDAQ  ...  KOSPI 200_BB_MID20  \
# 0   13.371  1325.800049  1673.069946  483.799988  ...          166.383999
# 1   13.536  1327.500000  1608.209961  491.940002  ...          167.093332
# 2   13.727  1354.300049  1643.849976  497.190002  ...          168.141999
# 3   13.726  1346.599976  1646.119995  509.899994  ...          169.301333
# 4   13.618  1333.599976  1652.209961  514.090027  ...          170.346665
#
# ...

# %%
#데이터 변수 다 보기
print(merge_final_data.columns)
# Out:
# Index(['Date', 'Shanghai Comp', 'KODEX 200', 'TOPIX', 'Brent Crude Oil',
#        'Gold Spot', 'KRW/JPY', 'KRW/USD', 'NASDAQ', 'KOSDAQ',
#        'KOSPI 200 Close', 'KOSPI 200 Open', 'KOSPI 200 High', 'KOSPI 200 Low',
#        'KRW/CNY', 'KOSPI 200_MA5', 'KOSPI 200_MA15', 'KOSPI 200_EMA5',
#        'KOSPI 200_EMA15', 'KOSPI 200_RSI14', 'KOSPI 200_BB_MID20',
#        'KOSPI 200_BB_UPPER20', 'KOSPI 200_BB_LOWER20', 'Actual_Return(%)',
#        'GARCH_Mu', 'GARCH_Vol', 'GJR_GARCH_Vol', 'VaR_95', 'GJR_VaR_95',
#        'Risk_Label'],
#       dtype='str')

# %%
merge_final_data.to_csv(r'C:..\..\data\processed\data_middle.csv', index=False)
