# %% [markdown]
# ### train / validation / test - threshold 기준이 정해져야 tech feature와 GARCH feature 병합가능함 아직 미완

# %%
#기본 파이썬 라이브러리
import pandas as pd
import numpy as np
# Out:
# c:\Users\dddhs\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\dddhs\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (

# %%
data_tech=pd.read_csv(r'C:..\..\data\processed\data_tech_features.csv')

data_GARCH=pd.read_csv(r'C:..\..\data\processed\data_GARCH_GJR-GARCH_VaR_Risk_Label.csv')

# %%
#data_tech와 data_GARCH의 병합해주고 최종 데이터셋을 만들어보자, 그러고 nan값이나 문제가 있는지 확인 하자
merge_final_data = pd.merge(data_tech, data_GARCH, on='Date', how='inner')
merge_final_data.head()
merge_final_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4109 entries, 0 to 4108
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  4109 non-null   str
#  1   Shanghai Comp         4109 non-null   float64
#  2   KODEX 200             4109 non-null   float64
#  3   TOPIX                 4109 non-null   float64
#  4   Brent Crude Oil       4109 non-null   float64
#  5   Gold Spot             4109 non-null   float64
#  6   KRW/JPY               4109 non-null   float64
#  7   KRW/USD               4109 non-null   float64
#  8   NASDAQ                4109 non-null   float64
#  9   KOSDAQ                4109 non-null   float64
#  10  KOSPI 200 Close       4109 non-null   float64
#  11  KOSPI 200 Open        4109 non-null   float64
#  12  KOSPI 200 High        4109 non-null   float64
#  13  KOSPI 200 Low         4109 non-null   float64
#  14  KRW/CNY               4109 non-null   float64
#  15  KOSPI 200_MA5         4109 non-null   float64
#  16  KOSPI 200_MA15        4109 non-null   float64
#  17  KOSPI 200_EMA5        4109 non-null   float64
#  18  KOSPI 200_EMA15       4109 non-null   float64
#  19  KOSPI 200_RSI14       4109 non-null   float64
#  20  KOSPI 200_BB_MID20    4109 non-null   float64
#  21  KOSPI 200_BB_UPPER20  4109 non-null   float64
#  22  KOSPI 200_BB_LOWER20  4109 non-null   float64
#  23  Actual_Return(%)      4109 non-null   float64
#  24  GARCH_Mu              4109 non-null   float64
#  25  GARCH_Vol             4109 non-null   float64
#  26  GJR_GARCH_Vol         4109 non-null   float64
#  27  VaR_95                4109 non-null   float64
#  28  GJR_VaR_95            4109 non-null   float64
#  29  Risk_Label            4109 non-null   str
# dtypes: float64(28), str(2)
# memory usage: 1.0 MB

# %%
merge_final_data.to_csv(r'C:..\..\data\processed\data_middle.csv', index=False)
