# %%
#기본 파이썬 라이브러리
import pandas as pd
import numpy as np
# Out:
# c:\Users\dddhs\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\dddhs\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (

# %%
data_tech=pd.read_csv(r'C:\Users\dddhs\TS_RL_proj\data\processed\data_tech_features.csv')

data_GARCH=pd.read_csv(r'C:\Users\dddhs\TS_RL_proj\data\processed\GARCH_GJR-GARCH_VaR_0.05_Risk_label.csv')

# %%
data_tech.head(20)
# Out:
#           Date  Shanghai Comp     KODEX 200       TOPIX  Brent Crude Oil  \
# 0   2009-04-17    2503.935059  12910.509766  679.428528        51.959999
# 1   2009-04-20    2557.456055  12992.271484  680.204834        51.959999
# 2   2009-04-21    2535.827881  12992.271484  663.898682        51.959999
# 3   2009-04-22    2461.345947  13166.940430  664.675171        51.959999
# 4   2009-04-23    2463.954102  13300.724609  669.333923        51.959999
# 5   2009-04-24    2448.594971  13148.357422  666.228149        51.959999
# 6   2009-04-27    2405.347900  13003.415039  663.898682        51.959999
# 7   2009-04-28    2401.437988  12654.084961  651.474792        51.959999
# 8   2009-04-29    2468.191895  13030.134766  651.474792        51.959999
# 9   2009-04-30    2477.569092  13312.172852  672.440002        51.959999
# 10  2009-05-04    2559.910889  13552.844727  672.440002        54.580002
# 11  2009-05-06    2592.520020  13526.518555  672.440002        56.150002
# ...

# %%
data_GARCH.head(20)
# Out:
#           Date  Actual_Return (%)  GARCH_Vol  GJR_GARCH_Vol    VaR_95  \
# 0   2009-04-20           0.564563   1.474962       1.469190 -2.749950
# 1   2009-04-21          -0.197523   1.423665       1.416096 -2.649217
# 2   2009-04-22           1.408955   1.369916       1.357370 -2.537800
# 3   2009-04-23           0.992765   1.366743       1.300283 -2.429493
# 4   2009-04-24          -1.147696   1.338269       1.294011 -2.417593
# 5   2009-04-27          -1.155214   1.327041       1.304459 -2.437416
# 6   2009-04-28          -2.882009   1.317202       1.315516 -2.458393
# 7   2009-04-29           2.852956   1.492876       1.647842 -3.088895
# 8   2009-04-30           2.252450   1.619686       1.493315 -2.795720
# 9   2009-05-04           2.074916   1.663332       1.651886 -3.096568
# 10  2009-05-06          -0.485340   1.686212       1.523064 -2.852162
# 11  2009-05-07           0.513164   1.624381       1.596359 -2.991220
# ...
