# %%
# 랜덤성 제어를 위한 표준 라이브러리 모듈을 불러옵니다.
import random
from collections import deque
from pathlib import Path
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import MinMaxScaler


# 데이터셋을 불러옵니다.
dat = pd.read_csv(Path("../../data/processed/data_selected.csv"), index_col=0)

# 재현 가능한 실험을 위해 시드 값을 고정합니다.
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# GPU가 있으면 CUDA를, 없으면 CPU를 사용하도록 장치를 설정합니다.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# DDQN에서 사용할 Q-Network 구조를 정의합니다.
# 데이터 수가 많지 않으므로 과적합 가능성을 염두에 두고 2개 은닉층을 사용합니다.
class QNetwork(nn.Module):
    def __init__(self, state_dim: int, action_dim: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 96),
            nn.ReLU(),
            nn.Linear(96, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim),
        )

    def forward(self, x):
        return self.net(x)                         # (batch, 2)

# 경험을 저장하고 무작위 샘플링하기 위한 리플레이 버퍼를 정의합니다.
class ReplayBuffer:
    def __init__(self, capacity: int):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size: int):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = map(np.array, zip(*batch))
        return (
            torch.FloatTensor(states).to(device),
            torch.LongTensor(actions).unsqueeze(1).to(device),
            torch.FloatTensor(rewards).unsqueeze(1).to(device),
            torch.FloatTensor(next_states).to(device),
            torch.FloatTensor(dones.astype(np.float32)).unsqueeze(1).to(device),
        )

    def __len__(self):
        return len(self.buffer)


# DDQN 에이전트를 정의합니다.
class DDQNAgent:
    def __init__(
        self,
        state_dim,
        action_dim,
        gamma=0.95,
        lr=5e-4,
        batch_size=64,
        memory_size=100_000,
        target_update=2000,
        epsilon_start=1.0,
        epsilon_end=0.05,
        epsilon_decay=0.995,
    ):
        self.action_dim = action_dim
        self.gamma = gamma
        self.batch_size = batch_size
        self.target_update = target_update

        self.epsilon = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay

        self.online_net = QNetwork(state_dim, action_dim).to(device)
        self.target_net = QNetwork(state_dim, action_dim).to(device)
        self.target_net.load_state_dict(self.online_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.online_net.parameters(), lr=lr)
        self.memory = ReplayBuffer(memory_size)
        self.total_steps = 0

    def act(self, state, epsilon: float = None):
        if epsilon is None:
            epsilon = self.epsilon

        if random.random() < epsilon:
            return random.randrange(self.action_dim)

        state_t = torch.FloatTensor(state).unsqueeze(0).to(device)
        with torch.no_grad():
            q_values = self.online_net(state_t)
        return int(torch.argmax(q_values, dim=1).item())

    def decay_epsilon(self):
        self.epsilon = max(self.epsilon_end, self.epsilon * self.epsilon_decay)

    def update(self):
        if len(self.memory) < self.batch_size:
            return None

        states, actions, rewards, next_states, dones = self.memory.sample(self.batch_size)
        
        #online_net에서 현재 Q값 계산
        q_values = self.online_net(states).gather(1, actions)
        #online_net에서 다음 행동 선택 
        next_actions = self.online_net(next_states).argmax(dim=1, keepdim=True)
        #target_net에서 다음 행동의 Q값 계산
        next_q_values = self.target_net(next_states).gather(1, next_actions)
        target_q = rewards + (1 - dones) * self.gamma * next_q_values
        loss = F.mse_loss(q_values, target_q.detach())
        
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.online_net.parameters(), max_norm=10.0)
        self.optimizer.step()
        self.total_steps += 1
        if self.total_steps % self.target_update == 0:
            self.target_net.load_state_dict(self.online_net.state_dict())
        return float(loss.item())

def encode_risk_labels(series):
    s = series.copy()
    # 문자열 타입이면 'High Risk' → 1, 'Low Risk' → 0 매핑
    if pd.api.types.is_object_dtype(s) or pd.api.types.is_string_dtype(s):
        s = s.map({'Low Risk': 0, 'High Risk': 1})
        if s.isna().any():
            raise ValueError(f"알 수 없는 라벨 값이 있습니다: {series[s.isna()].unique()}")
    # 숫자형이면 그냥 int 변환
    return s.fillna(0).astype(int).to_numpy()

# ---- 데이터 준비 (Train/Valid/Test Split 먼저, 그 후 Scaling) ----

risk_label_col = "Risk_Label"
feature_cols = [c for c in dat.select_dtypes(include=[np.number]).columns if c != risk_label_col]
if len(feature_cols) == 0:
    raise ValueError("학습에 사용할 수치형 feature가 없습니다.")

risk_label_data = encode_risk_labels(dat[risk_label_col])
feature_data_raw = dat[feature_cols].fillna(0.0).to_numpy()
n_steps = len(dat)

train_end = int(n_steps * 0.45)
valid_end = int(n_steps * 0.80)

train_indices = np.arange(0, train_end)
valid_indices = np.arange(train_end, valid_end)
test_indices  = np.arange(valid_end, n_steps)

train_feature_raw = feature_data_raw[train_indices]
train_label = risk_label_data[train_indices]

valid_feature_raw = feature_data_raw[valid_indices]
valid_label = risk_label_data[valid_indices]
if len(valid_label) < 2:
    raise ValueError("Validation set 길이가 너무 짧아 tuning/selection 분할이 불가능합니다. split 비율을 조정하세요.")
valid_split_point = int(len(valid_label) * 0.65)
valid_tune_feature_raw = valid_feature_raw[:valid_split_point]
valid_tune_label = valid_label[:valid_split_point]
valid_select_feature_raw = valid_feature_raw[valid_split_point:]
valid_select_label = valid_label[valid_split_point:]

test_feature_raw = feature_data_raw[test_indices]
test_label = risk_label_data[test_indices]

def summarize_class_ratio(name, y):
    n_total = len(y)
    n0 = int((y == 0).sum())
    n1 = int((y == 1).sum())
    r0 = n0 / n_total if n_total > 0 else 0.0
    r1 = n1 / n_total if n_total > 0 else 0.0
    imbalance = (n1 / max(n0, 1)) if n_total > 0 else 0.0
    print(f"{name:>5} | n={n_total:4d} | class0={n0:4d} ({r0:.2%}) | class1={n1:4d} ({r1:.2%}) | c1/c0={imbalance:.4f})")
    if n0 == 0 or n1 == 0:
        raise ValueError(f"{name} set에 클래스 0 또는 1이 없습니다. split 비율 또는 기간을 조정하세요.")

print("Class Ratio Summary (Before ADASYN)")
summarize_class_ratio("Train", train_label)
summarize_class_ratio("ValTun", valid_tune_label)
summarize_class_ratio("ValSel", valid_select_label)
summarize_class_ratio("Test", test_label)

# 보상 계산에 사용할 class_ratio는 원본 train 기준으로 고정합니다.
n_negative_original = (train_label == 0).sum()
n_positive_original = (train_label == 1).sum()
class_ratio_reward = n_positive_original / max(n_negative_original, 1)
print(f"Reward class ratio (original train): {class_ratio_reward:.4f}")

# ---- ADASYN을 적용하지 않고 원본 학습 데이터를 그대로 사용 ----
train_feature = train_feature_raw.astype(np.float32)
train_label = train_label.astype(np.int64)

scaler = MinMaxScaler()
scaler.fit(train_feature)

train_feature = scaler.transform(train_feature).astype(np.float32)
valid_tune_feature = scaler.transform(valid_tune_feature_raw).astype(np.float32)
valid_select_feature = scaler.transform(valid_select_feature_raw).astype(np.float32)
test_feature = scaler.transform(test_feature_raw).astype(np.float32)

print("=" * 60)
print("Data Split Information")
print("=" * 60)
print(f"Total samples: {n_steps}")
print(f"Train set: {len(train_label)} samples")
print(f"  - Class 0: {(train_label==0).sum()}, Class 1: {(train_label==1).sum()}")
print(f"Valid(Tune) set: {len(valid_tune_label)} samples")
print(f"  - Class 0: {(valid_tune_label==0).sum()}, Class 1: {(valid_tune_label==1).sum()}")
print(f"Valid(Select) set: {len(valid_select_label)} samples")
print(f"  - Class 0: {(valid_select_label==0).sum()}, Class 1: {(valid_select_label==1).sum()}")
test_ratio = len(test_label) / n_steps
print(f"Test set: {len(test_label)} samples ({test_ratio*100:.1f}%)")
print(f"  - Class 0: {(test_label==0).sum()}, Class 1: {(test_label==1).sum()}")

# 원본 학습 세트의 클래스 비율을 그대로 사용합니다.
n_negative = (train_label == 0).sum()
n_positive = (train_label == 1).sum()
class_ratio = class_ratio_reward

print(f"\nClass ratio (train set): {n_positive / max(n_negative, 1):.4f}")
print(f"Class ratio used for reward: {class_ratio:.4f}")
print("=" * 60)

state_dim = len(feature_cols)
action_dim = 2

def compute_reward(action, actual_label, class_ratio):
    action = int(action)
    actual_label = int(actual_label)
    if actual_label == 0:
        if action == 0:
            return class_ratio
        else:
            return -0.45            # FP
    else:
        if action == 1:
            return 1.30             # TP
        else:
            return -1.20            # FN
        
# train_label에서 High Risk 인덱스를 미리 계산
high_risk_indices = np.where(train_label == 1)[0]
print(f"High Risk 인덱스 수 (train): {len(high_risk_indices)}")

def get_balanced_start_idx(max_steps, high_risk_prob=0.5):
    """
    high_risk_prob 확률로 High Risk가 윈도우 안에
    반드시 포함되는 start_idx를 반환.
    
    나머지 확률로는 기존 랜덤 방식 사용.
    시계열 순서는 항상 유지됨.
    
    Parameters:
        max_steps: 에피소드 길이 (500)
        high_risk_prob: High Risk 포함 윈도우 선택 확률
    
    Returns:
        start_idx: 에피소드 시작 인덱스
    """
    n = len(train_feature)
    max_start = n - max_steps - 1
    
    if np.random.random() < high_risk_prob:
        # High Risk 인덱스 중 하나를 무작위 선택
        hr_idx = np.random.choice(high_risk_indices)
        
        # 이 hr_idx가 윈도우 안에 포함되는
        # start_idx의 유효 범위 계산:
        # 조건: start_idx <= hr_idx <= start_idx + max_steps - 1
        # → low = hr_idx - max_steps + 1
        # → high = hr_idx
        low  = max(0, hr_idx - max_steps + 1)
        high = min(max_start, hr_idx)
        
        if low > high:
            # 유효 범위가 없으면 (데이터 끝부분 등) 랜덤
            return np.random.randint(0, max_start + 1)
        
        # 유효 범위 안에서 랜덤 선택
        # → High Risk가 윈도우 앞/중간/뒤 어디든 포함됨
        return int(np.random.randint(low, high + 1))
    
    else:
        # 기존 방식: 완전 랜덤
        return int(np.random.randint(0, max_start + 1))
# Out:
# Class Ratio Summary (Before ADASYN)
# Train | n=1848 | class0=1638 (88.64%) | class1= 210 (11.36%) | c1/c0=0.1282)
# ValTun | n= 934 | class0= 829 (88.76%) | class1= 105 (11.24%) | c1/c0=0.1267)
# ValSel | n= 504 | class0= 427 (84.72%) | class1=  77 (15.28%) | c1/c0=0.1803)
#  Test | n= 822 | class0= 723 (87.96%) | class1=  99 (12.04%) | c1/c0=0.1369)
# Reward class ratio (original train): 0.1282
# ============================================================
# Data Split Information
# ============================================================
# Total samples: 4108
# Train set: 1848 samples
#   - Class 0: 1638, Class 1: 210
# Valid(Tune) set: 934 samples
#   - Class 0: 829, Class 1: 105
# Valid(Select) set: 504 samples
#   - Class 0: 427, Class 1: 77
# Test set: 822 samples (20.0%)
#   - Class 0: 723, Class 1: 99
#
# Class ratio (train set): 0.1282
# Class ratio used for reward: 0.1282
# ============================================================
# High Risk 인덱스 수 (train): 210

# %%
# ---- Validation 기반 하이퍼파라미터 Grid Search ----
from itertools import product

param_grid = {
    'gamma': [0.5,0.9],
    'lr': [1e-4,5e-4,1e-3],
    'epsilon_decay': [0.99, 0.995],
    'batch_size': [32, 64],
}

# 성능 지표 함수: G-Mean 기준으로 튜닝

def compute_metrics(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0
    precision = tp /(tp+fp) if (tp + fp) > 0 else 0.0

    gmean = float(np.sqrt(sensitivity * specificity))
    f1 =float(2 * (precision * sensitivity) / (precision + sensitivity)) if (precision + sensitivity) > 0 else 0.0

    return gmean, f1, sensitivity, specificity, precision

def predict_labels_argmax(model, features):
    preds = []
    with torch.no_grad():
        for t in range(len(features)):
            state_t = torch.FloatTensor(features[t]).unsqueeze(0).to(device)
            q_values = model(state_t)
            preds.append(int(torch.argmax(q_values, dim=1).item()))
    return np.array(preds)

def evaluate_argmax(model, x_valid, y_valid):
    preds = predict_labels_argmax(model, x_valid)
    gmean, f1, sensitivity, specificity, precision = compute_metrics(y_valid, preds)
    return gmean, f1, sensitivity, specificity, precision


def get_q_margin(model, features, batch_size=2048):
    """
    Q-margin = Q(High Risk) - Q(Low Risk)
    값이 클수록 High Risk(class 1)로 판단할 근거가 큽니다.
    """
    model.eval()
    margins = []

    with torch.no_grad():
        for start in range(0, len(features), batch_size):
            x_batch = torch.FloatTensor(features[start:start + batch_size]).to(device)
            q_values = model(x_batch).cpu().numpy()
            q_margin = q_values[:, 1] - q_values[:, 0]
            margins.append(q_margin)

    return np.concatenate(margins)


def predict_by_q_threshold(model, features, threshold):
    margins = get_q_margin(model, features)
    return (margins >= threshold).astype(int)


def select_threshold_by_gmean99_sens(model, x_valid, y_valid, keep_ratio=0.99):
    """
    valid_select 기준 Q-margin threshold 선택:
    1) valid G-mean 최대값 계산
    2) G-mean >= max_gmean * keep_ratio 후보만 유지
    3) 그 후보 중 sensitivity 최대인 threshold 선택
    """
    margins = get_q_margin(model, x_valid)

    # 실제 예측이 바뀌는 지점과 기존 argmax 기준(threshold=0)을 후보로 사용합니다.
    threshold_grid = np.unique(np.r_[margins, 0.0])
    records = []

    for th in threshold_grid:
        pred = (margins >= th).astype(int)
        tn, fp, fn, tp = confusion_matrix(y_valid, pred, labels=[0, 1]).ravel()

        sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
        f1 = (
            2 * precision * sensitivity / (precision + sensitivity)
            if (precision + sensitivity) > 0 else 0.0
        )
        gmean = float(np.sqrt(sensitivity * specificity))

        records.append({
            "threshold": float(th),
            "tn": int(tn),
            "fp": int(fp),
            "fn": int(fn),
            "tp": int(tp),
            "sensitivity": float(sensitivity),
            "specificity": float(specificity),
            "precision": float(precision),
            "f1": float(f1),
            "gmean": float(gmean),
        })

    threshold_search_df = pd.DataFrame(records)

    max_gmean = threshold_search_df["gmean"].max()
    gmean_floor = max_gmean * keep_ratio

    threshold_candidate_df = threshold_search_df[
        threshold_search_df["gmean"] >= gmean_floor
    ].copy()

    # G-mean 99% 이상 유지 후보 중 sensitivity를 최우선으로 선택
    threshold_candidate_df = threshold_candidate_df.sort_values(
        by=["sensitivity", "tp", "f1", "precision", "fp"],
        ascending=[False, False, False, False, True]
    ).reset_index(drop=True)

    best = threshold_candidate_df.iloc[0].to_dict()
    best["max_gmean"] = float(max_gmean)
    best["gmean_floor"] = float(gmean_floor)
    best["keep_ratio"] = float(keep_ratio)

    return best, threshold_search_df, threshold_candidate_df


#그리드 서치 학습 =============================================
grid_search_results = []
param_combinations = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

print("\n" + "=" * 80)
print(f"HYPERPARAMETER GRID SEARCH (Total: {len(param_combinations)} combinations)")
print("=" * 80)

patience = 25
min_episodes = 60
best_overall_select_gmean = -1.0
best_overall_params = None

for idx, params in enumerate(param_combinations):
    param_dict = dict(zip(param_names, params))
    gamma, lr, epsilon_decay, batch_size = params
    # 각 조합마다 동일한 초기 조건으로 시작
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    print(f"\n[{idx+1}/{len(param_combinations)}] gamma={gamma:.2f}, lr={lr:.0e}, eps_decay={epsilon_decay:.3f}, bs={batch_size}")

    agent_tune = DDQNAgent(
        state_dim=state_dim,
        action_dim=action_dim,
        gamma=gamma,
        lr=lr,
        batch_size=batch_size,
        memory_size=50_000,
        target_update=2000,
        epsilon_start=1.0,
        epsilon_end=0.05,
        epsilon_decay=epsilon_decay,
    )

    episodes_tune = 200
    max_steps_tune = 500
    best_tune_gmean = -1.0
    best_tune_state_dict = None
    patience_counter = 0

    for ep in range(1, episodes_tune + 1):
        start_idx = get_balanced_start_idx(max_steps_tune, high_risk_prob=0.5)
        episode_reward = 0.0

        for i in range(max_steps_tune):
            state = train_feature[start_idx + i]
            next_state = train_feature[start_idx + i + 1] if start_idx + i + 1 < len(train_feature) else train_feature[start_idx + i]
            actual_label = train_label[start_idx + i]

            action = agent_tune.act(state)
            reward = compute_reward(action, actual_label, class_ratio)
            done = i == (max_steps_tune - 1)

            agent_tune.memory.push(state, action, reward, next_state, done)
            _ = agent_tune.update()
            episode_reward += reward

        agent_tune.decay_epsilon()

    # 5 에피소드마다 tune 데이터로 검증을 수행하여 G-mean이 개선되는지 확인=================================
        if ep % 5 == 0:
            agent_tune.online_net.eval()
            tune_gmean, tune_f1, tune_sensitivity, tune_specificity, tune_precision = evaluate_argmax(
                agent_tune.online_net, valid_tune_feature, valid_tune_label
            )
            agent_tune.online_net.train()

            if tune_gmean > best_tune_gmean:
                best_tune_gmean = tune_gmean
                patience_counter = 0
                best_tune_state_dict = {k: v.detach().cpu().clone() for k, v in agent_tune.online_net.state_dict().items()}
            else:
                patience_counter += 1

            if ep % 20 == 0:
                print(f"  Ep {ep:3d} | Tune G-mean: {tune_gmean:.4f} F1: {tune_f1:.4f} (Sens: {tune_sensitivity:.4f}, Spec: {tune_specificity:.4f}, Pre: {tune_precision:.4f}) | Best G-mean: {best_tune_gmean:.4f}")

            if ep > min_episodes and patience_counter >= patience:
                break
# Tune에서 가장 좋은 모델로 Selection 데이터에 대한 최종 평가를 수행합니다====================

    agent_tune.online_net.eval()
    if best_tune_state_dict is not None:
        agent_tune.online_net.load_state_dict(best_tune_state_dict)
    select_gmean, select_f1, select_sensitivity, select_specificity, select_precision = evaluate_argmax(
        agent_tune.online_net, valid_select_feature, valid_select_label
    )

    grid_search_results.append({
        'params': param_dict,
        'best_tune_gmean': best_tune_gmean,
        'select_gmean': select_gmean,
        'select_f1': select_f1,
        'select_sensitivity': select_sensitivity,
        'select_specificity': select_specificity,
        'select_precision': select_precision
    })

    if select_gmean > best_overall_select_gmean:
        best_overall_select_gmean = select_gmean
        best_overall_params = param_dict

grid_search_results.sort(key=lambda x: x['select_gmean'], reverse=True)

print("\n" + "=" * 80)
print("TOP 5 HYPERPARAMETERS")
print("=" * 80)
for i, result in enumerate(grid_search_results[:5]):
    print(f"{i+1}. "
          f"G-mean: {result['select_gmean']:.4f} | "
          f"F1: {result['select_f1']:.4f} | "
          f"Prec: {result['select_precision']:.4f} | "
          f"Params: {result['params']}")

print("\n" + "=" * 80)
print("BEST HYPERPARAMETERS")
print("=" * 80)
for k, v in best_overall_params.items():
    print(f"{k}: {v}")
print(f"Best Selection G-mean: {best_overall_select_gmean:.4f}")
print("=" * 80)

# ---- 최적 파라미터로 본 학습 ----
print("\nTraining with best hyperparameters...")
agent = DDQNAgent(
    state_dim=state_dim,
    action_dim=action_dim,
    gamma=best_overall_params['gamma'],
    lr=best_overall_params['lr'],
    batch_size=best_overall_params['batch_size'],
    memory_size=50_000,
    target_update=2000,
    epsilon_start=1.0,
    epsilon_end=0.05,
    epsilon_decay=best_overall_params['epsilon_decay'],
)

episodes = 800
max_steps = 500
scores = []
valid_scores = []
best_ckpt_valid_gmean = -1.0
best_ckpt_epoch = 0
best_ckpt_state_dict = None

for ep in range(1, episodes + 1):
    episode_reward = 0.0
    start_idx = get_balanced_start_idx(max_steps, high_risk_prob=0.5)

    for i in range(max_steps):
        state = train_feature[start_idx + i]
        next_state = train_feature[start_idx + i + 1] if start_idx + i + 1 < len(train_feature) else train_feature[start_idx + i]
        actual_label = train_label[start_idx + i]

        action = agent.act(state)
        reward = compute_reward(action, actual_label, class_ratio)
        done = i == (max_steps - 1)

        agent.memory.push(state, action, reward, next_state, done)
        _ = agent.update()
        episode_reward += reward

    agent.decay_epsilon()
    scores.append(episode_reward)

    if ep % 10 == 0:
        agent.online_net.eval()
        valid_gmean, valid_f1, valid_sensitivity, valid_specificity, valid_precision = evaluate_argmax(
            agent.online_net, valid_select_feature, valid_select_label
        )
        valid_scores.append(valid_gmean)

        if valid_gmean > best_ckpt_valid_gmean:
            best_ckpt_valid_gmean = valid_gmean
            best_ckpt_epoch = ep
            best_ckpt_state_dict = {k: v.detach().cpu().clone() for k, v in agent.online_net.state_dict().items()}
        agent.online_net.train()

        print(f"Episode {ep:3d} | "f"Reward: {np.mean(scores[-10:]):8.5f} | "f"G-mean: {valid_gmean:.4f} | "f"F1: {valid_f1:.4f} | "f"Prec: {valid_precision:.4f} | "f"Best G-mean: {best_ckpt_valid_gmean:.4f}")

print("최종 학습 완료")
if best_ckpt_state_dict is not None:
    agent.online_net.load_state_dict(best_ckpt_state_dict)
    agent.target_net.load_state_dict(best_ckpt_state_dict)
    print(f"Best checkpoint restored: epoch={best_ckpt_epoch}, valid_gmean={best_ckpt_valid_gmean:.4f}")

agent.online_net.eval()

# ---- valid_select에서 Q-margin threshold 선택 ----
# 기준: G-mean 최대값의 99% 이상을 유지하는 threshold 중 sensitivity 최대
threshold_info, threshold_search_df, threshold_candidate_df = select_threshold_by_gmean99_sens(
    agent.online_net,
    valid_select_feature,
    valid_select_label,
    keep_ratio=0.99
)
Q_THRESHOLD = threshold_info["threshold"]

print("\n" + "=" * 60)
print("VALID Q-MARGIN THRESHOLD SELECTION")
print("=" * 60)
print(f"Max valid G-mean      = {threshold_info['max_gmean']:.4f}")
print(f"G-mean floor 99%      = {threshold_info['gmean_floor']:.4f}")
print(f"Selected threshold    = {Q_THRESHOLD:.6f}")
print(
    f"Selected valid CM: "
    f"TN={int(threshold_info['tn'])}, FP={int(threshold_info['fp'])}, "
    f"FN={int(threshold_info['fn'])}, TP={int(threshold_info['tp'])}"
)
print(
    f"Valid Sens={threshold_info['sensitivity']:.4f}, "
    f"Spec={threshold_info['specificity']:.4f}, "
    f"Prec={threshold_info['precision']:.4f}, "
    f"F1={threshold_info['f1']:.4f}, "
    f"G-mean={threshold_info['gmean']:.4f}"
)
print("=" * 60)

# ---- Test 평가 ----
test_predictions = predict_by_q_threshold(agent.online_net, test_feature, Q_THRESHOLD)

cm_test = confusion_matrix(test_label, test_predictions, labels=[0, 1])
tn, fp, fn, tp = cm_test.ravel()
sensitivity_test = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity_test = tn / (tn + fp) if (tn + fp) > 0 else 0
gmean_test = np.sqrt(sensitivity_test * specificity_test)

print("\n" + "=" * 60)
print("TEST SET - DDQN 분류 모델 최종 성능 평가")
print("=" * 60)
print(f"\nG-mean: {gmean_test:.4f}")
print(f"\nConfusion Matrix:")
print(cm_test)
print(f"\nTN: {cm_test[0, 0]}, FP: {cm_test[0, 1]}")
print(f"FN: {cm_test[1, 0]}, TP: {cm_test[1, 1]}")

print(f"\n분류 리포트:")
print(classification_report(test_label, test_predictions,
                          labels=[0, 1],
                          target_names=['Class 0 (Negative)', 'Class 1 (Positive)'],
                          zero_division=0))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax1 = axes[0]
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Blues', cbar=False, ax=ax1,
            xticklabels=['Pred 0', 'Pred 1'],
            yticklabels=['Actual 0', 'Actual 1'])
ax1.set_title('Test Set - Confusion Matrix (Count)', fontsize=12, fontweight='bold')
ax1.set_ylabel('True Label')
ax1.set_xlabel('Predicted Label')

cm_test_row_sums = cm_test.sum(axis=1, keepdims=True)
cm_test_percent = np.divide(cm_test.astype(float), cm_test_row_sums,
                             out=np.zeros_like(cm_test, dtype=float),
                             where=cm_test_row_sums != 0) * 100
ax2 = axes[1]
sns.heatmap(cm_test_percent, annot=True, fmt='.2f', cmap='Blues', cbar=True, ax=ax2,
            xticklabels=['Pred 0', 'Pred 1'],
            yticklabels=['Actual 0', 'Actual 1'],
            cbar_kws={'label': 'Percentage (%)'})
ax2.set_title('Test Set - Confusion Matrix (Percentage)', fontsize=12, fontweight='bold')
ax2.set_ylabel('True Label')
ax2.set_xlabel('Predicted Label')

plt.tight_layout()
plt.show()

precision = tp / (tp + fp) if (tp + fp) > 0 else 0
f1_score_val = 2 * (precision * sensitivity_test) / (precision + sensitivity_test) if (precision + sensitivity_test) > 0 else 0


print(f"\n상세 메트릭 (Test Set):")
print(f"Sensitivity (Recall for Class 1): {sensitivity_test:.4f}")
print(f"Specificity (Recall for Class 0): {specificity_test:.4f}")
print(f"Precision (Class 1):              {precision:.4f}")
print(f"F1-Score:                         {f1_score_val:.4f}")
print(f"G-mean:                           {gmean_test:.4f}")
print("=" * 60)

print("\n" + "=" * 60)
print("VALIDATION SET vs TEST SET 성능 비교")
print("=" * 60)

agent.online_net.eval()
valid_predictions = predict_by_q_threshold(agent.online_net, valid_select_feature, Q_THRESHOLD)
cm_valid = confusion_matrix(valid_select_label, valid_predictions, labels=[0, 1])
tn_v, fp_v, fn_v, tp_v = cm_valid.ravel()
sensitivity_valid = tp_v / (tp_v + fn_v) if (tp_v + fn_v) > 0 else 0
specificity_valid = tn_v / (tn_v + fp_v) if (tn_v + fp_v) > 0 else 0
gmean_valid = np.sqrt(sensitivity_valid * specificity_valid)

print(f"\nValidation(Selection) Set - G-mean: {gmean_valid:.4f}")
print(f"Test Set - G-mean: {gmean_test:.4f}")
print(f"Difference (Valid - Test): {gmean_valid - gmean_test:.4f}")
print("\nValidation Confusion Matrix:")
print(cm_valid)
print("\nTest Confusion Matrix:")
print(cm_test)
print("=" * 60)
# Out:
# ================================================================================
# HYPERPARAMETER GRID SEARCH (Total: 24 combinations)
# ================================================================================
#
# [1/24] gamma=0.50, lr=1e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6138 F1: 0.3446 (Sens: 0.4381, Spec: 0.8601, Pre: 0.2840) | Best G-mean: 0.6138
#   Ep  40 | Tune G-mean: 0.5318 F1: 0.2986 (Sens: 0.3143, Spec: 0.8999, Pre: 0.2845) | Best G-mean: 0.6138
#   Ep  60 | Tune G-mean: 0.5812 F1: 0.3347 (Sens: 0.3810, Spec: 0.8866, Pre: 0.2985) | Best G-mean: 0.6138
#   Ep  80 | Tune G-mean: 0.5543 F1: 0.3172 (Sens: 0.3429, Spec: 0.8963, Pre: 0.2951) | Best G-mean: 0.6138
#   Ep 100 | Tune G-mean: 0.5513 F1: 0.3064 (Sens: 0.3429, Spec: 0.8866, Pre: 0.2769) | Best G-mean: 0.6138
#   Ep 120 | Tune G-mean: 0.5848 F1: 0.3293 (Sens: 0.3905, Spec: 0.8758, Pre: 0.2847) | Best G-mean: 0.6138
#   Ep 140 | Tune G-mean: 0.6143 F1: 0.3459 (Sens: 0.4381, Spec: 0.8613, Pre: 0.2857) | Best G-mean: 0.6143
#   Ep 160 | Tune G-mean: 0.5758 F1: 0.3348 (Sens: 0.3714, Spec: 0.8926, Pre: 0.3047) | Best G-mean: 0.6143
#   Ep 180 | Tune G-mean: 0.6054 F1: 0.3478 (Sens: 0.4190, Spec: 0.8745, Pre: 0.2973) | Best G-mean: 0.6147
#   Ep 200 | Tune G-mean: 0.5473 F1: 0.3125 (Sens: 0.3333, Spec: 0.8987, Pre: 0.2941) | Best G-mean: 0.6147
#
# [2/24] gamma=0.50, lr=1e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5447 F1: 0.3030 (Sens: 0.3333, Spec: 0.8902, Pre: 0.2778) | Best G-mean: 0.5684
#   Ep  40 | Tune G-mean: 0.5586 F1: 0.3122 (Sens: 0.3524, Spec: 0.8854, Pre: 0.2803) | Best G-mean: 0.5727
#   Ep  60 | Tune G-mean: 0.5788 F1: 0.3265 (Sens: 0.3810, Spec: 0.8794, Pre: 0.2857) | Best G-mean: 0.5792
#   Ep  80 | Tune G-mean: 0.5551 F1: 0.3200 (Sens: 0.3429, Spec: 0.8987, Pre: 0.3000) | Best G-mean: 0.5792
#   Ep 100 | Tune G-mean: 0.5481 F1: 0.3153 (Sens: 0.3333, Spec: 0.9011, Pre: 0.2991) | Best G-mean: 0.5886
#   Ep 120 | Tune G-mean: 0.5695 F1: 0.3319 (Sens: 0.3619, Spec: 0.8963, Pre: 0.3065) | Best G-mean: 0.5906
#   Ep 140 | Tune G-mean: 0.5939 F1: 0.3429 (Sens: 0.4000, Spec: 0.8818, Pre: 0.3000) | Best G-mean: 0.5939
#   Ep 160 | Tune G-mean: 0.5420 F1: 0.3148 (Sens: 0.3238, Spec: 0.9071, Pre: 0.3063) | Best G-mean: 0.5939
#   Ep 180 | Tune G-mean: 0.5532 F1: 0.3130 (Sens: 0.3429, Spec: 0.8926, Pre: 0.2880) | Best G-mean: 0.5939
#   Ep 200 | Tune G-mean: 0.5636 F1: 0.2955 (Sens: 0.3714, Spec: 0.8552, Pre: 0.2453) | Best G-mean: 0.5939
#
# [3/24] gamma=0.50, lr=1e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.5776 F1: 0.3226 (Sens: 0.3810, Spec: 0.8758, Pre: 0.2797) | Best G-mean: 0.6076
#   Ep  40 | Tune G-mean: 0.5723 F1: 0.3223 (Sens: 0.3714, Spec: 0.8818, Pre: 0.2847) | Best G-mean: 0.6117
#   Ep  60 | Tune G-mean: 0.5402 F1: 0.3077 (Sens: 0.3238, Spec: 0.9011, Pre: 0.2931) | Best G-mean: 0.6117
#   Ep  80 | Tune G-mean: 0.5536 F1: 0.3144 (Sens: 0.3429, Spec: 0.8938, Pre: 0.2903) | Best G-mean: 0.6117
#   Ep 100 | Tune G-mean: 0.5528 F1: 0.3117 (Sens: 0.3429, Spec: 0.8914, Pre: 0.2857) | Best G-mean: 0.6117
#   Ep 120 | Tune G-mean: 0.5540 F1: 0.3158 (Sens: 0.3429, Spec: 0.8951, Pre: 0.2927) | Best G-mean: 0.6117
#   Ep 140 | Tune G-mean: 0.5731 F1: 0.3250 (Sens: 0.3714, Spec: 0.8842, Pre: 0.2889) | Best G-mean: 0.6117
#
# [4/24] gamma=0.50, lr=1e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.5574 F1: 0.3083 (Sens: 0.3524, Spec: 0.8818, Pre: 0.2741) | Best G-mean: 0.5578
#   Ep  40 | Tune G-mean: 0.5637 F1: 0.3115 (Sens: 0.3619, Spec: 0.8782, Pre: 0.2734) | Best G-mean: 0.5719
#   Ep  60 | Tune G-mean: 0.5431 F1: 0.3192 (Sens: 0.3238, Spec: 0.9107, Pre: 0.3148) | Best G-mean: 0.5719
#   Ep  80 | Tune G-mean: 0.5864 F1: 0.3347 (Sens: 0.3905, Spec: 0.8806, Pre: 0.2929) | Best G-mean: 0.5894
#   Ep 100 | Tune G-mean: 0.5879 F1: 0.3604 (Sens: 0.3810, Spec: 0.9071, Pre: 0.3419) | Best G-mean: 0.5894
#   Ep 120 | Tune G-mean: 0.5789 F1: 0.3467 (Sens: 0.3714, Spec: 0.9023, Pre: 0.3250) | Best G-mean: 0.5975
#   Ep 140 | Tune G-mean: 0.6009 F1: 0.3496 (Sens: 0.4095, Spec: 0.8818, Pre: 0.3050) | Best G-mean: 0.6009
#   Ep 160 | Tune G-mean: 0.5827 F1: 0.3404 (Sens: 0.3810, Spec: 0.8914, Pre: 0.3077) | Best G-mean: 0.6009
#   Ep 180 | Tune G-mean: 0.5816 F1: 0.3361 (Sens: 0.3810, Spec: 0.8878, Pre: 0.3008) | Best G-mean: 0.6009
#   Ep 200 | Tune G-mean: 0.5890 F1: 0.3268 (Sens: 0.4000, Spec: 0.8673, Pre: 0.2763) | Best G-mean: 0.6009
#
# [5/24] gamma=0.50, lr=5e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6125 F1: 0.3407 (Sens: 0.4381, Spec: 0.8565, Pre: 0.2788) | Best G-mean: 0.6165
#   Ep  40 | Tune G-mean: 0.5555 F1: 0.3214 (Sens: 0.3429, Spec: 0.8999, Pre: 0.3025) | Best G-mean: 0.6275
#   Ep  60 | Tune G-mean: 0.5649 F1: 0.3154 (Sens: 0.3619, Spec: 0.8818, Pre: 0.2794) | Best G-mean: 0.6275
#   Ep  80 | Tune G-mean: 0.4876 F1: 0.2511 (Sens: 0.2667, Spec: 0.8914, Pre: 0.2373) | Best G-mean: 0.6275
#   Ep 100 | Tune G-mean: 0.5528 F1: 0.2794 (Sens: 0.3619, Spec: 0.8444, Pre: 0.2275) | Best G-mean: 0.6275
#   Ep 120 | Tune G-mean: 0.5032 F1: 0.2441 (Sens: 0.2952, Spec: 0.8577, Pre: 0.2081) | Best G-mean: 0.6275
#   Ep 140 | Tune G-mean: 0.5144 F1: 0.2454 (Sens: 0.3143, Spec: 0.8420, Pre: 0.2012) | Best G-mean: 0.6275
#   Ep 160 | Tune G-mean: 0.4817 F1: 0.2535 (Sens: 0.2571, Spec: 0.9023, Pre: 0.2500) | Best G-mean: 0.6275
#
# [6/24] gamma=0.50, lr=5e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5707 F1: 0.3171 (Sens: 0.3714, Spec: 0.8770, Pre: 0.2766) | Best G-mean: 0.5880
#   Ep  40 | Tune G-mean: 0.5391 F1: 0.3036 (Sens: 0.3238, Spec: 0.8975, Pre: 0.2857) | Best G-mean: 0.5880
#   Ep  60 | Tune G-mean: 0.6114 F1: 0.3072 (Sens: 0.4667, Spec: 0.8010, Pre: 0.2290) | Best G-mean: 0.6114
#   Ep  80 | Tune G-mean: 0.5512 F1: 0.2644 (Sens: 0.3714, Spec: 0.8179, Pre: 0.2053) | Best G-mean: 0.6114
#   Ep 100 | Tune G-mean: 0.4905 F1: 0.2407 (Sens: 0.2762, Spec: 0.8709, Pre: 0.2132) | Best G-mean: 0.6114
#   Ep 120 | Tune G-mean: 0.5120 F1: 0.2290 (Sens: 0.3238, Spec: 0.8094, Pre: 0.1771) | Best G-mean: 0.6114
#   Ep 140 | Tune G-mean: 0.5283 F1: 0.2545 (Sens: 0.3333, Spec: 0.8372, Pre: 0.2059) | Best G-mean: 0.6114
#   Ep 160 | Tune G-mean: 0.5252 F1: 0.2298 (Sens: 0.3524, Spec: 0.7829, Pre: 0.1705) | Best G-mean: 0.6114
#   Ep 180 | Tune G-mean: 0.5321 F1: 0.2287 (Sens: 0.3714, Spec: 0.7624, Pre: 0.1653) | Best G-mean: 0.6114
#
# [7/24] gamma=0.50, lr=5e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.5104 F1: 0.2885 (Sens: 0.2857, Spec: 0.9119, Pre: 0.2913) | Best G-mean: 0.5980
#   Ep  40 | Tune G-mean: 0.5804 F1: 0.3320 (Sens: 0.3810, Spec: 0.8842, Pre: 0.2941) | Best G-mean: 0.5980
#   Ep  60 | Tune G-mean: 0.6192 F1: 0.3245 (Sens: 0.4667, Spec: 0.8215, Pre: 0.2487) | Best G-mean: 0.6241
#   Ep  80 | Tune G-mean: 0.5811 F1: 0.3178 (Sens: 0.3905, Spec: 0.8649, Pre: 0.2680) | Best G-mean: 0.6241
#   Ep 100 | Tune G-mean: 0.5047 F1: 0.2667 (Sens: 0.2857, Spec: 0.8914, Pre: 0.2500) | Best G-mean: 0.6241
#   Ep 120 | Tune G-mean: 0.5463 F1: 0.2751 (Sens: 0.3524, Spec: 0.8468, Pre: 0.2256) | Best G-mean: 0.6241
#   Ep 140 | Tune G-mean: 0.5347 F1: 0.2713 (Sens: 0.3333, Spec: 0.8577, Pre: 0.2288) | Best G-mean: 0.6241
#   Ep 160 | Tune G-mean: 0.5320 F1: 0.2642 (Sens: 0.3333, Spec: 0.8492, Pre: 0.2188) | Best G-mean: 0.6241
#
# [8/24] gamma=0.50, lr=5e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.5528 F1: 0.3117 (Sens: 0.3429, Spec: 0.8914, Pre: 0.2857) | Best G-mean: 0.5567
#   Ep  40 | Tune G-mean: 0.5315 F1: 0.2973 (Sens: 0.3143, Spec: 0.8987, Pre: 0.2821) | Best G-mean: 0.6121
#   Ep  60 | Tune G-mean: 0.5377 F1: 0.2657 (Sens: 0.3429, Spec: 0.8432, Pre: 0.2169) | Best G-mean: 0.6121
#   Ep  80 | Tune G-mean: 0.5336 F1: 0.2682 (Sens: 0.3333, Spec: 0.8540, Pre: 0.2244) | Best G-mean: 0.6121
#   Ep 100 | Tune G-mean: 0.4957 F1: 0.2390 (Sens: 0.2857, Spec: 0.8601, Pre: 0.2055) | Best G-mean: 0.6121
#   Ep 120 | Tune G-mean: 0.5780 F1: 0.2776 (Sens: 0.4190, Spec: 0.7973, Pre: 0.2075) | Best G-mean: 0.6121
#   Ep 140 | Tune G-mean: 0.5569 F1: 0.2676 (Sens: 0.3810, Spec: 0.8142, Pre: 0.2062) | Best G-mean: 0.6121
#   Ep 160 | Tune G-mean: 0.5841 F1: 0.2821 (Sens: 0.4286, Spec: 0.7961, Pre: 0.2103) | Best G-mean: 0.6121
#
# [9/24] gamma=0.50, lr=1e-03, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.5848 F1: 0.3293 (Sens: 0.3905, Spec: 0.8758, Pre: 0.2847) | Best G-mean: 0.5848
#   Ep  40 | Tune G-mean: 0.5022 F1: 0.2816 (Sens: 0.2762, Spec: 0.9131, Pre: 0.2871) | Best G-mean: 0.5852
#   Ep  60 | Tune G-mean: 0.5303 F1: 0.2742 (Sens: 0.3238, Spec: 0.8685, Pre: 0.2378) | Best G-mean: 0.5852
#   Ep  80 | Tune G-mean: 0.5207 F1: 0.2482 (Sens: 0.3238, Spec: 0.8372, Pre: 0.2012) | Best G-mean: 0.5852
#   Ep 100 | Tune G-mean: 0.5659 F1: 0.2888 (Sens: 0.3810, Spec: 0.8408, Pre: 0.2326) | Best G-mean: 0.5852
#   Ep 120 | Tune G-mean: 0.5148 F1: 0.2463 (Sens: 0.3143, Spec: 0.8432, Pre: 0.2025) | Best G-mean: 0.5852
#   Ep 140 | Tune G-mean: 0.5806 F1: 0.2752 (Sens: 0.4286, Spec: 0.7865, Pre: 0.2027) | Best G-mean: 0.5852
#
# [10/24] gamma=0.50, lr=1e-03, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5968 F1: 0.3103 (Sens: 0.4286, Spec: 0.8311, Pre: 0.2432) | Best G-mean: 0.6173
#   Ep  40 | Tune G-mean: 0.5474 F1: 0.2782 (Sens: 0.3524, Spec: 0.8504, Pre: 0.2298) | Best G-mean: 0.6173
#   Ep  60 | Tune G-mean: 0.5651 F1: 0.2867 (Sens: 0.3810, Spec: 0.8384, Pre: 0.2299) | Best G-mean: 0.6173
#   Ep  80 | Tune G-mean: 0.5812 F1: 0.3043 (Sens: 0.4000, Spec: 0.8444, Pre: 0.2456) | Best G-mean: 0.6173
#   Ep 100 | Tune G-mean: 0.5292 F1: 0.2709 (Sens: 0.3238, Spec: 0.8649, Pre: 0.2329) | Best G-mean: 0.6173
#   Ep 120 | Tune G-mean: 0.5697 F1: 0.2474 (Sens: 0.4476, Spec: 0.7250, Pre: 0.1709) | Best G-mean: 0.6173
#   Ep 140 | Tune G-mean: 0.4922 F1: 0.2299 (Sens: 0.2857, Spec: 0.8480, Pre: 0.1923) | Best G-mean: 0.6173
#
# [11/24] gamma=0.50, lr=1e-03, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.5592 F1: 0.3364 (Sens: 0.3429, Spec: 0.9119, Pre: 0.3303) | Best G-mean: 0.6041
#   Ep  40 | Tune G-mean: 0.5914 F1: 0.3197 (Sens: 0.4095, Spec: 0.8540, Pre: 0.2622) | Best G-mean: 0.6041
#   Ep  60 | Tune G-mean: 0.6047 F1: 0.3009 (Sens: 0.4571, Spec: 0.7998, Pre: 0.2243) | Best G-mean: 0.6047
#   Ep  80 | Tune G-mean: 0.5636 F1: 0.2955 (Sens: 0.3714, Spec: 0.8552, Pre: 0.2453) | Best G-mean: 0.6047
#   Ep 100 | Tune G-mean: 0.5261 F1: 0.2785 (Sens: 0.3143, Spec: 0.8806, Pre: 0.2500) | Best G-mean: 0.6047
#   Ep 120 | Tune G-mean: 0.5472 F1: 0.2657 (Sens: 0.3619, Spec: 0.8275, Pre: 0.2099) | Best G-mean: 0.6047
#   Ep 140 | Tune G-mean: 0.5576 F1: 0.2796 (Sens: 0.3714, Spec: 0.8372, Pre: 0.2241) | Best G-mean: 0.6047
#   Ep 160 | Tune G-mean: 0.5342 F1: 0.2571 (Sens: 0.3429, Spec: 0.8323, Pre: 0.2057) | Best G-mean: 0.6047
#   Ep 180 | Tune G-mean: 0.5302 F1: 0.2593 (Sens: 0.3333, Spec: 0.8432, Pre: 0.2121) | Best G-mean: 0.6047
#
# [12/24] gamma=0.50, lr=1e-03, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.5354 F1: 0.2906 (Sens: 0.3238, Spec: 0.8854, Pre: 0.2636) | Best G-mean: 0.5525
#   Ep  40 | Tune G-mean: 0.4486 F1: 0.2105 (Sens: 0.2286, Spec: 0.8806, Pre: 0.1951) | Best G-mean: 0.5525
#   Ep  60 | Tune G-mean: 0.5330 F1: 0.2544 (Sens: 0.3429, Spec: 0.8287, Pre: 0.2022) | Best G-mean: 0.5525
#   Ep  80 | Tune G-mean: 0.5613 F1: 0.2680 (Sens: 0.3905, Spec: 0.8070, Pre: 0.2040) | Best G-mean: 0.5613
#   Ep 100 | Tune G-mean: 0.5084 F1: 0.2433 (Sens: 0.3048, Spec: 0.8480, Pre: 0.2025) | Best G-mean: 0.5613
#   Ep 120 | Tune G-mean: 0.5395 F1: 0.2297 (Sens: 0.3905, Spec: 0.7455, Pre: 0.1627) | Best G-mean: 0.5613
#   Ep 140 | Tune G-mean: 0.5158 F1: 0.2369 (Sens: 0.3238, Spec: 0.8215, Pre: 0.1868) | Best G-mean: 0.5924
#   Ep 160 | Tune G-mean: 0.6092 F1: 0.2959 (Sens: 0.4762, Spec: 0.7793, Pre: 0.2146) | Best G-mean: 0.6092
#   Ep 180 | Tune G-mean: 0.5442 F1: 0.2500 (Sens: 0.3714, Spec: 0.7973, Pre: 0.1884) | Best G-mean: 0.6092
#   Ep 200 | Tune G-mean: 0.5865 F1: 0.2733 (Sens: 0.4476, Spec: 0.7684, Pre: 0.1967) | Best G-mean: 0.6092
#
# [13/24] gamma=0.90, lr=1e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6200 F1: 0.3494 (Sens: 0.4476, Spec: 0.8589, Pre: 0.2866) | Best G-mean: 0.6200
#   Ep  40 | Tune G-mean: 0.5325 F1: 0.3014 (Sens: 0.3143, Spec: 0.9023, Pre: 0.2895) | Best G-mean: 0.6200
#   Ep  60 | Tune G-mean: 0.6030 F1: 0.3568 (Sens: 0.4095, Spec: 0.8878, Pre: 0.3162) | Best G-mean: 0.6200
#   Ep  80 | Tune G-mean: 0.5904 F1: 0.3489 (Sens: 0.3905, Spec: 0.8926, Pre: 0.3154) | Best G-mean: 0.6200
#   Ep 100 | Tune G-mean: 0.5631 F1: 0.3289 (Sens: 0.3524, Spec: 0.8999, Pre: 0.3083) | Best G-mean: 0.6200
#   Ep 120 | Tune G-mean: 0.5844 F1: 0.3280 (Sens: 0.3905, Spec: 0.8745, Pre: 0.2828) | Best G-mean: 0.6200
#   Ep 140 | Tune G-mean: 0.6151 F1: 0.3485 (Sens: 0.4381, Spec: 0.8637, Pre: 0.2893) | Best G-mean: 0.6200
#
# [14/24] gamma=0.90, lr=1e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5455 F1: 0.3057 (Sens: 0.3333, Spec: 0.8926, Pre: 0.2823) | Best G-mean: 0.5614
#   Ep  40 | Tune G-mean: 0.5578 F1: 0.3096 (Sens: 0.3524, Spec: 0.8830, Pre: 0.2761) | Best G-mean: 0.5630
#   Ep  60 | Tune G-mean: 0.6063 F1: 0.3358 (Sens: 0.4286, Spec: 0.8577, Pre: 0.2761) | Best G-mean: 0.6063
#   Ep  80 | Tune G-mean: 0.5758 F1: 0.3348 (Sens: 0.3714, Spec: 0.8926, Pre: 0.3047) | Best G-mean: 0.6063
#   Ep 100 | Tune G-mean: 0.5676 F1: 0.3248 (Sens: 0.3619, Spec: 0.8902, Pre: 0.2946) | Best G-mean: 0.6063
#   Ep 120 | Tune G-mean: 0.5672 F1: 0.3234 (Sens: 0.3619, Spec: 0.8890, Pre: 0.2923) | Best G-mean: 0.6063
#   Ep 140 | Tune G-mean: 0.5784 F1: 0.3252 (Sens: 0.3810, Spec: 0.8782, Pre: 0.2837) | Best G-mean: 0.6063
#   Ep 160 | Tune G-mean: 0.5569 F1: 0.3273 (Sens: 0.3429, Spec: 0.9047, Pre: 0.3130) | Best G-mean: 0.6063
#   Ep 180 | Tune G-mean: 0.5892 F1: 0.3445 (Sens: 0.3905, Spec: 0.8890, Pre: 0.3083) | Best G-mean: 0.6121
#   Ep 200 | Tune G-mean: 0.6088 F1: 0.3435 (Sens: 0.4286, Spec: 0.8649, Pre: 0.2866) | Best G-mean: 0.6121
#
# [15/24] gamma=0.90, lr=1e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.5723 F1: 0.3223 (Sens: 0.3714, Spec: 0.8818, Pre: 0.2847) | Best G-mean: 0.5947
#   Ep  40 | Tune G-mean: 0.5653 F1: 0.3167 (Sens: 0.3619, Spec: 0.8830, Pre: 0.2815) | Best G-mean: 0.6067
#   Ep  60 | Tune G-mean: 0.5458 F1: 0.3070 (Sens: 0.3333, Spec: 0.8938, Pre: 0.2846) | Best G-mean: 0.6067
#   Ep  80 | Tune G-mean: 0.5665 F1: 0.3207 (Sens: 0.3619, Spec: 0.8866, Pre: 0.2879) | Best G-mean: 0.6067
#   Ep 100 | Tune G-mean: 0.5665 F1: 0.3207 (Sens: 0.3619, Spec: 0.8866, Pre: 0.2879) | Best G-mean: 0.6067
#   Ep 120 | Tune G-mean: 0.5540 F1: 0.3158 (Sens: 0.3429, Spec: 0.8951, Pre: 0.2927) | Best G-mean: 0.6067
#   Ep 140 | Tune G-mean: 0.5780 F1: 0.3239 (Sens: 0.3810, Spec: 0.8770, Pre: 0.2817) | Best G-mean: 0.6067
#
# [16/24] gamma=0.90, lr=1e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.5436 F1: 0.2991 (Sens: 0.3333, Spec: 0.8866, Pre: 0.2713) | Best G-mean: 0.5567
#   Ep  40 | Tune G-mean: 0.5649 F1: 0.3154 (Sens: 0.3619, Spec: 0.8818, Pre: 0.2794) | Best G-mean: 0.5776
#   Ep  60 | Tune G-mean: 0.5566 F1: 0.3258 (Sens: 0.3429, Spec: 0.9035, Pre: 0.3103) | Best G-mean: 0.5776
#   Ep  80 | Tune G-mean: 0.5840 F1: 0.3267 (Sens: 0.3905, Spec: 0.8733, Pre: 0.2808) | Best G-mean: 0.5972
#   Ep 100 | Tune G-mean: 0.5824 F1: 0.3390 (Sens: 0.3810, Spec: 0.8902, Pre: 0.3053) | Best G-mean: 0.5972
#   Ep 120 | Tune G-mean: 0.5851 F1: 0.3493 (Sens: 0.3810, Spec: 0.8987, Pre: 0.3226) | Best G-mean: 0.6017
#   Ep 140 | Tune G-mean: 0.5943 F1: 0.3443 (Sens: 0.4000, Spec: 0.8830, Pre: 0.3022) | Best G-mean: 0.6024
#   Ep 160 | Tune G-mean: 0.5975 F1: 0.3559 (Sens: 0.4000, Spec: 0.8926, Pre: 0.3206) | Best G-mean: 0.6213
#   Ep 180 | Tune G-mean: 0.6013 F1: 0.3510 (Sens: 0.4095, Spec: 0.8830, Pre: 0.3071) | Best G-mean: 0.6213
#   Ep 200 | Tune G-mean: 0.5997 F1: 0.3454 (Sens: 0.4095, Spec: 0.8782, Pre: 0.2986) | Best G-mean: 0.6252
#
# [17/24] gamma=0.90, lr=5e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6052 F1: 0.3206 (Sens: 0.4381, Spec: 0.8359, Pre: 0.2527) | Best G-mean: 0.6082
#   Ep  40 | Tune G-mean: 0.5151 F1: 0.2818 (Sens: 0.2952, Spec: 0.8987, Pre: 0.2696) | Best G-mean: 0.6082
#   Ep  60 | Tune G-mean: 0.5688 F1: 0.3108 (Sens: 0.3714, Spec: 0.8709, Pre: 0.2671) | Best G-mean: 0.6344
#   Ep  80 | Tune G-mean: 0.5433 F1: 0.2979 (Sens: 0.3333, Spec: 0.8854, Pre: 0.2692) | Best G-mean: 0.6344
#   Ep 100 | Tune G-mean: 0.5536 F1: 0.2960 (Sens: 0.3524, Spec: 0.8697, Pre: 0.2552) | Best G-mean: 0.6344
#   Ep 120 | Tune G-mean: 0.5116 F1: 0.2520 (Sens: 0.3048, Spec: 0.8589, Pre: 0.2148) | Best G-mean: 0.6344
#   Ep 140 | Tune G-mean: 0.4935 F1: 0.2500 (Sens: 0.2762, Spec: 0.8818, Pre: 0.2283) | Best G-mean: 0.6344
#   Ep 160 | Tune G-mean: 0.5339 F1: 0.2692 (Sens: 0.3333, Spec: 0.8552, Pre: 0.2258) | Best G-mean: 0.6344
#
# [18/24] gamma=0.90, lr=5e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5680 F1: 0.3262 (Sens: 0.3619, Spec: 0.8914, Pre: 0.2969) | Best G-mean: 0.5844
#   Ep  40 | Tune G-mean: 0.5279 F1: 0.3077 (Sens: 0.3048, Spec: 0.9144, Pre: 0.3107) | Best G-mean: 0.6151
#   Ep  60 | Tune G-mean: 0.6078 F1: 0.3077 (Sens: 0.4571, Spec: 0.8082, Pre: 0.2319) | Best G-mean: 0.6151
#   Ep  80 | Tune G-mean: 0.5815 F1: 0.2848 (Sens: 0.4190, Spec: 0.8070, Pre: 0.2157) | Best G-mean: 0.6151
#   Ep 100 | Tune G-mean: 0.5296 F1: 0.2720 (Sens: 0.3238, Spec: 0.8661, Pre: 0.2345) | Best G-mean: 0.6151
#   Ep 120 | Tune G-mean: 0.5703 F1: 0.2781 (Sens: 0.4000, Spec: 0.8130, Pre: 0.2132) | Best G-mean: 0.6151
#   Ep 140 | Tune G-mean: 0.5659 F1: 0.2888 (Sens: 0.3810, Spec: 0.8408, Pre: 0.2326) | Best G-mean: 0.6151
#   Ep 160 | Tune G-mean: 0.6101 F1: 0.2865 (Sens: 0.4952, Spec: 0.7515, Pre: 0.2016) | Best G-mean: 0.6151
#
# [19/24] gamma=0.90, lr=5e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.5282 F1: 0.3092 (Sens: 0.3048, Spec: 0.9156, Pre: 0.3137) | Best G-mean: 0.5947
#   Ep  40 | Tune G-mean: 0.5804 F1: 0.3320 (Sens: 0.3810, Spec: 0.8842, Pre: 0.2941) | Best G-mean: 0.5947
#   Ep  60 | Tune G-mean: 0.5672 F1: 0.2920 (Sens: 0.3810, Spec: 0.8444, Pre: 0.2367) | Best G-mean: 0.6195
#   Ep  80 | Tune G-mean: 0.5756 F1: 0.3162 (Sens: 0.3810, Spec: 0.8697, Pre: 0.2703) | Best G-mean: 0.6195
#   Ep 100 | Tune G-mean: 0.4959 F1: 0.2578 (Sens: 0.2762, Spec: 0.8902, Pre: 0.2417) | Best G-mean: 0.6195
#   Ep 120 | Tune G-mean: 0.5426 F1: 0.2791 (Sens: 0.3429, Spec: 0.8589, Pre: 0.2353) | Best G-mean: 0.6195
#   Ep 140 | Tune G-mean: 0.5597 F1: 0.2645 (Sens: 0.3905, Spec: 0.8022, Pre: 0.2000) | Best G-mean: 0.6195
#   Ep 160 | Tune G-mean: 0.4978 F1: 0.2449 (Sens: 0.2857, Spec: 0.8673, Pre: 0.2143) | Best G-mean: 0.6195
#
# [20/24] gamma=0.90, lr=5e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.5376 F1: 0.2982 (Sens: 0.3238, Spec: 0.8926, Pre: 0.2764) | Best G-mean: 0.5657
#   Ep  40 | Tune G-mean: 0.5676 F1: 0.3474 (Sens: 0.3524, Spec: 0.9144, Pre: 0.3426) | Best G-mean: 0.6099
#   Ep  60 | Tune G-mean: 0.5807 F1: 0.3166 (Sens: 0.3905, Spec: 0.8637, Pre: 0.2662) | Best G-mean: 0.6099
#   Ep  80 | Tune G-mean: 0.5078 F1: 0.2573 (Sens: 0.2952, Spec: 0.8733, Pre: 0.2279) | Best G-mean: 0.6099
#   Ep 100 | Tune G-mean: 0.5484 F1: 0.2686 (Sens: 0.3619, Spec: 0.8311, Pre: 0.2135) | Best G-mean: 0.6099
#   Ep 120 | Tune G-mean: 0.5719 F1: 0.2730 (Sens: 0.4095, Spec: 0.7986, Pre: 0.2048) | Best G-mean: 0.6099
#   Ep 140 | Tune G-mean: 0.5871 F1: 0.2973 (Sens: 0.4190, Spec: 0.8227, Pre: 0.2304) | Best G-mean: 0.6148
#   Ep 160 | Tune G-mean: 0.5528 F1: 0.2589 (Sens: 0.3810, Spec: 0.8022, Pre: 0.1961) | Best G-mean: 0.6148
#   Ep 180 | Tune G-mean: 0.5487 F1: 0.2591 (Sens: 0.3714, Spec: 0.8106, Pre: 0.1990) | Best G-mean: 0.6289
#   Ep 200 | Tune G-mean: 0.5906 F1: 0.2806 (Sens: 0.4476, Spec: 0.7793, Pre: 0.2043) | Best G-mean: 0.6289
#
# [21/24] gamma=0.90, lr=1e-03, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.5728 F1: 0.3077 (Sens: 0.3810, Spec: 0.8613, Pre: 0.2581) | Best G-mean: 0.5931
#   Ep  40 | Tune G-mean: 0.4768 F1: 0.2613 (Sens: 0.2476, Spec: 0.9180, Pre: 0.2766) | Best G-mean: 0.5931
#   Ep  60 | Tune G-mean: 0.5555 F1: 0.3020 (Sens: 0.3524, Spec: 0.8758, Pre: 0.2643) | Best G-mean: 0.5931
#   Ep  80 | Tune G-mean: 0.4852 F1: 0.2435 (Sens: 0.2667, Spec: 0.8830, Pre: 0.2240) | Best G-mean: 0.5931
#   Ep 100 | Tune G-mean: 0.4978 F1: 0.2449 (Sens: 0.2857, Spec: 0.8673, Pre: 0.2143) | Best G-mean: 0.5931
#   Ep 120 | Tune G-mean: 0.4843 F1: 0.2403 (Sens: 0.2667, Spec: 0.8794, Pre: 0.2188) | Best G-mean: 0.5931
#   Ep 140 | Tune G-mean: 0.4918 F1: 0.2447 (Sens: 0.2762, Spec: 0.8758, Pre: 0.2197) | Best G-mean: 0.5931
#
# [22/24] gamma=0.90, lr=1e-03, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5668 F1: 0.3047 (Sens: 0.3714, Spec: 0.8649, Pre: 0.2583) | Best G-mean: 0.5668
#   Ep  40 | Tune G-mean: 0.4862 F1: 0.2467 (Sens: 0.2667, Spec: 0.8866, Pre: 0.2295) | Best G-mean: 0.5668
#   Ep  60 | Tune G-mean: 0.5365 F1: 0.2628 (Sens: 0.3429, Spec: 0.8396, Pre: 0.2130) | Best G-mean: 0.5668
#   Ep  80 | Tune G-mean: 0.5536 F1: 0.2699 (Sens: 0.3714, Spec: 0.8251, Pre: 0.2120) | Best G-mean: 0.5668
#   Ep 100 | Tune G-mean: 0.5170 F1: 0.2678 (Sens: 0.3048, Spec: 0.8770, Pre: 0.2388) | Best G-mean: 0.5996
#   Ep 120 | Tune G-mean: 0.5545 F1: 0.2623 (Sens: 0.3810, Spec: 0.8070, Pre: 0.2000) | Best G-mean: 0.5996
#   Ep 140 | Tune G-mean: 0.5098 F1: 0.2471 (Sens: 0.3048, Spec: 0.8528, Pre: 0.2078) | Best G-mean: 0.5996
#   Ep 160 | Tune G-mean: 0.5579 F1: 0.2387 (Sens: 0.4286, Spec: 0.7262, Pre: 0.1654) | Best G-mean: 0.5996
#   Ep 180 | Tune G-mean: 0.5416 F1: 0.2533 (Sens: 0.3619, Spec: 0.8106, Pre: 0.1949) | Best G-mean: 0.5996
#   Ep 200 | Tune G-mean: 0.5097 F1: 0.2167 (Sens: 0.3333, Spec: 0.7793, Pre: 0.1606) | Best G-mean: 0.5996
#
# [23/24] gamma=0.90, lr=1e-03, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.5592 F1: 0.3364 (Sens: 0.3429, Spec: 0.9119, Pre: 0.3303) | Best G-mean: 0.6095
#   Ep  40 | Tune G-mean: 0.5752 F1: 0.3150 (Sens: 0.3810, Spec: 0.8685, Pre: 0.2685) | Best G-mean: 0.6095
#   Ep  60 | Tune G-mean: 0.5651 F1: 0.2761 (Sens: 0.3905, Spec: 0.8179, Pre: 0.2135) | Best G-mean: 0.6095
#   Ep  80 | Tune G-mean: 0.5524 F1: 0.2925 (Sens: 0.3524, Spec: 0.8661, Pre: 0.2500) | Best G-mean: 0.6095
#   Ep 100 | Tune G-mean: 0.5235 F1: 0.2705 (Sens: 0.3143, Spec: 0.8721, Pre: 0.2374) | Best G-mean: 0.6095
#   Ep 120 | Tune G-mean: 0.5600 F1: 0.2857 (Sens: 0.3714, Spec: 0.8444, Pre: 0.2321) | Best G-mean: 0.6095
#
# [24/24] gamma=0.90, lr=1e-03, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.5300 F1: 0.2920 (Sens: 0.3143, Spec: 0.8938, Pre: 0.2727) | Best G-mean: 0.5473
#   Ep  40 | Tune G-mean: 0.4969 F1: 0.2613 (Sens: 0.2762, Spec: 0.8938, Pre: 0.2479) | Best G-mean: 0.5955
#   Ep  60 | Tune G-mean: 0.5129 F1: 0.2418 (Sens: 0.3143, Spec: 0.8372, Pre: 0.1964) | Best G-mean: 0.5955
#   Ep  80 | Tune G-mean: 0.5476 F1: 0.2667 (Sens: 0.3619, Spec: 0.8287, Pre: 0.2111) | Best G-mean: 0.5955
#   Ep 100 | Tune G-mean: 0.5453 F1: 0.2446 (Sens: 0.3810, Spec: 0.7805, Pre: 0.1802) | Best G-mean: 0.5955
#   Ep 120 | Tune G-mean: 0.5240 F1: 0.2353 (Sens: 0.3429, Spec: 0.8010, Pre: 0.1791) | Best G-mean: 0.5955
#   Ep 140 | Tune G-mean: 0.5201 F1: 0.2278 (Sens: 0.3429, Spec: 0.7889, Pre: 0.1706) | Best G-mean: 0.5955
#   Ep 160 | Tune G-mean: 0.5321 F1: 0.2287 (Sens: 0.3714, Spec: 0.7624, Pre: 0.1653) | Best G-mean: 0.5955
#
# ================================================================================
# TOP 5 HYPERPARAMETERS
# ================================================================================
# 1. G-mean: 0.6706 | F1: 0.3934 | Prec: 0.2874 | Params: {'gamma': 0.9, 'lr': 0.0001, 'epsilon_decay': 0.995, 'batch_size': 32}
# 2. G-mean: 0.6695 | F1: 0.3918 | Prec: 0.2857 | Params: {'gamma': 0.9, 'lr': 0.0001, 'epsilon_decay': 0.99, 'batch_size': 32}
# 3. G-mean: 0.6625 | F1: 0.3852 | Prec: 0.2814 | Params: {'gamma': 0.5, 'lr': 0.0001, 'epsilon_decay': 0.995, 'batch_size': 32}
# 4. G-mean: 0.6323 | F1: 0.3605 | Prec: 0.2692 | Params: {'gamma': 0.9, 'lr': 0.001, 'epsilon_decay': 0.995, 'batch_size': 32}
# 5. G-mean: 0.6317 | F1: 0.3644 | Prec: 0.2770 | Params: {'gamma': 0.9, 'lr': 0.001, 'epsilon_decay': 0.99, 'batch_size': 32}
#
# ================================================================================
# BEST HYPERPARAMETERS
# ================================================================================
# gamma: 0.9
# lr: 0.0001
# epsilon_decay: 0.995
# batch_size: 32
# Best Selection G-mean: 0.6706
# ================================================================================
#
# Training with best hyperparameters...
# Episode  10 | Reward: -64.43859 | G-mean: 0.6449 | F1: 0.3755 | Prec: 0.2829 | Best G-mean: 0.6449
# Episode  20 | Reward: -62.89205 | G-mean: 0.6449 | F1: 0.3755 | Prec: 0.2829 | Best G-mean: 0.6449
# Episode  30 | Reward: -60.79423 | G-mean: 0.6520 | F1: 0.3874 | Prec: 0.2966 | Best G-mean: 0.6520
# Episode  40 | Reward: -50.74282 | G-mean: 0.6597 | F1: 0.3896 | Prec: 0.2922 | Best G-mean: 0.6597
# Episode  50 | Reward: -55.82013 | G-mean: 0.6561 | F1: 0.4019 | Prec: 0.3182 | Best G-mean: 0.6597
# Episode  60 | Reward: -49.13205 | G-mean: 0.6250 | F1: 0.3725 | Prec: 0.2992 | Best G-mean: 0.6597
# Episode  70 | Reward: -44.79026 | G-mean: 0.6534 | F1: 0.3843 | Prec: 0.2895 | Best G-mean: 0.6597
# Episode  80 | Reward: -39.40692 | G-mean: 0.6503 | F1: 0.3750 | Prec: 0.2761 | Best G-mean: 0.6597
# Episode  90 | Reward: -46.03692 | G-mean: 0.6410 | F1: 0.3651 | Prec: 0.2683 | Best G-mean: 0.6597
# Episode 100 | Reward: -33.48513 | G-mean: 0.6213 | F1: 0.3654 | Prec: 0.2901 | Best G-mean: 0.6597
# Episode 110 | Reward: -34.17654 | G-mean: 0.6333 | F1: 0.3621 | Prec: 0.2710 | Best G-mean: 0.6597
# Episode 120 | Reward: -27.86397 | G-mean: 0.6180 | F1: 0.3529 | Prec: 0.2708 | Best G-mean: 0.6597
# Episode 130 | Reward: -18.82064 | G-mean: 0.5994 | F1: 0.3687 | Prec: 0.3235 | Best G-mean: 0.6597
# Episode 140 | Reward: -22.40077 | G-mean: 0.6267 | F1: 0.3565 | Prec: 0.2680 | Best G-mean: 0.6597
# Episode 150 | Reward: -23.99141 | G-mean: 0.6113 | F1: 0.3421 | Prec: 0.2583 | Best G-mean: 0.6597
# Episode 160 | Reward: -10.74872 | G-mean: 0.6122 | F1: 0.3436 | Prec: 0.2600 | Best G-mean: 0.6597
# Episode 170 | Reward: -12.74808 | G-mean: 0.6003 | F1: 0.3708 | Prec: 0.3267 | Best G-mean: 0.6597
# Episode 180 | Reward: -4.80128 | G-mean: 0.6295 | F1: 0.3525 | Prec: 0.2575 | Best G-mean: 0.6597
# Episode 190 | Reward: -12.83577 | G-mean: 0.6051 | F1: 0.3590 | Prec: 0.2966 | Best G-mean: 0.6597
# Episode 200 | Reward: -5.72731 | G-mean: 0.6119 | F1: 0.3486 | Prec: 0.2695 | Best G-mean: 0.6597
# Episode 210 | Reward: -3.19000 | G-mean: 0.6237 | F1: 0.3628 | Prec: 0.2826 | Best G-mean: 0.6597
# Episode 220 | Reward:  5.61949 | G-mean: 0.6129 | F1: 0.3502 | Prec: 0.2714 | Best G-mean: 0.6597
# Episode 230 | Reward:  6.92256 | G-mean: 0.6295 | F1: 0.3525 | Prec: 0.2575 | Best G-mean: 0.6597
# Episode 240 | Reward:  2.50103 | G-mean: 0.6267 | F1: 0.3565 | Prec: 0.2680 | Best G-mean: 0.6597
# Episode 250 | Reward:  5.33308 | G-mean: 0.5928 | F1: 0.3288 | Prec: 0.2535 | Best G-mean: 0.6597
# Episode 260 | Reward:  7.31897 | G-mean: 0.6177 | F1: 0.3431 | Prec: 0.2531 | Best G-mean: 0.6597
# Episode 270 | Reward:  4.96385 | G-mean: 0.5944 | F1: 0.3260 | Prec: 0.2467 | Best G-mean: 0.6597
# Episode 280 | Reward: 14.41910 | G-mean: 0.6221 | F1: 0.3457 | Prec: 0.2530 | Best G-mean: 0.6597
# Episode 290 | Reward: 16.06000 | G-mean: 0.6199 | F1: 0.3562 | Prec: 0.2746 | Best G-mean: 0.6597
# Episode 300 | Reward: 21.00987 | G-mean: 0.5990 | F1: 0.3560 | Prec: 0.2982 | Best G-mean: 0.6597
# Episode 310 | Reward: 19.47936 | G-mean: 0.6227 | F1: 0.3504 | Prec: 0.2611 | Best G-mean: 0.6597
# Episode 320 | Reward: 31.19244 | G-mean: 0.6171 | F1: 0.3463 | Prec: 0.2597 | Best G-mean: 0.6597
# Episode 330 | Reward: 26.53154 | G-mean: 0.6191 | F1: 0.3493 | Prec: 0.2632 | Best G-mean: 0.6597
# Episode 340 | Reward: 31.01551 | G-mean: 0.6207 | F1: 0.3475 | Prec: 0.2579 | Best G-mean: 0.6597
# Episode 350 | Reward: 27.64410 | G-mean: 0.6062 | F1: 0.3393 | Prec: 0.2585 | Best G-mean: 0.6597
# Episode 360 | Reward: 20.19397 | G-mean: 0.6357 | F1: 0.3577 | Prec: 0.2604 | Best G-mean: 0.6597
# Episode 370 | Reward: 28.56782 | G-mean: 0.6317 | F1: 0.3644 | Prec: 0.2770 | Best G-mean: 0.6597
# Episode 380 | Reward: 34.48385 | G-mean: 0.5799 | F1: 0.3267 | Prec: 0.2640 | Best G-mean: 0.6597
# Episode 390 | Reward: 30.10692 | G-mean: 0.6142 | F1: 0.3467 | Prec: 0.2635 | Best G-mean: 0.6597
# Episode 400 | Reward: 31.13115 | G-mean: 0.6103 | F1: 0.3406 | Prec: 0.2566 | Best G-mean: 0.6597
# Episode 410 | Reward: 41.01090 | G-mean: 0.5984 | F1: 0.3380 | Prec: 0.2647 | Best G-mean: 0.6597
# Episode 420 | Reward: 31.14103 | G-mean: 0.6197 | F1: 0.3372 | Prec: 0.2391 | Best G-mean: 0.6597
# Episode 430 | Reward: 41.40090 | G-mean: 0.5755 | F1: 0.3188 | Prec: 0.2538 | Best G-mean: 0.6597
# Episode 440 | Reward: 34.39500 | G-mean: 0.5824 | F1: 0.3238 | Prec: 0.2556 | Best G-mean: 0.6597
# Episode 450 | Reward: 40.04833 | G-mean: 0.5807 | F1: 0.3284 | Prec: 0.2661 | Best G-mean: 0.6597
# Episode 460 | Reward: 43.17885 | G-mean: 0.5817 | F1: 0.3117 | Prec: 0.2338 | Best G-mean: 0.6597
# Episode 470 | Reward: 42.50295 | G-mean: 0.5662 | F1: 0.3179 | Prec: 0.2627 | Best G-mean: 0.6597
# Episode 480 | Reward: 46.80846 | G-mean: 0.5641 | F1: 0.3062 | Prec: 0.2424 | Best G-mean: 0.6597
# Episode 490 | Reward: 42.02192 | G-mean: 0.5683 | F1: 0.2939 | Prec: 0.2143 | Best G-mean: 0.6597
# Episode 500 | Reward: 47.86795 | G-mean: 0.5261 | F1: 0.2889 | Prec: 0.2524 | Best G-mean: 0.6597
# Episode 510 | Reward: 46.89923 | G-mean: 0.5381 | F1: 0.2917 | Prec: 0.2435 | Best G-mean: 0.6597
# Episode 520 | Reward: 39.89910 | G-mean: 0.5694 | F1: 0.3084 | Prec: 0.2409 | Best G-mean: 0.6597
# Episode 530 | Reward: 45.23590 | G-mean: 0.5520 | F1: 0.3000 | Prec: 0.2439 | Best G-mean: 0.6597
# Episode 540 | Reward: 42.41115 | G-mean: 0.5741 | F1: 0.3013 | Prec: 0.2222 | Best G-mean: 0.6597
# Episode 550 | Reward: 45.06936 | G-mean: 0.5605 | F1: 0.2946 | Prec: 0.2245 | Best G-mean: 0.6597
# Episode 560 | Reward: 51.74923 | G-mean: 0.5500 | F1: 0.3053 | Prec: 0.2566 | Best G-mean: 0.6597
# Episode 570 | Reward: 52.29590 | G-mean: 0.5428 | F1: 0.2915 | Prec: 0.2377 | Best G-mean: 0.6597
# Episode 580 | Reward: 57.18590 | G-mean: 0.5624 | F1: 0.3033 | Prec: 0.2388 | Best G-mean: 0.6597
# Episode 590 | Reward: 57.32167 | G-mean: 0.5395 | F1: 0.2857 | Prec: 0.2302 | Best G-mean: 0.6597
# Episode 600 | Reward: 59.72077 | G-mean: 0.5515 | F1: 0.2821 | Prec: 0.2102 | Best G-mean: 0.6597
# Episode 610 | Reward: 61.01679 | G-mean: 0.5263 | F1: 0.2648 | Prec: 0.2042 | Best G-mean: 0.6597
# Episode 620 | Reward: 51.61615 | G-mean: 0.5603 | F1: 0.3069 | Prec: 0.2480 | Best G-mean: 0.6597
# Episode 630 | Reward: 60.82013 | G-mean: 0.5457 | F1: 0.2783 | Prec: 0.2092 | Best G-mean: 0.6597
# Episode 640 | Reward: 70.47987 | G-mean: 0.5214 | F1: 0.2542 | Prec: 0.1887 | Best G-mean: 0.6597
# Episode 650 | Reward: 64.05859 | G-mean: 0.5217 | F1: 0.2924 | Prec: 0.2660 | Best G-mean: 0.6597
# Episode 660 | Reward: 48.51679 | G-mean: 0.5415 | F1: 0.2768 | Prec: 0.2109 | Best G-mean: 0.6597
# Episode 670 | Reward: 64.00269 | G-mean: 0.5410 | F1: 0.2667 | Prec: 0.1910 | Best G-mean: 0.6597
# Episode 680 | Reward: 56.42949 | G-mean: 0.5381 | F1: 0.2917 | Prec: 0.2435 | Best G-mean: 0.6597
# Episode 690 | Reward: 52.75321 | G-mean: 0.5378 | F1: 0.2765 | Prec: 0.2143 | Best G-mean: 0.6597
# Episode 700 | Reward: 55.04321 | G-mean: 0.5389 | F1: 0.2932 | Prec: 0.2456 | Best G-mean: 0.6597
# Episode 710 | Reward: 58.05885 | G-mean: 0.4927 | F1: 0.2556 | Prec: 0.2233 | Best G-mean: 0.6597
# Episode 720 | Reward: 68.06538 | G-mean: 0.5032 | F1: 0.2788 | Prec: 0.2614 | Best G-mean: 0.6597
# Episode 730 | Reward: 57.91256 | G-mean: 0.5300 | F1: 0.2857 | Prec: 0.2411 | Best G-mean: 0.6597
# Episode 740 | Reward: 65.18615 | G-mean: 0.5304 | F1: 0.2710 | Prec: 0.2117 | Best G-mean: 0.6597
# Episode 750 | Reward: 46.82359 | G-mean: 0.5341 | F1: 0.2843 | Prec: 0.2333 | Best G-mean: 0.6597
# Episode 760 | Reward: 71.29167 | G-mean: 0.5238 | F1: 0.2842 | Prec: 0.2453 | Best G-mean: 0.6597
# Episode 770 | Reward: 65.17513 | G-mean: 0.5196 | F1: 0.2605 | Prec: 0.2029 | Best G-mean: 0.6597
# Episode 780 | Reward: 66.53551 | G-mean: 0.5166 | F1: 0.2621 | Prec: 0.2093 | Best G-mean: 0.6597
# Episode 790 | Reward: 59.03256 | G-mean: 0.5144 | F1: 0.2762 | Prec: 0.2404 | Best G-mean: 0.6597
# Episode 800 | Reward: 62.72103 | G-mean: 0.5137 | F1: 0.2747 | Prec: 0.2381 | Best G-mean: 0.6597
# 최종 학습 완료
# Best checkpoint restored: epoch=40, valid_gmean=0.6597
#
# ============================================================
# VALID Q-MARGIN THRESHOLD SELECTION
# ============================================================
# Max valid G-mean      = 0.6770
# G-mean floor 99%      = 0.6702
# Selected threshold    = -0.133976
# Selected valid CM: TN=267, FP=160, FN=21, TP=56
# Valid Sens=0.7273, Spec=0.6253, Prec=0.2593, F1=0.3823, G-mean=0.6744
# ============================================================
#
# ============================================================
# TEST SET - DDQN 분류 모델 최종 성능 평가
# ============================================================
#
# G-mean: 0.6686
#
# Confusion Matrix:
# [[516 207]
#  [ 37  62]]
#
# TN: 516, FP: 207
# FN: 37, TP: 62
#
# 분류 리포트:
#                     precision    recall  f1-score   support
#
# Class 0 (Negative)       0.93      0.71      0.81       723
# Class 1 (Positive)       0.23      0.63      0.34        99
#
#           accuracy                           0.70       822
#          macro avg       0.58      0.67      0.57       822
#       weighted avg       0.85      0.70      0.75       822
# 상세 메트릭 (Test Set):
# Sensitivity (Recall for Class 1): 0.6263
# Specificity (Recall for Class 0): 0.7137
# Precision (Class 1):              0.2305
# F1-Score:                         0.3370
# G-mean:                           0.6686
# ============================================================
#
# ============================================================
# VALIDATION SET vs TEST SET 성능 비교
# ============================================================
#
# Validation(Selection) Set - G-mean: 0.6744
# Test Set - G-mean: 0.6686
# Difference (Valid - Test): 0.0058
#
# Validation Confusion Matrix:
# [[267 160]
#  [ 21  56]]
#
# Test Confusion Matrix:
# [[516 207]
#  [ 37  62]]
# ============================================================

# %%
# Test 구간 날짜 인덱스
test_dates = dat.index[test_indices]

# (이미 계산된) test_predictions를 사용해 Test 구간 결과만 저장
test_predicted_actions_df = pd.DataFrame({
    "Date": test_dates,
    "Predicted_Action": test_predictions
})


# CSV 저장
output_test_csv_path = "../../results/results_RL/DDQN_predictions4.csv"
test_predicted_actions_df.to_csv(output_test_csv_path, index=False)

print(f"Test 구간 예측 결과가 '{output_test_csv_path}' 파일로 저장되었습니다.")
display(test_predicted_actions_df.head())
# Out:
# Test 구간 예측 결과가 '../../results/results_RL/DDQN_predictions4.csv' 파일로 저장되었습니다.
#          Date  Predicted_Action
# 0  2022-10-17                 0
# 1  2022-10-18                 0
# 2  2022-10-19                 1
# 3  2022-10-20                 1
# 4  2022-10-21                 0
