# %%
# 랜덤성 제어를 위한 표준 라이브러리 모듈을 불러옵니다.
import random
from collections import deque
from pathlib import Path
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import MinMaxScaler


# 데이터셋을 불러옵니다.
dat = pd.read_csv(Path("../../data/processed/data_vif.csv"), index_col=0)

# 재현 가능한 실험을 위해 시드 값을 고정합니다.
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# GPU가 있으면 CUDA를, 없으면 CPU를 사용하도록 장치를 설정합니다.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# DDQN에서 사용할 Q-Network 구조를 정의합니다.
# 데이터 수가 많지 않으므로 과적합 가능성을 염두에 두고 2개 은닉층을 사용합니다.
class QNetwork(nn.Module):
    def __init__(self, state_dim: int, action_dim: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 96),
            nn.ReLU(),
            nn.Linear(96, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim),
        )

    def forward(self, x):
        return self.net(x)


# 경험을 저장하고 무작위 샘플링하기 위한 리플레이 버퍼를 정의합니다.
class ReplayBuffer:
    def __init__(self, capacity: int):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size: int):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = map(np.array, zip(*batch))
        return (
            torch.FloatTensor(states).to(device),
            torch.LongTensor(actions).unsqueeze(1).to(device),
            torch.FloatTensor(rewards).unsqueeze(1).to(device),
            torch.FloatTensor(next_states).to(device),
            torch.FloatTensor(dones.astype(np.float32)).unsqueeze(1).to(device),
        )

    def __len__(self):
        return len(self.buffer)


# DDQN 에이전트를 정의합니다.
class DDQNAgent:
    def __init__(
        self,
        state_dim,
        action_dim,
        gamma=0.95,
        lr=5e-4,
        batch_size=64,
        memory_size=100_000,
        target_update=500,
        epsilon_start=1.0,
        epsilon_end=0.05,
        epsilon_decay=0.995,
    ):
        self.action_dim = action_dim
        self.gamma = gamma
        self.batch_size = batch_size
        self.target_update = target_update

        self.epsilon = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay

        self.online_net = QNetwork(state_dim, action_dim).to(device)
        self.target_net = QNetwork(state_dim, action_dim).to(device)
        self.target_net.load_state_dict(self.online_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.online_net.parameters(), lr=lr)
        self.memory = ReplayBuffer(memory_size)
        self.total_steps = 0

    def act(self, state, epsilon: float = None):
        if epsilon is None:
            epsilon = self.epsilon

        if random.random() < epsilon:
            return random.randrange(self.action_dim)

        state_t = torch.FloatTensor(state).unsqueeze(0).to(device)
        with torch.no_grad():
            q_values = self.online_net(state_t)
        return int(torch.argmax(q_values, dim=1).item())

    def decay_epsilon(self):
        self.epsilon = max(self.epsilon_end, self.epsilon * self.epsilon_decay)

    def update(self):
        if len(self.memory) < self.batch_size:
            return None

        states, actions, rewards, next_states, dones = self.memory.sample(self.batch_size)
        q_values = self.online_net(states).gather(1, actions)
        next_actions = self.online_net(next_states).argmax(dim=1, keepdim=True)
        next_q_values = self.target_net(next_states).gather(1, next_actions)
        target_q = rewards + (1 - dones) * self.gamma * next_q_values
        loss = F.mse_loss(q_values, target_q.detach())
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.online_net.parameters(), max_norm=10.0)
        self.optimizer.step()
        self.total_steps += 1
        if self.total_steps % self.target_update == 0:
            self.target_net.load_state_dict(self.online_net.state_dict())
        return float(loss.item())


# ---- 데이터 준비 (Train/Valid/Test Split 먼저, 그 후 Scaling) ----

risk_label_col = "Risk_Label"
feature_cols = [c for c in dat.select_dtypes(include=[np.number]).columns if c != risk_label_col]
if len(feature_cols) == 0:
    raise ValueError("학습에 사용할 수치형 feature가 없습니다.")

risk_label_data = dat[risk_label_col].map({'Low Risk': 0, 'High Risk': 1}).fillna(0).astype(int).to_numpy()
feature_data_raw = dat[feature_cols].fillna(0.0).to_numpy()
n_steps = len(dat)

train_ratio, valid_ratio, test_ratio = 0.5, 0.3, 0.2
n_train = int(n_steps * train_ratio)
n_valid = int(n_steps * valid_ratio)

train_indices = np.arange(0, n_train)
valid_indices = np.arange(n_train, n_train + n_valid)
test_indices = np.arange(n_train + n_valid, n_steps)

train_feature_raw = feature_data_raw[train_indices]
train_label = risk_label_data[train_indices]

valid_feature_raw = feature_data_raw[valid_indices]
valid_label = risk_label_data[valid_indices]
if len(valid_label) < 2:
    raise ValueError("Validation set 길이가 너무 짧아 tuning/selection 분할이 불가능합니다. split 비율을 조정하세요.")
valid_split_point = len(valid_label) // 2
valid_tune_feature_raw = valid_feature_raw[:valid_split_point]
valid_tune_label = valid_label[:valid_split_point]
valid_select_feature_raw = valid_feature_raw[valid_split_point:]
valid_select_label = valid_label[valid_split_point:]

test_feature_raw = feature_data_raw[test_indices]
test_label = risk_label_data[test_indices]

def summarize_class_ratio(name, y):
    n_total = len(y)
    n0 = int((y == 0).sum())
    n1 = int((y == 1).sum())
    r0 = n0 / n_total if n_total > 0 else 0.0
    r1 = n1 / n_total if n_total > 0 else 0.0
    imbalance = (n1 / max(n0, 1)) if n_total > 0 else 0.0
    print(f"{name:>5} | n={n_total:4d} | class0={n0:4d} ({r0:.2%}) | class1={n1:4d} ({r1:.2%}) | c1/c0={imbalance:.4f})")
    if n0 == 0 or n1 == 0:
        raise ValueError(f"{name} set에 클래스 0 또는 1이 없습니다. split 비율 또는 기간을 조정하세요.")

print("Class Ratio Summary (Before ADASYN)")
summarize_class_ratio("Train", train_label)
summarize_class_ratio("ValTun", valid_tune_label)
summarize_class_ratio("ValSel", valid_select_label)
summarize_class_ratio("Test", test_label)

# 보상 계산에 사용할 class_ratio는 원본 train 기준으로 고정합니다.
n_negative_original = (train_label == 0).sum()
n_positive_original = (train_label == 1).sum()
class_ratio_reward = n_positive_original / max(n_negative_original, 1)
print(f"Reward class ratio (original train): {class_ratio_reward:.4f}")

# ---- ADASYN을 적용하지 않고 원본 학습 데이터를 그대로 사용 ----
train_feature = train_feature_raw.astype(np.float32)
train_label = train_label.astype(np.int64)

scaler = MinMaxScaler()
scaler.fit(train_feature)

train_feature = scaler.transform(train_feature).astype(np.float32)
valid_tune_feature = scaler.transform(valid_tune_feature_raw).astype(np.float32)
valid_select_feature = scaler.transform(valid_select_feature_raw).astype(np.float32)
test_feature = scaler.transform(test_feature_raw).astype(np.float32)

print("=" * 60)
print("Data Split Information")
print("=" * 60)
print(f"Total samples: {n_steps}")
print(f"Train set: {len(train_label)} samples")
print(f"  - Class 0: {(train_label==0).sum()}, Class 1: {(train_label==1).sum()}")
print(f"Valid(Tune) set: {len(valid_tune_label)} samples")
print(f"  - Class 0: {(valid_tune_label==0).sum()}, Class 1: {(valid_tune_label==1).sum()}")
print(f"Valid(Select) set: {len(valid_select_label)} samples")
print(f"  - Class 0: {(valid_select_label==0).sum()}, Class 1: {(valid_select_label==1).sum()}")
print(f"Test set: {len(test_indices)} samples ({test_ratio*100:.1f}%)")
print(f"  - Class 0: {(test_label==0).sum()}, Class 1: {(test_label==1).sum()}")

# 원본 학습 세트의 클래스 비율을 그대로 사용합니다.
n_negative = (train_label == 0).sum()
n_positive = (train_label == 1).sum()
class_ratio = class_ratio_reward

print(f"\nClass ratio (train set): {n_positive / max(n_negative, 1):.4f}")
print(f"Class ratio used for reward: {class_ratio:.4f}")
print("=" * 60)

state_dim = len(feature_cols)
action_dim = 2

def compute_reward(action, actual_label, class_ratio):
    action = int(action)
    actual_label = int(actual_label)
    if actual_label == 0:
        if action == 0:
            return class_ratio
        else:
            return -class_ratio
    else:
        if action == 1:
            return 0.85
        else:
            return -0.85
# Out:
# Class Ratio Summary (Before ADASYN)
# Train | n=2054 | class0=1859 (90.51%) | class1= 195 (9.49%) | c1/c0=0.1049)
# ValTun | n= 616 | class0= 540 (87.66%) | class1=  76 (12.34%) | c1/c0=0.1407)
# ValSel | n= 616 | class0= 530 (86.04%) | class1=  86 (13.96%) | c1/c0=0.1623)
#  Test | n= 822 | class0= 730 (88.81%) | class1=  92 (11.19%) | c1/c0=0.1260)
# Reward class ratio (original train): 0.1049
# ============================================================
# Data Split Information
# ============================================================
# Total samples: 4108
# Train set: 2054 samples
#   - Class 0: 1859, Class 1: 195
# Valid(Tune) set: 616 samples
#   - Class 0: 540, Class 1: 76
# Valid(Select) set: 616 samples
#   - Class 0: 530, Class 1: 86
# Test set: 822 samples (20.0%)
#   - Class 0: 730, Class 1: 92
#
# Class ratio (train set): 0.1049
# Class ratio used for reward: 0.1049
# ============================================================

# %%
# ---- Validation 기반 하이퍼파라미터 Grid Search ----
from itertools import product

param_grid = {
    'gamma': [0.9, 0.99],
    'lr': [1e-4, 1e-3],
    'epsilon_decay': [0.99, 0.999],
    'batch_size': [32, 64],
}

def compute_gmean(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0
    gmean = float(np.sqrt(sensitivity * specificity))
    return gmean, sensitivity, specificity

def predict_labels_argmax(model, features):
    preds = []
    with torch.no_grad():
        for t in range(len(features)):
            state_t = torch.FloatTensor(features[t]).unsqueeze(0).to(device)
            q_values = model(state_t)
            preds.append(int(torch.argmax(q_values, dim=1).item()))
    return np.array(preds)

def evaluate_argmax(model, x_valid, y_valid):
    preds = predict_labels_argmax(model, x_valid)
    gmean, sensitivity, specificity = compute_gmean(y_valid, preds)
    return gmean, sensitivity, specificity

grid_search_results = []
param_combinations = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

print("\n" + "=" * 80)
print(f"HYPERPARAMETER GRID SEARCH (Total: {len(param_combinations)} combinations)")
print("=" * 80)

patience = 25
min_episodes = 60
best_overall_select_gmean = 0.0
best_overall_params = None

for idx, params in enumerate(param_combinations):
    param_dict = dict(zip(param_names, params))
    gamma, lr, epsilon_decay, batch_size = params

    print(f"\n[{idx+1}/{len(param_combinations)}] gamma={gamma:.2f}, lr={lr:.0e}, eps_decay={epsilon_decay:.3f}, bs={batch_size}")

    agent_tune = DDQNAgent(
        state_dim=state_dim,
        action_dim=action_dim,
        gamma=gamma,
        lr=lr,
        batch_size=batch_size,
        memory_size=50_000,
        target_update=200,
        epsilon_start=1.0,
        epsilon_end=0.05,
        epsilon_decay=epsilon_decay,
    )

    episodes_tune = 200
    max_steps_tune = 500
    best_tune_gmean = 0.0
    best_tune_state_dict = None
    patience_counter = 0

    for ep in range(1, episodes_tune + 1):
        start_idx = np.random.randint(0, len(train_feature) - max_steps_tune - 1)
        episode_reward = 0.0

        for i in range(max_steps_tune):
            state = train_feature[start_idx + i]
            next_state = train_feature[start_idx + i + 1] if start_idx + i + 1 < len(train_feature) else train_feature[start_idx + i]
            actual_label = train_label[start_idx + i]

            action = agent_tune.act(state)
            reward = compute_reward(action, actual_label, class_ratio)
            done = i == (max_steps_tune - 1)

            agent_tune.memory.push(state, action, reward, next_state, done)
            _ = agent_tune.update()
            episode_reward += reward

        agent_tune.decay_epsilon()

        if ep % 5 == 0:
            agent_tune.online_net.eval()
            tune_gmean, tune_sensitivity, tune_specificity = evaluate_argmax(
                agent_tune.online_net, valid_tune_feature, valid_tune_label
            )
            agent_tune.online_net.train()

            if tune_gmean > best_tune_gmean:
                best_tune_gmean = tune_gmean
                patience_counter = 0
                best_tune_state_dict = {k: v.detach().cpu().clone() for k, v in agent_tune.online_net.state_dict().items()}
            else:
                patience_counter += 1

            if ep % 20 == 0:
                print(f"  Ep {ep:3d} | Tune G-mean: {tune_gmean:.4f} (Sens: {tune_sensitivity:.4f}, Spec: {tune_specificity:.4f}) | Best: {best_tune_gmean:.4f}")

            if ep > min_episodes and patience_counter >= patience:
                break

    agent_tune.online_net.eval()
    if best_tune_state_dict is not None:
        agent_tune.online_net.load_state_dict(best_tune_state_dict)
    select_gmean, select_sensitivity, select_specificity = evaluate_argmax(
        agent_tune.online_net, valid_select_feature, valid_select_label
    )

    grid_search_results.append({
        'params': param_dict,
        'best_tune_gmean': best_tune_gmean,
        'select_gmean': select_gmean,
        'select_sensitivity': select_sensitivity,
        'select_specificity': select_specificity,
    })

    if select_gmean > best_overall_select_gmean:
        best_overall_select_gmean = select_gmean
        best_overall_params = param_dict

grid_search_results.sort(key=lambda x: x['select_gmean'], reverse=True)

print("\n" + "=" * 80)
print("TOP 5 HYPERPARAMETERS")
print("=" * 80)
for i, result in enumerate(grid_search_results[:5]):
    print(f"{i+1}. Select G-mean: {result['select_gmean']:.4f} | Tune Best: {result['best_tune_gmean']:.4f} | Params: {result['params']}")

print("\n" + "=" * 80)
print("BEST HYPERPARAMETERS")
print("=" * 80)
for k, v in best_overall_params.items():
    print(f"{k}: {v}")
print(f"Best Selection G-mean: {best_overall_select_gmean:.4f}")
print("=" * 80)

# ---- 최적 파라미터로 본 학습 ----
print("\nTraining with best hyperparameters...")
agent = DDQNAgent(
    state_dim=state_dim,
    action_dim=action_dim,
    gamma=best_overall_params['gamma'],
    lr=best_overall_params['lr'],
    batch_size=best_overall_params['batch_size'],
    memory_size=50_000,
    target_update=200,
    epsilon_start=1.0,
    epsilon_end=0.05,
    epsilon_decay=best_overall_params['epsilon_decay'],
)

episodes = 600
max_steps = 500
scores = []
valid_scores = []
best_ckpt_valid_gmean = -1.0
best_ckpt_epoch = 0
best_ckpt_state_dict = None

for ep in range(1, episodes + 1):
    episode_reward = 0.0
    start_idx = np.random.randint(0, len(train_feature) - max_steps - 1)

    for i in range(max_steps):
        state = train_feature[start_idx + i]
        next_state = train_feature[start_idx + i + 1] if start_idx + i + 1 < len(train_feature) else train_feature[start_idx + i]
        actual_label = train_label[start_idx + i]

        action = agent.act(state)
        reward = compute_reward(action, actual_label, class_ratio)
        done = i == (max_steps - 1)

        agent.memory.push(state, action, reward, next_state, done)
        _ = agent.update()
        episode_reward += reward

    agent.decay_epsilon()
    scores.append(episode_reward)

    if ep % 10 == 0:
        agent.online_net.eval()
        valid_gmean, valid_sensitivity, valid_specificity = evaluate_argmax(
            agent.online_net, valid_select_feature, valid_select_label
        )
        valid_scores.append(valid_gmean)

        if valid_gmean > best_ckpt_valid_gmean:
            best_ckpt_valid_gmean = valid_gmean
            best_ckpt_epoch = ep
            best_ckpt_state_dict = {k: v.detach().cpu().clone() for k, v in agent.online_net.state_dict().items()}
        agent.online_net.train()

        print(f"Episode {ep:3d} | Train Reward: {np.mean(scores[-10:]):8.5f} | Valid G-mean: {valid_gmean:.4f} (Sens: {valid_sensitivity:.4f}, Spec: {valid_specificity:.4f}) | Best G: {best_ckpt_valid_gmean:.4f}")

print("최종 학습 완료")
if best_ckpt_state_dict is not None:
    agent.online_net.load_state_dict(best_ckpt_state_dict)
    agent.target_net.load_state_dict(best_ckpt_state_dict)
    print(f"Best checkpoint restored: epoch={best_ckpt_epoch}, valid_gmean={best_ckpt_valid_gmean:.4f}")

agent.online_net.eval()

# ---- Test 평가 ----
test_predictions = predict_labels_argmax(agent.online_net, test_feature)

cm_test = confusion_matrix(test_label, test_predictions, labels=[0, 1])
tn, fp, fn, tp = cm_test.ravel()
sensitivity_test = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity_test = tn / (tn + fp) if (tn + fp) > 0 else 0
gmean_test = np.sqrt(sensitivity_test * specificity_test)

print("\n" + "=" * 60)
print("TEST SET - DDQN 분류 모델 최종 성능 평가")
print("=" * 60)
print(f"\nG-mean: {gmean_test:.4f}")
print(f"\nConfusion Matrix:")
print(cm_test)
print(f"\nTN: {cm_test[0, 0]}, FP: {cm_test[0, 1]}")
print(f"FN: {cm_test[1, 0]}, TP: {cm_test[1, 1]}")

print(f"\n분류 리포트:")
print(classification_report(test_label, test_predictions,
                          labels=[0, 1],
                          target_names=['Class 0 (Negative)', 'Class 1 (Positive)'],
                          zero_division=0))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax1 = axes[0]
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Blues', cbar=False, ax=ax1,
            xticklabels=['Pred 0', 'Pred 1'],
            yticklabels=['Actual 0', 'Actual 1'])
ax1.set_title('Test Set - Confusion Matrix (Count)', fontsize=12, fontweight='bold')
ax1.set_ylabel('True Label')
ax1.set_xlabel('Predicted Label')

cm_test_row_sums = cm_test.sum(axis=1, keepdims=True)
cm_test_percent = np.divide(cm_test.astype(float), cm_test_row_sums,
                             out=np.zeros_like(cm_test, dtype=float),
                             where=cm_test_row_sums != 0) * 100
ax2 = axes[1]
sns.heatmap(cm_test_percent, annot=True, fmt='.2f', cmap='Blues', cbar=True, ax=ax2,
            xticklabels=['Pred 0', 'Pred 1'],
            yticklabels=['Actual 0', 'Actual 1'],
            cbar_kws={'label': 'Percentage (%)'})
ax2.set_title('Test Set - Confusion Matrix (Percentage)', fontsize=12, fontweight='bold')
ax2.set_ylabel('True Label')
ax2.set_xlabel('Predicted Label')

plt.tight_layout()
plt.show()

precision = tp / (tp + fp) if (tp + fp) > 0 else 0
f1_score_val = 2 * (precision * sensitivity_test) / (precision + sensitivity_test) if (precision + sensitivity_test) > 0 else 0

print(f"\n상세 메트릭 (Test Set):")
print(f"Sensitivity (Recall for Class 1): {sensitivity_test:.4f}")
print(f"Specificity (Recall for Class 0): {specificity_test:.4f}")
print(f"Precision (Class 1): {precision:.4f}")
print(f"F1-Score: {f1_score_val:.4f}")
print("=" * 60)

print("\n" + "=" * 60)
print("VALIDATION SET vs TEST SET 성능 비교")
print("=" * 60)

agent.online_net.eval()
valid_predictions = predict_labels_argmax(agent.online_net, valid_select_feature)
cm_valid = confusion_matrix(valid_select_label, valid_predictions, labels=[0, 1])
tn_v, fp_v, fn_v, tp_v = cm_valid.ravel()
sensitivity_valid = tp_v / (tp_v + fn_v) if (tp_v + fn_v) > 0 else 0
specificity_valid = tn_v / (tn_v + fp_v) if (tn_v + fp_v) > 0 else 0
gmean_valid = np.sqrt(sensitivity_valid * specificity_valid)

print(f"\nValidation(Selection) Set - G-mean: {gmean_valid:.4f}")
print(f"Test Set - G-mean: {gmean_test:.4f}")
print(f"Difference (Valid - Test): {gmean_valid - gmean_test:.4f}")
print("\nValidation Confusion Matrix:")
print(cm_valid)
print("\nTest Confusion Matrix:")
print(cm_test)
print("=" * 60)
# Out:
# ================================================================================
# HYPERPARAMETER GRID SEARCH (Total: 16 combinations)
# ================================================================================
#
# [1/16] gamma=0.90, lr=1e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6408 (Sens: 0.5789, Spec: 0.7093) | Best: 0.6578
#   Ep  40 | Tune G-mean: 0.6500 (Sens: 0.6053, Spec: 0.6981) | Best: 0.6620
#   Ep  60 | Tune G-mean: 0.6597 (Sens: 0.6184, Spec: 0.7037) | Best: 0.6620
#   Ep  80 | Tune G-mean: 0.5989 (Sens: 0.4342, Spec: 0.8259) | Best: 0.6620
#   Ep 100 | Tune G-mean: 0.5941 (Sens: 0.4342, Spec: 0.8130) | Best: 0.6796
#   Ep 120 | Tune G-mean: 0.5670 (Sens: 0.3816, Spec: 0.8426) | Best: 0.6796
#   Ep 140 | Tune G-mean: 0.5765 (Sens: 0.4079, Spec: 0.8148) | Best: 0.6796
#   Ep 160 | Tune G-mean: 0.5811 (Sens: 0.4342, Spec: 0.7778) | Best: 0.6796
#   Ep 180 | Tune G-mean: 0.6154 (Sens: 0.5000, Spec: 0.7574) | Best: 0.6796
#   Ep 200 | Tune G-mean: 0.5804 (Sens: 0.4605, Spec: 0.7315) | Best: 0.6796
#
# [2/16] gamma=0.90, lr=1e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5804 (Sens: 0.4079, Spec: 0.8259) | Best: 0.6716
#   Ep  40 | Tune G-mean: 0.5900 (Sens: 0.5000, Spec: 0.6963) | Best: 0.6716
#   Ep  60 | Tune G-mean: 0.5600 (Sens: 0.3947, Spec: 0.7944) | Best: 0.6716
#   Ep  80 | Tune G-mean: 0.5507 (Sens: 0.4474, Spec: 0.6778) | Best: 0.6716
#   Ep 100 | Tune G-mean: 0.5301 (Sens: 0.4079, Spec: 0.6889) | Best: 0.6716
#   Ep 120 | Tune G-mean: 0.5290 (Sens: 0.4342, Spec: 0.6444) | Best: 0.6716
#
# [3/16] gamma=0.90, lr=1e-04, eps_decay=0.999, bs=32
#   Ep  20 | Tune G-mean: 0.6592 (Sens: 0.6842, Spec: 0.6352) | Best: 0.6592
#   Ep  40 | Tune G-mean: 0.6459 (Sens: 0.6974, Spec: 0.5981) | Best: 0.6638
#   Ep  60 | Tune G-mean: 0.6458 (Sens: 0.5789, Spec: 0.7204) | Best: 0.6638
#   Ep  80 | Tune G-mean: 0.6051 (Sens: 0.4474, Spec: 0.8185) | Best: 0.6638
#   Ep 100 | Tune G-mean: 0.6623 (Sens: 0.5921, Spec: 0.7407) | Best: 0.6638
#   Ep 120 | Tune G-mean: 0.6098 (Sens: 0.4605, Spec: 0.8074) | Best: 0.6638
#   Ep 140 | Tune G-mean: 0.5948 (Sens: 0.4474, Spec: 0.7907) | Best: 0.6638
#
# [4/16] gamma=0.90, lr=1e-04, eps_decay=0.999, bs=64
#   Ep  20 | Tune G-mean: 0.6150 (Sens: 0.5263, Spec: 0.7185) | Best: 0.6293
#   Ep  40 | Tune G-mean: 0.6282 (Sens: 0.5395, Spec: 0.7315) | Best: 0.6321
#   Ep  60 | Tune G-mean: 0.5899 (Sens: 0.4474, Spec: 0.7778) | Best: 0.6321
#   Ep  80 | Tune G-mean: 0.5992 (Sens: 0.4605, Spec: 0.7796) | Best: 0.6321
#   Ep 100 | Tune G-mean: 0.5613 (Sens: 0.3947, Spec: 0.7981) | Best: 0.6321
#   Ep 120 | Tune G-mean: 0.5864 (Sens: 0.4737, Spec: 0.7259) | Best: 0.6321
#   Ep 140 | Tune G-mean: 0.5678 (Sens: 0.4605, Spec: 0.7000) | Best: 0.6321
#
# [5/16] gamma=0.90, lr=1e-03, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.4704 (Sens: 0.2500, Spec: 0.8852) | Best: 0.5745
#   Ep  40 | Tune G-mean: 0.6266 (Sens: 0.5395, Spec: 0.7278) | Best: 0.6266
#   Ep  60 | Tune G-mean: 0.5141 (Sens: 0.3158, Spec: 0.8370) | Best: 0.6266
#   Ep  80 | Tune G-mean: 0.5589 (Sens: 0.3816, Spec: 0.8185) | Best: 0.6266
#   Ep 100 | Tune G-mean: 0.5512 (Sens: 0.3816, Spec: 0.7963) | Best: 0.6266
#   Ep 120 | Tune G-mean: 0.5873 (Sens: 0.4342, Spec: 0.7944) | Best: 0.6266
#   Ep 140 | Tune G-mean: 0.5832 (Sens: 0.4342, Spec: 0.7833) | Best: 0.6266
#   Ep 160 | Tune G-mean: 0.5567 (Sens: 0.3947, Spec: 0.7852) | Best: 0.6266
#
# [6/16] gamma=0.90, lr=1e-03, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5207 (Sens: 0.3289, Spec: 0.8241) | Best: 0.6567
#   Ep  40 | Tune G-mean: 0.5044 (Sens: 0.3158, Spec: 0.8056) | Best: 0.6567
#   Ep  60 | Tune G-mean: 0.5579 (Sens: 0.4079, Spec: 0.7630) | Best: 0.6567
#   Ep  80 | Tune G-mean: 0.5602 (Sens: 0.4605, Spec: 0.6815) | Best: 0.6567
#   Ep 100 | Tune G-mean: 0.5869 (Sens: 0.4868, Spec: 0.7074) | Best: 0.6567
#   Ep 120 | Tune G-mean: 0.5804 (Sens: 0.4737, Spec: 0.7111) | Best: 0.6567
#
# [7/16] gamma=0.90, lr=1e-03, eps_decay=0.999, bs=32
#   Ep  20 | Tune G-mean: 0.5901 (Sens: 0.4079, Spec: 0.8537) | Best: 0.6356
#   Ep  40 | Tune G-mean: 0.5679 (Sens: 0.4079, Spec: 0.7907) | Best: 0.6449
#   Ep  60 | Tune G-mean: 0.5843 (Sens: 0.4079, Spec: 0.8370) | Best: 0.6449
#   Ep  80 | Tune G-mean: 0.6194 (Sens: 0.5395, Spec: 0.7111) | Best: 0.6449
#   Ep 100 | Tune G-mean: 0.5791 (Sens: 0.4342, Spec: 0.7722) | Best: 0.6449
#   Ep 120 | Tune G-mean: 0.5343 (Sens: 0.3816, Spec: 0.7481) | Best: 0.6449
#   Ep 140 | Tune G-mean: 0.5665 (Sens: 0.3947, Spec: 0.8130) | Best: 0.6449
#
# [8/16] gamma=0.90, lr=1e-03, eps_decay=0.999, bs=64
#   Ep  20 | Tune G-mean: 0.5299 (Sens: 0.3289, Spec: 0.8537) | Best: 0.6086
#   Ep  40 | Tune G-mean: 0.5721 (Sens: 0.4868, Spec: 0.6722) | Best: 0.6086
#   Ep  60 | Tune G-mean: 0.5391 (Sens: 0.3684, Spec: 0.7889) | Best: 0.6086
#   Ep  80 | Tune G-mean: 0.5450 (Sens: 0.4211, Spec: 0.7056) | Best: 0.6086
#   Ep 100 | Tune G-mean: 0.5635 (Sens: 0.4737, Spec: 0.6704) | Best: 0.6086
#   Ep 120 | Tune G-mean: 0.5853 (Sens: 0.4868, Spec: 0.7037) | Best: 0.6086
#
# [9/16] gamma=0.99, lr=1e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6633 (Sens: 0.6711, Spec: 0.6556) | Best: 0.6647
#   Ep  40 | Tune G-mean: 0.6318 (Sens: 0.5132, Spec: 0.7778) | Best: 0.6647
#   Ep  60 | Tune G-mean: 0.6306 (Sens: 0.5395, Spec: 0.7370) | Best: 0.6709
#   Ep  80 | Tune G-mean: 0.5535 (Sens: 0.3684, Spec: 0.8315) | Best: 0.6709
#   Ep 100 | Tune G-mean: 0.5668 (Sens: 0.4211, Spec: 0.7630) | Best: 0.6709
#   Ep 120 | Tune G-mean: 0.6421 (Sens: 0.6184, Spec: 0.6667) | Best: 0.6709
#   Ep 140 | Tune G-mean: 0.6379 (Sens: 0.6053, Spec: 0.6722) | Best: 0.6709
#   Ep 160 | Tune G-mean: 0.5572 (Sens: 0.3684, Spec: 0.8426) | Best: 0.6709
#
# [10/16] gamma=0.99, lr=1e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.6146 (Sens: 0.4868, Spec: 0.7759) | Best: 0.6514
#   Ep  40 | Tune G-mean: 0.6025 (Sens: 0.5000, Spec: 0.7259) | Best: 0.6514
#   Ep  60 | Tune G-mean: 0.6245 (Sens: 0.6053, Spec: 0.6444) | Best: 0.6514
#   Ep  80 | Tune G-mean: 0.5519 (Sens: 0.3816, Spec: 0.7981) | Best: 0.6514
#   Ep 100 | Tune G-mean: 0.5428 (Sens: 0.3816, Spec: 0.7722) | Best: 0.6514
#   Ep 120 | Tune G-mean: 0.4920 (Sens: 0.2763, Spec: 0.8759) | Best: 0.6514
#
# [11/16] gamma=0.99, lr=1e-04, eps_decay=0.999, bs=32
#   Ep  20 | Tune G-mean: 0.5990 (Sens: 0.4737, Spec: 0.7574) | Best: 0.6480
#   Ep  40 | Tune G-mean: 0.6035 (Sens: 0.4868, Spec: 0.7481) | Best: 0.6480
#   Ep  60 | Tune G-mean: 0.5862 (Sens: 0.5395, Spec: 0.6370) | Best: 0.6480
#   Ep  80 | Tune G-mean: 0.6117 (Sens: 0.5789, Spec: 0.6463) | Best: 0.6480
#   Ep 100 | Tune G-mean: 0.5745 (Sens: 0.4605, Spec: 0.7167) | Best: 0.6480
#   Ep 120 | Tune G-mean: 0.5975 (Sens: 0.4737, Spec: 0.7537) | Best: 0.6480
#   Ep 140 | Tune G-mean: 0.5968 (Sens: 0.4737, Spec: 0.7519) | Best: 0.6480
#
# [12/16] gamma=0.99, lr=1e-04, eps_decay=0.999, bs=64
#   Ep  20 | Tune G-mean: 0.6368 (Sens: 0.5263, Spec: 0.7704) | Best: 0.6612
#   Ep  40 | Tune G-mean: 0.6404 (Sens: 0.6711, Spec: 0.6111) | Best: 0.6612
#   Ep  60 | Tune G-mean: 0.6381 (Sens: 0.6447, Spec: 0.6315) | Best: 0.6612
#   Ep  80 | Tune G-mean: 0.5846 (Sens: 0.4342, Spec: 0.7870) | Best: 0.6612
#   Ep 100 | Tune G-mean: 0.5934 (Sens: 0.4474, Spec: 0.7870) | Best: 0.6612
#   Ep 120 | Tune G-mean: 0.6096 (Sens: 0.5132, Spec: 0.7241) | Best: 0.6612
#   Ep 140 | Tune G-mean: 0.6298 (Sens: 0.5789, Spec: 0.6852) | Best: 0.6612
#
# [13/16] gamma=0.99, lr=1e-03, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6200 (Sens: 0.6447, Spec: 0.5963) | Best: 0.6562
#   Ep  40 | Tune G-mean: 0.6181 (Sens: 0.5263, Spec: 0.7259) | Best: 0.6562
#   Ep  60 | Tune G-mean: 0.5948 (Sens: 0.4474, Spec: 0.7907) | Best: 0.6562
#   Ep  80 | Tune G-mean: 0.5894 (Sens: 0.6974, Spec: 0.4981) | Best: 0.6562
#   Ep 100 | Tune G-mean: 0.5691 (Sens: 0.3947, Spec: 0.8204) | Best: 0.6562
#   Ep 120 | Tune G-mean: 0.5658 (Sens: 0.3816, Spec: 0.8389) | Best: 0.6562
#
# [14/16] gamma=0.99, lr=1e-03, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.6540 (Sens: 0.5526, Spec: 0.7741) | Best: 0.6614
#   Ep  40 | Tune G-mean: 0.5728 (Sens: 0.4737, Spec: 0.6926) | Best: 0.6614
#   Ep  60 | Tune G-mean: 0.5599 (Sens: 0.4079, Spec: 0.7685) | Best: 0.6614
#   Ep  80 | Tune G-mean: 0.5455 (Sens: 0.4079, Spec: 0.7296) | Best: 0.6614
#   Ep 100 | Tune G-mean: 0.5742 (Sens: 0.4342, Spec: 0.7593) | Best: 0.6614
#   Ep 120 | Tune G-mean: 0.5766 (Sens: 0.4737, Spec: 0.7019) | Best: 0.6614
#   Ep 140 | Tune G-mean: 0.5982 (Sens: 0.4474, Spec: 0.8000) | Best: 0.6614
#
# [15/16] gamma=0.99, lr=1e-03, eps_decay=0.999, bs=32
#   Ep  20 | Tune G-mean: 0.5785 (Sens: 0.4474, Spec: 0.7481) | Best: 0.6331
#   Ep  40 | Tune G-mean: 0.6267 (Sens: 0.5263, Spec: 0.7463) | Best: 0.6532
#   Ep  60 | Tune G-mean: 0.6325 (Sens: 0.5132, Spec: 0.7796) | Best: 0.6532
#   Ep  80 | Tune G-mean: 0.5703 (Sens: 0.3947, Spec: 0.8241) | Best: 0.6532
#   Ep 100 | Tune G-mean: 0.5148 (Sens: 0.3289, Spec: 0.8056) | Best: 0.6532
#   Ep 120 | Tune G-mean: 0.5825 (Sens: 0.4342, Spec: 0.7815) | Best: 0.6532
#   Ep 140 | Tune G-mean: 0.5531 (Sens: 0.3816, Spec: 0.8019) | Best: 0.6532
#   Ep 160 | Tune G-mean: 0.5757 (Sens: 0.4211, Spec: 0.7870) | Best: 0.6532
#
# [16/16] gamma=0.99, lr=1e-03, eps_decay=0.999, bs=64
#   Ep  20 | Tune G-mean: 0.6267 (Sens: 0.5263, Spec: 0.7463) | Best: 0.6291
#   Ep  40 | Tune G-mean: 0.6126 (Sens: 0.5263, Spec: 0.7130) | Best: 0.6314
#   Ep  60 | Tune G-mean: 0.6048 (Sens: 0.5000, Spec: 0.7315) | Best: 0.6342
#   Ep  80 | Tune G-mean: 0.6049 (Sens: 0.4605, Spec: 0.7944) | Best: 0.6342
#   Ep 100 | Tune G-mean: 0.5837 (Sens: 0.5395, Spec: 0.6315) | Best: 0.6342
#   Ep 120 | Tune G-mean: 0.6107 (Sens: 0.5658, Spec: 0.6593) | Best: 0.6342
#   Ep 140 | Tune G-mean: 0.6035 (Sens: 0.4605, Spec: 0.7907) | Best: 0.6342
#   Ep 160 | Tune G-mean: 0.5791 (Sens: 0.4342, Spec: 0.7722) | Best: 0.6369
#   Ep 180 | Tune G-mean: 0.5729 (Sens: 0.4868, Spec: 0.6741) | Best: 0.6369
#   Ep 200 | Tune G-mean: 0.6127 (Sens: 0.5132, Spec: 0.7315) | Best: 0.6369
#
# ================================================================================
# TOP 5 HYPERPARAMETERS
# ================================================================================
# 1. Select G-mean: 0.6808 | Tune Best: 0.6321 | Params: {'gamma': 0.9, 'lr': 0.0001, 'epsilon_decay': 0.999, 'batch_size': 64}
# 2. Select G-mean: 0.6581 | Tune Best: 0.6514 | Params: {'gamma': 0.99, 'lr': 0.0001, 'epsilon_decay': 0.99, 'batch_size': 64}
# 3. Select G-mean: 0.6398 | Tune Best: 0.6449 | Params: {'gamma': 0.9, 'lr': 0.001, 'epsilon_decay': 0.999, 'batch_size': 32}
# 4. Select G-mean: 0.6375 | Tune Best: 0.6086 | Params: {'gamma': 0.9, 'lr': 0.001, 'epsilon_decay': 0.999, 'batch_size': 64}
# 5. Select G-mean: 0.6323 | Tune Best: 0.6480 | Params: {'gamma': 0.99, 'lr': 0.0001, 'epsilon_decay': 0.999, 'batch_size': 32}
#
# ================================================================================
# BEST HYPERPARAMETERS
# ================================================================================
# gamma: 0.9
# lr: 0.0001
# epsilon_decay: 0.999
# batch_size: 64
# Best Selection G-mean: 0.6808
# ================================================================================
#
# Training with best hyperparameters...
# Episode  10 | Train Reward: -1.59944 | Valid G-mean: 0.6391 (Sens: 0.8140, Spec: 0.5019) | Best G: 0.6391
# Episode  20 | Train Reward:  2.23678 | Valid G-mean: 0.6297 (Sens: 0.8372, Spec: 0.4736) | Best G: 0.6391
# Episode  30 | Train Reward:  1.07643 | Valid G-mean: 0.6616 (Sens: 0.8140, Spec: 0.5377) | Best G: 0.6616
# Episode  40 | Train Reward:  2.85962 | Valid G-mean: 0.6405 (Sens: 0.5814, Spec: 0.7057) | Best G: 0.6616
# Episode  50 | Train Reward:  6.19888 | Valid G-mean: 0.6674 (Sens: 0.7791, Spec: 0.5717) | Best G: 0.6674
# Episode  60 | Train Reward:  2.11308 | Valid G-mean: 0.6674 (Sens: 0.7791, Spec: 0.5717) | Best G: 0.6674
# Episode  70 | Train Reward:  2.30189 | Valid G-mean: 0.6580 (Sens: 0.8023, Spec: 0.5396) | Best G: 0.6674
# Episode  80 | Train Reward:  2.43066 | Valid G-mean: 0.6567 (Sens: 0.7209, Spec: 0.5981) | Best G: 0.6674
# Episode  90 | Train Reward:  4.54154 | Valid G-mean: 0.6424 (Sens: 0.7674, Spec: 0.5377) | Best G: 0.6674
# Episode 100 | Train Reward:  5.04143 | Valid G-mean: 0.6515 (Sens: 0.7209, Spec: 0.5887) | Best G: 0.6674
# Episode 110 | Train Reward:  5.91892 | Valid G-mean: 0.6288 (Sens: 0.7907, Spec: 0.5000) | Best G: 0.6674
# Episode 120 | Train Reward:  5.17238 | Valid G-mean: 0.6768 (Sens: 0.6744, Spec: 0.6792) | Best G: 0.6768
# Episode 130 | Train Reward:  9.21839 | Valid G-mean: 0.6389 (Sens: 0.7093, Spec: 0.5755) | Best G: 0.6768
# Episode 140 | Train Reward:  6.31101 | Valid G-mean: 0.6094 (Sens: 0.7209, Spec: 0.5151) | Best G: 0.6768
# Episode 150 | Train Reward:  9.71465 | Valid G-mean: 0.6731 (Sens: 0.6860, Spec: 0.6604) | Best G: 0.6768
# Episode 160 | Train Reward:  8.62881 | Valid G-mean: 0.6591 (Sens: 0.6977, Spec: 0.6226) | Best G: 0.6768
# Episode 170 | Train Reward:  7.62402 | Valid G-mean: 0.6700 (Sens: 0.6977, Spec: 0.6434) | Best G: 0.6768
# Episode 180 | Train Reward: 11.93696 | Valid G-mean: 0.6521 (Sens: 0.6977, Spec: 0.6094) | Best G: 0.6768
# Episode 190 | Train Reward:  9.58881 | Valid G-mean: 0.6329 (Sens: 0.5930, Spec: 0.6755) | Best G: 0.6768
# Episode 200 | Train Reward:  8.09497 | Valid G-mean: 0.6419 (Sens: 0.6977, Spec: 0.5906) | Best G: 0.6768
# Episode 210 | Train Reward:  7.62185 | Valid G-mean: 0.6241 (Sens: 0.6163, Spec: 0.6321) | Best G: 0.6768
# Episode 220 | Train Reward: 11.48629 | Valid G-mean: 0.6182 (Sens: 0.7209, Spec: 0.5302) | Best G: 0.6768
# Episode 230 | Train Reward:  9.91360 | Valid G-mean: 0.6260 (Sens: 0.6163, Spec: 0.6358) | Best G: 0.6768
# Episode 240 | Train Reward: 14.89280 | Valid G-mean: 0.6284 (Sens: 0.6977, Spec: 0.5660) | Best G: 0.6768
# Episode 250 | Train Reward: 12.48822 | Valid G-mean: 0.6311 (Sens: 0.5930, Spec: 0.6717) | Best G: 0.6768
# Episode 260 | Train Reward: 14.99769 | Valid G-mean: 0.6028 (Sens: 0.6977, Spec: 0.5208) | Best G: 0.6768
# Episode 270 | Train Reward: 15.41944 | Valid G-mean: 0.6281 (Sens: 0.6279, Spec: 0.6283) | Best G: 0.6768
# Episode 280 | Train Reward: 16.42934 | Valid G-mean: 0.6126 (Sens: 0.6395, Spec: 0.5868) | Best G: 0.6768
# Episode 290 | Train Reward: 14.99049 | Valid G-mean: 0.6375 (Sens: 0.7326, Spec: 0.5547) | Best G: 0.6768
# Episode 300 | Train Reward: 14.32497 | Valid G-mean: 0.6157 (Sens: 0.5581, Spec: 0.6792) | Best G: 0.6768
# Episode 310 | Train Reward: 19.27881 | Valid G-mean: 0.6052 (Sens: 0.7326, Spec: 0.5000) | Best G: 0.6768
# Episode 320 | Train Reward: 15.39416 | Valid G-mean: 0.5980 (Sens: 0.6744, Spec: 0.5302) | Best G: 0.6768
# Episode 330 | Train Reward: 15.29434 | Valid G-mean: 0.5873 (Sens: 0.6977, Spec: 0.4943) | Best G: 0.6768
# Episode 340 | Train Reward: 18.77245 | Valid G-mean: 0.6213 (Sens: 0.6163, Spec: 0.6264) | Best G: 0.6768
# Episode 350 | Train Reward: 23.01594 | Valid G-mean: 0.6187 (Sens: 0.5814, Spec: 0.6585) | Best G: 0.6768
# Episode 360 | Train Reward: 29.07591 | Valid G-mean: 0.6166 (Sens: 0.6163, Spec: 0.6170) | Best G: 0.6768
# Episode 370 | Train Reward: 22.85752 | Valid G-mean: 0.5877 (Sens: 0.6163, Spec: 0.5604) | Best G: 0.6768
# Episode 380 | Train Reward: 22.23035 | Valid G-mean: 0.5821 (Sens: 0.6279, Spec: 0.5396) | Best G: 0.6768
# Episode 390 | Train Reward: 19.90531 | Valid G-mean: 0.6109 (Sens: 0.6163, Spec: 0.6057) | Best G: 0.6768
# Episode 400 | Train Reward: 21.15175 | Valid G-mean: 0.6014 (Sens: 0.6163, Spec: 0.5868) | Best G: 0.6768
# Episode 410 | Train Reward: 24.21825 | Valid G-mean: 0.6012 (Sens: 0.6628, Spec: 0.5453) | Best G: 0.6768
# Episode 420 | Train Reward: 26.26913 | Valid G-mean: 0.6136 (Sens: 0.6047, Spec: 0.6226) | Best G: 0.6768
# Episode 430 | Train Reward: 21.78402 | Valid G-mean: 0.6168 (Sens: 0.6744, Spec: 0.5642) | Best G: 0.6768
# Episode 440 | Train Reward: 29.48972 | Valid G-mean: 0.6062 (Sens: 0.6163, Spec: 0.5962) | Best G: 0.6768
# Episode 450 | Train Reward: 27.80780 | Valid G-mean: 0.6089 (Sens: 0.6047, Spec: 0.6132) | Best G: 0.6768
# Episode 460 | Train Reward: 26.73357 | Valid G-mean: 0.6285 (Sens: 0.5930, Spec: 0.6660) | Best G: 0.6768
# Episode 470 | Train Reward: 24.46497 | Valid G-mean: 0.6113 (Sens: 0.5930, Spec: 0.6302) | Best G: 0.6768
# Episode 480 | Train Reward: 28.82923 | Valid G-mean: 0.5877 (Sens: 0.6163, Spec: 0.5604) | Best G: 0.6768
# Episode 490 | Train Reward: 25.38444 | Valid G-mean: 0.5946 (Sens: 0.6395, Spec: 0.5528) | Best G: 0.6768
# Episode 500 | Train Reward: 28.70196 | Valid G-mean: 0.6267 (Sens: 0.5814, Spec: 0.6755) | Best G: 0.6768
# Episode 510 | Train Reward: 30.16178 | Valid G-mean: 0.5997 (Sens: 0.6395, Spec: 0.5623) | Best G: 0.6768
# Episode 520 | Train Reward: 32.41157 | Valid G-mean: 0.5928 (Sens: 0.6047, Spec: 0.5811) | Best G: 0.6768
# Episode 530 | Train Reward: 28.52619 | Valid G-mean: 0.5854 (Sens: 0.6395, Spec: 0.5358) | Best G: 0.6768
# Episode 540 | Train Reward: 32.12294 | Valid G-mean: 0.6201 (Sens: 0.6047, Spec: 0.6358) | Best G: 0.6768
# Episode 550 | Train Reward: 28.97976 | Valid G-mean: 0.6067 (Sens: 0.6395, Spec: 0.5755) | Best G: 0.6768
# Episode 560 | Train Reward: 33.21021 | Valid G-mean: 0.5957 (Sens: 0.6047, Spec: 0.5868) | Best G: 0.6768
# Episode 570 | Train Reward: 27.38538 | Valid G-mean: 0.5569 (Sens: 0.6395, Spec: 0.4849) | Best G: 0.6768
# Episode 580 | Train Reward: 27.50692 | Valid G-mean: 0.6004 (Sens: 0.6163, Spec: 0.5849) | Best G: 0.6768
# Episode 590 | Train Reward: 29.67133 | Valid G-mean: 0.6098 (Sens: 0.5814, Spec: 0.6396) | Best G: 0.6768
# Episode 600 | Train Reward: 29.09119 | Valid G-mean: 0.6037 (Sens: 0.6395, Spec: 0.5698) | Best G: 0.6768
# 최종 학습 완료
# Best checkpoint restored: epoch=120, valid_gmean=0.6768
#
# ============================================================
# TEST SET - DDQN 분류 모델 최종 성능 평가
# ============================================================
#
# G-mean: 0.6207
#
# Confusion Matrix:
# [[528 202]
#  [ 43  49]]
#
# TN: 528, FP: 202
# FN: 43, TP: 49
#
# 분류 리포트:
#                     precision    recall  f1-score   support
#
# Class 0 (Negative)       0.92      0.72      0.81       730
# Class 1 (Positive)       0.20      0.53      0.29        92
#
#           accuracy                           0.70       822
#          macro avg       0.56      0.63      0.55       822
#       weighted avg       0.84      0.70      0.75       822
# 상세 메트릭 (Test Set):
# Sensitivity (Recall for Class 1): 0.5326
# Specificity (Recall for Class 0): 0.7233
# Precision (Class 1): 0.1952
# F1-Score: 0.2857
# ============================================================
#
# ============================================================
# VALIDATION SET vs TEST SET 성능 비교
# ============================================================
#
# Validation(Selection) Set - G-mean: 0.6768
# Test Set - G-mean: 0.6207
# Difference (Valid - Test): 0.0562
#
# Validation Confusion Matrix:
# [[360 170]
#  [ 28  58]]
#
# Test Confusion Matrix:
# [[528 202]
#  [ 43  49]]
# ============================================================
