# %%
# 랜덤성 제어를 위한 표준 라이브러리 모듈을 불러옵니다.
import random
from collections import deque
from pathlib import Path
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import MinMaxScaler


# 데이터셋을 불러옵니다.
dat = pd.read_csv(Path("../../data/processed/data_selected.csv"), index_col=0)

# 재현 가능한 실험을 위해 시드 값을 고정합니다.
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# GPU가 있으면 CUDA를, 없으면 CPU를 사용하도록 장치를 설정합니다.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# DDQN에서 사용할 Q-Network 구조를 정의합니다.
# 데이터 수가 많지 않으므로 과적합 가능성을 염두에 두고 2개 은닉층을 사용합니다.
class QNetwork(nn.Module):
    def __init__(self, state_dim: int, action_dim: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 96),
            nn.ReLU(),
            nn.Linear(96, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim),
        )

    def forward(self, x):
        return self.net(x)                       # (batch, 2)

# 경험을 저장하고 무작위 샘플링하기 위한 리플레이 버퍼를 정의합니다.
class ReplayBuffer:
    def __init__(self, capacity: int):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size: int):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = map(np.array, zip(*batch))
        return (
            torch.FloatTensor(states).to(device),
            torch.LongTensor(actions).unsqueeze(1).to(device),
            torch.FloatTensor(rewards).unsqueeze(1).to(device),
            torch.FloatTensor(next_states).to(device),
            torch.FloatTensor(dones.astype(np.float32)).unsqueeze(1).to(device),
        )

    def __len__(self):
        return len(self.buffer)


# DDQN 에이전트를 정의합니다.
class DDQNAgent:
    def __init__(
        self,
        state_dim,
        action_dim,
        gamma=0.95,
        lr=5e-4,
        batch_size=64,
        memory_size=100_000,
        target_update=2000,
        epsilon_start=1.0,
        epsilon_end=0.05,
        epsilon_decay=0.995,
    ):
        self.action_dim = action_dim
        self.gamma = gamma
        self.batch_size = batch_size
        self.target_update = target_update

        self.epsilon = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay

        self.online_net = QNetwork(state_dim, action_dim).to(device)
        self.target_net = QNetwork(state_dim, action_dim).to(device)
        self.target_net.load_state_dict(self.online_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.online_net.parameters(), lr=lr)
        self.memory = ReplayBuffer(memory_size)
        self.total_steps = 0

    def act(self, state, epsilon: float = None):
        if epsilon is None:
            epsilon = self.epsilon

        if random.random() < epsilon:
            return random.randrange(self.action_dim)

        state_t = torch.FloatTensor(state).unsqueeze(0).to(device)
        with torch.no_grad():
            q_values = self.online_net(state_t)
        return int(torch.argmax(q_values, dim=1).item())

    def decay_epsilon(self):
        self.epsilon = max(self.epsilon_end, self.epsilon * self.epsilon_decay)

    def update(self):
        if len(self.memory) < self.batch_size:
            return None

        states, actions, rewards, next_states, dones = self.memory.sample(self.batch_size)
        
        #online_net에서 현재 Q값 계산
        q_values = self.online_net(states).gather(1, actions)
        #online_net에서 다음 행동 선택 
        next_actions = self.online_net(next_states).argmax(dim=1, keepdim=True)
        #target_net에서 다음 행동의 Q값 계산
        next_q_values = self.target_net(next_states).gather(1, next_actions)
        target_q = rewards + (1 - dones) * self.gamma * next_q_values
        loss = F.mse_loss(q_values, target_q.detach())
        
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.online_net.parameters(), max_norm=10.0)
        self.optimizer.step()
        self.total_steps += 1
        if self.total_steps % self.target_update == 0:
            self.target_net.load_state_dict(self.online_net.state_dict())
        return float(loss.item())

def encode_risk_labels(series):
    s = series.copy()
    # 문자열 타입이면 'High Risk' → 1, 'Low Risk' → 0 매핑
    if pd.api.types.is_object_dtype(s) or pd.api.types.is_string_dtype(s):
        s = s.map({'Low Risk': 0, 'High Risk': 1})
        if s.isna().any():
            raise ValueError(f"알 수 없는 라벨 값이 있습니다: {series[s.isna()].unique()}")
    # 숫자형이면 그냥 int 변환
    return s.fillna(0).astype(int).to_numpy()

# ---- 데이터 준비 (Train/Valid/Test Split 먼저, 그 후 Scaling) ----

risk_label_col = "Risk_Label"
feature_cols = [c for c in dat.select_dtypes(include=[np.number]).columns if c != risk_label_col]
if len(feature_cols) == 0:
    raise ValueError("학습에 사용할 수치형 feature가 없습니다.")

risk_label_data = encode_risk_labels(dat[risk_label_col])
feature_data_raw = dat[feature_cols].fillna(0.0).to_numpy()
n_steps = len(dat)

train_ratio, valid_ratio, test_ratio = 0.45, 0.35, 0.2
n_train = int(n_steps * train_ratio)
n_valid = int(n_steps * valid_ratio)

train_indices = np.arange(0, n_train)
valid_indices = np.arange(n_train, n_train + n_valid)
test_indices = np.arange(n_train + n_valid, n_steps)

train_feature_raw = feature_data_raw[train_indices]
train_label = risk_label_data[train_indices]

valid_feature_raw = feature_data_raw[valid_indices]
valid_label = risk_label_data[valid_indices]
if len(valid_label) < 2:
    raise ValueError("Validation set 길이가 너무 짧아 tuning/selection 분할이 불가능합니다. split 비율을 조정하세요.")
valid_split_point = int(len(valid_label) * 0.65)
valid_tune_feature_raw = valid_feature_raw[:valid_split_point]
valid_tune_label = valid_label[:valid_split_point]
valid_select_feature_raw = valid_feature_raw[valid_split_point:]
valid_select_label = valid_label[valid_split_point:]

test_feature_raw = feature_data_raw[test_indices]
test_label = risk_label_data[test_indices]

def summarize_class_ratio(name, y):
    n_total = len(y)
    n0 = int((y == 0).sum())
    n1 = int((y == 1).sum())
    r0 = n0 / n_total if n_total > 0 else 0.0
    r1 = n1 / n_total if n_total > 0 else 0.0
    imbalance = (n1 / max(n0, 1)) if n_total > 0 else 0.0
    print(f"{name:>5} | n={n_total:4d} | class0={n0:4d} ({r0:.2%}) | class1={n1:4d} ({r1:.2%}) | c1/c0={imbalance:.4f})")
    if n0 == 0 or n1 == 0:
        raise ValueError(f"{name} set에 클래스 0 또는 1이 없습니다. split 비율 또는 기간을 조정하세요.")

print("Class Ratio Summary (Before ADASYN)")
summarize_class_ratio("Train", train_label)
summarize_class_ratio("ValTun", valid_tune_label)
summarize_class_ratio("ValSel", valid_select_label)
summarize_class_ratio("Test", test_label)

# 보상 계산에 사용할 class_ratio는 원본 train 기준으로 고정합니다.
n_negative_original = (train_label == 0).sum()
n_positive_original = (train_label == 1).sum()
class_ratio_reward = n_positive_original / max(n_negative_original, 1)
print(f"Reward class ratio (original train): {class_ratio_reward:.4f}")

# ---- ADASYN을 적용하지 않고 원본 학습 데이터를 그대로 사용 ----
train_feature = train_feature_raw.astype(np.float32)
train_label = train_label.astype(np.int64)

scaler = MinMaxScaler()
scaler.fit(train_feature)

train_feature = scaler.transform(train_feature).astype(np.float32)
valid_tune_feature = scaler.transform(valid_tune_feature_raw).astype(np.float32)
valid_select_feature = scaler.transform(valid_select_feature_raw).astype(np.float32)
test_feature = scaler.transform(test_feature_raw).astype(np.float32)

print("=" * 60)
print("Data Split Information")
print("=" * 60)
print(f"Total samples: {n_steps}")
print(f"Train set: {len(train_label)} samples")
print(f"  - Class 0: {(train_label==0).sum()}, Class 1: {(train_label==1).sum()}")
print(f"Valid(Tune) set: {len(valid_tune_label)} samples")
print(f"  - Class 0: {(valid_tune_label==0).sum()}, Class 1: {(valid_tune_label==1).sum()}")
print(f"Valid(Select) set: {len(valid_select_label)} samples")
print(f"  - Class 0: {(valid_select_label==0).sum()}, Class 1: {(valid_select_label==1).sum()}")
print(f"Test set: {len(test_indices)} samples ({test_ratio*100:.1f}%)")
print(f"  - Class 0: {(test_label==0).sum()}, Class 1: {(test_label==1).sum()}")

# 원본 학습 세트의 클래스 비율을 그대로 사용합니다.
n_negative = (train_label == 0).sum()
n_positive = (train_label == 1).sum()
class_ratio = class_ratio_reward

print(f"\nClass ratio (train set): {n_positive / max(n_negative, 1):.4f}")
print(f"Class ratio used for reward: {class_ratio:.4f}")
print("=" * 60)

state_dim = len(feature_cols)
action_dim = 2

def compute_reward(action, actual_label, class_ratio):
    action = int(action)
    actual_label = int(actual_label)
    if actual_label == 0:
        if action == 0:
            return class_ratio
        else:
            return -class_ratio
    else:
        if action == 1:
            return 1
        else:
            return -1
        
# ↓ 여기에 새 함수 추가
# train_label에서 High Risk 인덱스를 미리 계산
high_risk_indices = np.where(train_label == 1)[0]
print(f"High Risk 인덱스 수 (train): {len(high_risk_indices)}")

def get_balanced_start_idx(max_steps, high_risk_prob=0.6):
    """
    high_risk_prob 확률로 High Risk가 윈도우 안에
    반드시 포함되는 start_idx를 반환.
    
    나머지 확률로는 기존 랜덤 방식 사용.
    시계열 순서는 항상 유지됨.
    
    Parameters:
        max_steps: 에피소드 길이 (500)
        high_risk_prob: High Risk 포함 윈도우 선택 확률
    
    Returns:
        start_idx: 에피소드 시작 인덱스
    """
    n = len(train_feature)
    max_start = n - max_steps - 1
    
    if np.random.random() < high_risk_prob:
        # High Risk 인덱스 중 하나를 무작위 선택
        hr_idx = np.random.choice(high_risk_indices)
        
        # 이 hr_idx가 윈도우 안에 포함되는
        # start_idx의 유효 범위 계산:
        # 조건: start_idx <= hr_idx <= start_idx + max_steps - 1
        # → low = hr_idx - max_steps + 1
        # → high = hr_idx
        low  = max(0, hr_idx - max_steps + 1)
        high = min(max_start, hr_idx)
        
        if low > high:
            # 유효 범위가 없으면 (데이터 끝부분 등) 랜덤
            return np.random.randint(0, max_start + 1)
        
        # 유효 범위 안에서 랜덤 선택
        # → High Risk가 윈도우 앞/중간/뒤 어디든 포함됨
        return int(np.random.randint(low, high + 1))
    
    else:
        # 기존 방식: 완전 랜덤
        return int(np.random.randint(0, max_start + 1))
# Out:
# Class Ratio Summary (Before ADASYN)
# Train | n=1848 | class0=1665 (90.10%) | class1= 183 (9.90%) | c1/c0=0.1099)
# ValTun | n= 934 | class0= 842 (90.15%) | class1=  92 (9.85%) | c1/c0=0.1093)
# ValSel | n= 503 | class0= 433 (86.08%) | class1=  70 (13.92%) | c1/c0=0.1617)
#  Test | n= 823 | class0= 732 (88.94%) | class1=  91 (11.06%) | c1/c0=0.1243)
# Reward class ratio (original train): 0.1099
# ============================================================
# Data Split Information
# ============================================================
# Total samples: 4108
# Train set: 1848 samples
#   - Class 0: 1665, Class 1: 183
# Valid(Tune) set: 934 samples
#   - Class 0: 842, Class 1: 92
# Valid(Select) set: 503 samples
#   - Class 0: 433, Class 1: 70
# Test set: 823 samples (20.0%)
#   - Class 0: 732, Class 1: 91
#
# Class ratio (train set): 0.1099
# Class ratio used for reward: 0.1099
# ============================================================
# High Risk 인덱스 수 (train): 183

# %%
# ---- Validation 기반 하이퍼파라미터 Grid Search ----
from itertools import product

param_grid = {
    'gamma': [0.5,0.7,0.9],
    'lr': [1e-4,5e-4,1e-3],
    'epsilon_decay': [0.99, 0.995],
    'batch_size': [32, 64],
}

def compute_gmean(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0
    gmean = float(np.sqrt(sensitivity * specificity))
    return gmean, sensitivity, specificity

def predict_labels_argmax(model, features):
    preds = []
    with torch.no_grad():
        for t in range(len(features)):
            state_t = torch.FloatTensor(features[t]).unsqueeze(0).to(device)
            q_values = model(state_t)
            preds.append(int(torch.argmax(q_values, dim=1).item()))
    return np.array(preds)

def evaluate_argmax(model, x_valid, y_valid):
    preds = predict_labels_argmax(model, x_valid)
    gmean, sensitivity, specificity = compute_gmean(y_valid, preds)
    return gmean, sensitivity, specificity


#그리드 서치 학습 =============================================
grid_search_results = []
param_combinations = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

print("\n" + "=" * 80)
print(f"HYPERPARAMETER GRID SEARCH (Total: {len(param_combinations)} combinations)")
print("=" * 80)

patience = 25
min_episodes = 60
best_overall_select_gmean = 0.0
best_overall_params = None

for idx, params in enumerate(param_combinations):
    param_dict = dict(zip(param_names, params))
    gamma, lr, epsilon_decay, batch_size = params
    # 각 조합마다 동일한 초기 조건으로 시작
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    print(f"\n[{idx+1}/{len(param_combinations)}] gamma={gamma:.2f}, lr={lr:.0e}, eps_decay={epsilon_decay:.3f}, bs={batch_size}")

    agent_tune = DDQNAgent(
        state_dim=state_dim,
        action_dim=action_dim,
        gamma=gamma,
        lr=lr,
        batch_size=batch_size,
        memory_size=50_000,
        target_update=2000,
        epsilon_start=1.0,
        epsilon_end=0.05,
        epsilon_decay=epsilon_decay,
    )

    episodes_tune = 200
    max_steps_tune = 500
    best_tune_gmean = 0.0
    best_tune_state_dict = None
    patience_counter = 0

    for ep in range(1, episodes_tune + 1):
        start_idx = get_balanced_start_idx(max_steps_tune, high_risk_prob=0.5)
        episode_reward = 0.0

        for i in range(max_steps_tune):
            state = train_feature[start_idx + i]
            next_state = train_feature[start_idx + i + 1] if start_idx + i + 1 < len(train_feature) else train_feature[start_idx + i]
            actual_label = train_label[start_idx + i]

            action = agent_tune.act(state)
            reward = compute_reward(action, actual_label, class_ratio)
            done = i == (max_steps_tune - 1)

            agent_tune.memory.push(state, action, reward, next_state, done)
            _ = agent_tune.update()
            episode_reward += reward

        agent_tune.decay_epsilon()

    # 5 에피소드마다 tune 데이터로 검증을 수행하여 G-mean이 개선되는지 확인=================================
        if ep % 5 == 0:
            agent_tune.online_net.eval()
            tune_gmean, tune_sensitivity, tune_specificity = evaluate_argmax(
                agent_tune.online_net, valid_tune_feature, valid_tune_label
            )
            agent_tune.online_net.train()

            if tune_gmean > best_tune_gmean:
                best_tune_gmean = tune_gmean
                patience_counter = 0
                best_tune_state_dict = {k: v.detach().cpu().clone() for k, v in agent_tune.online_net.state_dict().items()}
            else:
                patience_counter += 1

            if ep % 20 == 0:
                print(f"  Ep {ep:3d} | Tune G-mean: {tune_gmean:.4f} (Sens: {tune_sensitivity:.4f}, Spec: {tune_specificity:.4f}) | Best: {best_tune_gmean:.4f}")

            if ep > min_episodes and patience_counter >= patience:
                break
# Tune에서 가장 좋은 모델로 Selection 데이터에 대한 최종 평가를 수행합니다====================

    agent_tune.online_net.eval()
    if best_tune_state_dict is not None:
        agent_tune.online_net.load_state_dict(best_tune_state_dict)
    select_gmean, select_sensitivity, select_specificity = evaluate_argmax(
        agent_tune.online_net, valid_select_feature, valid_select_label
    )

    grid_search_results.append({
        'params': param_dict,
        'best_tune_gmean': best_tune_gmean,
        'select_gmean': select_gmean,
        'select_sensitivity': select_sensitivity,
        'select_specificity': select_specificity,
    })

    if select_gmean > best_overall_select_gmean:
        best_overall_select_gmean = select_gmean
        best_overall_params = param_dict

grid_search_results.sort(key=lambda x: x['select_gmean'], reverse=True)

print("\n" + "=" * 80)
print("TOP 5 HYPERPARAMETERS")
print("=" * 80)
for i, result in enumerate(grid_search_results[:5]):
    print(f"{i+1}. Select G-mean: {result['select_gmean']:.4f} | Tune Best: {result['best_tune_gmean']:.4f} | Params: {result['params']}")

print("\n" + "=" * 80)
print("BEST HYPERPARAMETERS")
print("=" * 80)
for k, v in best_overall_params.items():
    print(f"{k}: {v}")
print(f"Best Selection G-mean: {best_overall_select_gmean:.4f}")
print("=" * 80)

# ---- 최적 파라미터로 본 학습 ----
print("\nTraining with best hyperparameters...")
agent = DDQNAgent(
    state_dim=state_dim,
    action_dim=action_dim,
    gamma=best_overall_params['gamma'],
    lr=best_overall_params['lr'],
    batch_size=best_overall_params['batch_size'],
    memory_size=50_000,
    target_update=2000,
    epsilon_start=1.0,
    epsilon_end=0.05,
    epsilon_decay=best_overall_params['epsilon_decay'],
)

episodes = 800
max_steps = 500
scores = []
valid_scores = []
best_ckpt_valid_gmean = -1.0
best_ckpt_epoch = 0
best_ckpt_state_dict = None

for ep in range(1, episodes + 1):
    episode_reward = 0.0
    start_idx = get_balanced_start_idx(max_steps, high_risk_prob=0.5)

    for i in range(max_steps):
        state = train_feature[start_idx + i]
        next_state = train_feature[start_idx + i + 1] if start_idx + i + 1 < len(train_feature) else train_feature[start_idx + i]
        actual_label = train_label[start_idx + i]

        action = agent.act(state)
        reward = compute_reward(action, actual_label, class_ratio)
        done = i == (max_steps - 1)

        agent.memory.push(state, action, reward, next_state, done)
        _ = agent.update()
        episode_reward += reward

    agent.decay_epsilon()
    scores.append(episode_reward)

    if ep % 10 == 0:
        agent.online_net.eval()
        valid_gmean, valid_sensitivity, valid_specificity = evaluate_argmax(
            agent.online_net, valid_select_feature, valid_select_label
        )
        valid_scores.append(valid_gmean)

        if valid_gmean > best_ckpt_valid_gmean:
            best_ckpt_valid_gmean = valid_gmean
            best_ckpt_epoch = ep
            best_ckpt_state_dict = {k: v.detach().cpu().clone() for k, v in agent.online_net.state_dict().items()}
        agent.online_net.train()

        print(f"Episode {ep:3d} | Train Reward: {np.mean(scores[-10:]):8.5f} | Valid G-mean: {valid_gmean:.4f} (Sens: {valid_sensitivity:.4f}, Spec: {valid_specificity:.4f}) | Best G: {best_ckpt_valid_gmean:.4f}")

print("최종 학습 완료")
if best_ckpt_state_dict is not None:
    agent.online_net.load_state_dict(best_ckpt_state_dict)
    agent.target_net.load_state_dict(best_ckpt_state_dict)
    print(f"Best checkpoint restored: epoch={best_ckpt_epoch}, valid_gmean={best_ckpt_valid_gmean:.4f}")

agent.online_net.eval()

# ---- Test 평가 ----
test_predictions = predict_labels_argmax(agent.online_net, test_feature)

cm_test = confusion_matrix(test_label, test_predictions, labels=[0, 1])
tn, fp, fn, tp = cm_test.ravel()
sensitivity_test = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity_test = tn / (tn + fp) if (tn + fp) > 0 else 0
gmean_test = np.sqrt(sensitivity_test * specificity_test)

print("\n" + "=" * 60)
print("TEST SET - DDQN 분류 모델 최종 성능 평가")
print("=" * 60)
print(f"\nG-mean: {gmean_test:.4f}")
print(f"\nConfusion Matrix:")
print(cm_test)
print(f"\nTN: {cm_test[0, 0]}, FP: {cm_test[0, 1]}")
print(f"FN: {cm_test[1, 0]}, TP: {cm_test[1, 1]}")

print(f"\n분류 리포트:")
print(classification_report(test_label, test_predictions,
                          labels=[0, 1],
                          target_names=['Class 0 (Negative)', 'Class 1 (Positive)'],
                          zero_division=0))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax1 = axes[0]
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Blues', cbar=False, ax=ax1,
            xticklabels=['Pred 0', 'Pred 1'],
            yticklabels=['Actual 0', 'Actual 1'])
ax1.set_title('Test Set - Confusion Matrix (Count)', fontsize=12, fontweight='bold')
ax1.set_ylabel('True Label')
ax1.set_xlabel('Predicted Label')

cm_test_row_sums = cm_test.sum(axis=1, keepdims=True)
cm_test_percent = np.divide(cm_test.astype(float), cm_test_row_sums,
                             out=np.zeros_like(cm_test, dtype=float),
                             where=cm_test_row_sums != 0) * 100
ax2 = axes[1]
sns.heatmap(cm_test_percent, annot=True, fmt='.2f', cmap='Blues', cbar=True, ax=ax2,
            xticklabels=['Pred 0', 'Pred 1'],
            yticklabels=['Actual 0', 'Actual 1'],
            cbar_kws={'label': 'Percentage (%)'})
ax2.set_title('Test Set - Confusion Matrix (Percentage)', fontsize=12, fontweight='bold')
ax2.set_ylabel('True Label')
ax2.set_xlabel('Predicted Label')

plt.tight_layout()
plt.show()

precision = tp / (tp + fp) if (tp + fp) > 0 else 0
f1_score_val = 2 * (precision * sensitivity_test) / (precision + sensitivity_test) if (precision + sensitivity_test) > 0 else 0

print(f"\n상세 메트릭 (Test Set):")
print(f"Sensitivity (Recall for Class 1): {sensitivity_test:.4f}")
print(f"Specificity (Recall for Class 0): {specificity_test:.4f}")
print(f"Precision (Class 1): {precision:.4f}")
print(f"F1-Score: {f1_score_val:.4f}")
print("=" * 60)

print("\n" + "=" * 60)
print("VALIDATION SET vs TEST SET 성능 비교")
print("=" * 60)

agent.online_net.eval()
valid_predictions = predict_labels_argmax(agent.online_net, valid_select_feature)
cm_valid = confusion_matrix(valid_select_label, valid_predictions, labels=[0, 1])
tn_v, fp_v, fn_v, tp_v = cm_valid.ravel()
sensitivity_valid = tp_v / (tp_v + fn_v) if (tp_v + fn_v) > 0 else 0
specificity_valid = tn_v / (tn_v + fp_v) if (tn_v + fp_v) > 0 else 0
gmean_valid = np.sqrt(sensitivity_valid * specificity_valid)

print(f"\nValidation(Selection) Set - G-mean: {gmean_valid:.4f}")
print(f"Test Set - G-mean: {gmean_test:.4f}")
print(f"Difference (Valid - Test): {gmean_valid - gmean_test:.4f}")
print("\nValidation Confusion Matrix:")
print(cm_valid)
print("\nTest Confusion Matrix:")
print(cm_test)
print("=" * 60)
# Out:
# ================================================================================
# HYPERPARAMETER GRID SEARCH (Total: 36 combinations)
# ================================================================================
#
# [1/36] gamma=0.50, lr=1e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6467 (Sens: 0.5435, Spec: 0.7696) | Best: 0.6764
#   Ep  40 | Tune G-mean: 0.6502 (Sens: 0.5435, Spec: 0.7779) | Best: 0.6764
#   Ep  60 | Tune G-mean: 0.6260 (Sens: 0.5000, Spec: 0.7838) | Best: 0.6764
#   Ep  80 | Tune G-mean: 0.6131 (Sens: 0.5000, Spec: 0.7518) | Best: 0.6764
#   Ep 100 | Tune G-mean: 0.5988 (Sens: 0.4674, Spec: 0.7672) | Best: 0.6764
#   Ep 120 | Tune G-mean: 0.5695 (Sens: 0.4022, Spec: 0.8064) | Best: 0.6764
#
# [2/36] gamma=0.50, lr=1e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.6735 (Sens: 0.5543, Spec: 0.8183) | Best: 0.6735
#   Ep  40 | Tune G-mean: 0.6731 (Sens: 0.5870, Spec: 0.7720) | Best: 0.7137
#   Ep  60 | Tune G-mean: 0.6457 (Sens: 0.5870, Spec: 0.7102) | Best: 0.7137
#   Ep  80 | Tune G-mean: 0.6380 (Sens: 0.5761, Spec: 0.7067) | Best: 0.7137
#   Ep 100 | Tune G-mean: 0.6357 (Sens: 0.5652, Spec: 0.7150) | Best: 0.7137
#   Ep 120 | Tune G-mean: 0.6268 (Sens: 0.6196, Spec: 0.6342) | Best: 0.7137
#   Ep 140 | Tune G-mean: 0.6238 (Sens: 0.5543, Spec: 0.7019) | Best: 0.7137
#
# [3/36] gamma=0.50, lr=1e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6617 (Sens: 0.6196, Spec: 0.7067) | Best: 0.6845
#   Ep  40 | Tune G-mean: 0.6472 (Sens: 0.5217, Spec: 0.8029) | Best: 0.6845
#   Ep  60 | Tune G-mean: 0.6481 (Sens: 0.5326, Spec: 0.7886) | Best: 0.6845
#   Ep  80 | Tune G-mean: 0.6332 (Sens: 0.5761, Spec: 0.6960) | Best: 0.6845
#   Ep 100 | Tune G-mean: 0.5728 (Sens: 0.4022, Spec: 0.8159) | Best: 0.6845
#   Ep 120 | Tune G-mean: 0.5822 (Sens: 0.4130, Spec: 0.8207) | Best: 0.6845
#
# [4/36] gamma=0.50, lr=1e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.6597 (Sens: 0.5543, Spec: 0.7850) | Best: 0.6607
#   Ep  40 | Tune G-mean: 0.6183 (Sens: 0.4783, Spec: 0.7993) | Best: 0.6915
#   Ep  60 | Tune G-mean: 0.6099 (Sens: 0.5109, Spec: 0.7280) | Best: 0.6915
#   Ep  80 | Tune G-mean: 0.6323 (Sens: 0.5109, Spec: 0.7827) | Best: 0.6915
#   Ep 100 | Tune G-mean: 0.6283 (Sens: 0.5326, Spec: 0.7411) | Best: 0.6915
#   Ep 120 | Tune G-mean: 0.6140 (Sens: 0.5761, Spec: 0.6544) | Best: 0.6915
#   Ep 140 | Tune G-mean: 0.6083 (Sens: 0.5543, Spec: 0.6675) | Best: 0.6915
#
# [5/36] gamma=0.50, lr=5e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6183 (Sens: 0.4565, Spec: 0.8373) | Best: 0.6781
#   Ep  40 | Tune G-mean: 0.6434 (Sens: 0.5761, Spec: 0.7185) | Best: 0.6781
#   Ep  60 | Tune G-mean: 0.5969 (Sens: 0.5217, Spec: 0.6829) | Best: 0.6781
#   Ep  80 | Tune G-mean: 0.5873 (Sens: 0.4239, Spec: 0.8135) | Best: 0.6781
#   Ep 100 | Tune G-mean: 0.6256 (Sens: 0.5109, Spec: 0.7660) | Best: 0.6781
#   Ep 120 | Tune G-mean: 0.5949 (Sens: 0.4783, Spec: 0.7399) | Best: 0.6781
#
# [6/36] gamma=0.50, lr=5e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.6029 (Sens: 0.4239, Spec: 0.8575) | Best: 0.6956
#   Ep  40 | Tune G-mean: 0.6116 (Sens: 0.5000, Spec: 0.7482) | Best: 0.6956
#   Ep  60 | Tune G-mean: 0.5691 (Sens: 0.4457, Spec: 0.7268) | Best: 0.6956
#   Ep  80 | Tune G-mean: 0.5682 (Sens: 0.4457, Spec: 0.7245) | Best: 0.6956
#   Ep 100 | Tune G-mean: 0.5959 (Sens: 0.5217, Spec: 0.6805) | Best: 0.6956
#   Ep 120 | Tune G-mean: 0.6387 (Sens: 0.5435, Spec: 0.7506) | Best: 0.6956
#
# [7/36] gamma=0.50, lr=5e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6262 (Sens: 0.6630, Spec: 0.5914) | Best: 0.6681
#   Ep  40 | Tune G-mean: 0.6188 (Sens: 0.5217, Spec: 0.7340) | Best: 0.6681
#   Ep  60 | Tune G-mean: 0.6164 (Sens: 0.4891, Spec: 0.7767) | Best: 0.6681
#   Ep  80 | Tune G-mean: 0.6223 (Sens: 0.5217, Spec: 0.7423) | Best: 0.6681
#   Ep 100 | Tune G-mean: 0.6082 (Sens: 0.5000, Spec: 0.7399) | Best: 0.6681
#   Ep 120 | Tune G-mean: 0.6357 (Sens: 0.5652, Spec: 0.7150) | Best: 0.6681
#
# [8/36] gamma=0.50, lr=5e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.6295 (Sens: 0.5435, Spec: 0.7292) | Best: 0.6837
#   Ep  40 | Tune G-mean: 0.5517 (Sens: 0.3913, Spec: 0.7779) | Best: 0.6837
#   Ep  60 | Tune G-mean: 0.5707 (Sens: 0.4130, Spec: 0.7886) | Best: 0.6837
#   Ep  80 | Tune G-mean: 0.5381 (Sens: 0.3478, Spec: 0.8325) | Best: 0.6837
#   Ep 100 | Tune G-mean: 0.5833 (Sens: 0.4674, Spec: 0.7280) | Best: 0.6837
#   Ep 120 | Tune G-mean: 0.5673 (Sens: 0.4457, Spec: 0.7221) | Best: 0.6837
#
# [9/36] gamma=0.50, lr=1e-03, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6256 (Sens: 0.5109, Spec: 0.7660) | Best: 0.6764
#   Ep  40 | Tune G-mean: 0.5924 (Sens: 0.5000, Spec: 0.7019) | Best: 0.6764
#   Ep  60 | Tune G-mean: 0.6118 (Sens: 0.5109, Spec: 0.7328) | Best: 0.6764
#   Ep  80 | Tune G-mean: 0.6290 (Sens: 0.5109, Spec: 0.7743) | Best: 0.6764
#   Ep 100 | Tune G-mean: 0.5747 (Sens: 0.4674, Spec: 0.7067) | Best: 0.6764
#   Ep 120 | Tune G-mean: 0.5958 (Sens: 0.4891, Spec: 0.7257) | Best: 0.6764
#
# [10/36] gamma=0.50, lr=1e-03, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.6034 (Sens: 0.4674, Spec: 0.7791) | Best: 0.6716
#   Ep  40 | Tune G-mean: 0.6318 (Sens: 0.5109, Spec: 0.7815) | Best: 0.6716
#   Ep  60 | Tune G-mean: 0.6183 (Sens: 0.4783, Spec: 0.7993) | Best: 0.6716
#   Ep  80 | Tune G-mean: 0.6076 (Sens: 0.4674, Spec: 0.7898) | Best: 0.6716
#   Ep 100 | Tune G-mean: 0.5797 (Sens: 0.4130, Spec: 0.8135) | Best: 0.6716
#   Ep 120 | Tune G-mean: 0.5304 (Sens: 0.3478, Spec: 0.8088) | Best: 0.6716
#
# [11/36] gamma=0.50, lr=1e-03, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6730 (Sens: 0.6304, Spec: 0.7185) | Best: 0.6873
#   Ep  40 | Tune G-mean: 0.6072 (Sens: 0.4783, Spec: 0.7708) | Best: 0.6873
#   Ep  60 | Tune G-mean: 0.5749 (Sens: 0.4022, Spec: 0.8219) | Best: 0.6873
#   Ep  80 | Tune G-mean: 0.5720 (Sens: 0.3913, Spec: 0.8361) | Best: 0.6873
#   Ep 100 | Tune G-mean: 0.5991 (Sens: 0.4239, Spec: 0.8468) | Best: 0.6873
#   Ep 120 | Tune G-mean: 0.5704 (Sens: 0.3913, Spec: 0.8314) | Best: 0.6873
#   Ep 140 | Tune G-mean: 0.5680 (Sens: 0.3804, Spec: 0.8480) | Best: 0.6873
#
# [12/36] gamma=0.50, lr=1e-03, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.6247 (Sens: 0.4783, Spec: 0.8159) | Best: 0.6761
#   Ep  40 | Tune G-mean: 0.6192 (Sens: 0.4891, Spec: 0.7838) | Best: 0.6761
#   Ep  60 | Tune G-mean: 0.6138 (Sens: 0.5217, Spec: 0.7221) | Best: 0.6761
#   Ep  80 | Tune G-mean: 0.6043 (Sens: 0.4783, Spec: 0.7637) | Best: 0.6761
#   Ep 100 | Tune G-mean: 0.6445 (Sens: 0.5543, Spec: 0.7494) | Best: 0.6761
#   Ep 120 | Tune G-mean: 0.6247 (Sens: 0.5326, Spec: 0.7328) | Best: 0.6761
#   Ep 140 | Tune G-mean: 0.6040 (Sens: 0.4891, Spec: 0.7458) | Best: 0.6761
#
# [13/36] gamma=0.70, lr=1e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6434 (Sens: 0.5217, Spec: 0.7933) | Best: 0.6778
#   Ep  40 | Tune G-mean: 0.6642 (Sens: 0.5543, Spec: 0.7957) | Best: 0.6778
#   Ep  60 | Tune G-mean: 0.6527 (Sens: 0.5435, Spec: 0.7838) | Best: 0.6778
#   Ep  80 | Tune G-mean: 0.6437 (Sens: 0.5326, Spec: 0.7779) | Best: 0.6778
#   Ep 100 | Tune G-mean: 0.6395 (Sens: 0.5109, Spec: 0.8005) | Best: 0.6778
#   Ep 120 | Tune G-mean: 0.6279 (Sens: 0.4783, Spec: 0.8242) | Best: 0.6778
#
# [14/36] gamma=0.70, lr=1e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.6331 (Sens: 0.4891, Spec: 0.8195) | Best: 0.6669
#   Ep  40 | Tune G-mean: 0.6438 (Sens: 0.5217, Spec: 0.7945) | Best: 0.6930
#   Ep  60 | Tune G-mean: 0.6351 (Sens: 0.5217, Spec: 0.7732) | Best: 0.6930
#   Ep  80 | Tune G-mean: 0.6425 (Sens: 0.5543, Spec: 0.7447) | Best: 0.6930
#   Ep 100 | Tune G-mean: 0.6170 (Sens: 0.5000, Spec: 0.7613) | Best: 0.6930
#   Ep 120 | Tune G-mean: 0.6113 (Sens: 0.5435, Spec: 0.6876) | Best: 0.6930
#   Ep 140 | Tune G-mean: 0.6169 (Sens: 0.4783, Spec: 0.7957) | Best: 0.6930
#   Ep 160 | Tune G-mean: 0.6295 (Sens: 0.5435, Spec: 0.7292) | Best: 0.6930
#
# [15/36] gamma=0.70, lr=1e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6576 (Sens: 0.5978, Spec: 0.7233) | Best: 0.6953
#   Ep  40 | Tune G-mean: 0.6494 (Sens: 0.5109, Spec: 0.8254) | Best: 0.6953
#   Ep  60 | Tune G-mean: 0.6207 (Sens: 0.4674, Spec: 0.8242) | Best: 0.6953
#   Ep  80 | Tune G-mean: 0.6337 (Sens: 0.5217, Spec: 0.7696) | Best: 0.6953
#   Ep 100 | Tune G-mean: 0.6078 (Sens: 0.4457, Spec: 0.8290) | Best: 0.6953
#   Ep 120 | Tune G-mean: 0.5901 (Sens: 0.4022, Spec: 0.8658) | Best: 0.6953
#
# [16/36] gamma=0.70, lr=1e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.6534 (Sens: 0.5326, Spec: 0.8017) | Best: 0.6721
#   Ep  40 | Tune G-mean: 0.6048 (Sens: 0.4457, Spec: 0.8207) | Best: 0.6803
#   Ep  60 | Tune G-mean: 0.6126 (Sens: 0.4891, Spec: 0.7672) | Best: 0.6803
#   Ep  80 | Tune G-mean: 0.5930 (Sens: 0.4348, Spec: 0.8088) | Best: 0.6803
#   Ep 100 | Tune G-mean: 0.6151 (Sens: 0.4783, Spec: 0.7910) | Best: 0.6803
#   Ep 120 | Tune G-mean: 0.6300 (Sens: 0.5435, Spec: 0.7304) | Best: 0.6803
#   Ep 140 | Tune G-mean: 0.6047 (Sens: 0.5326, Spec: 0.6865) | Best: 0.6803
#
# [17/36] gamma=0.70, lr=5e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.5847 (Sens: 0.4348, Spec: 0.7862) | Best: 0.6783
#   Ep  40 | Tune G-mean: 0.5735 (Sens: 0.4783, Spec: 0.6876) | Best: 0.6783
#   Ep  60 | Tune G-mean: 0.5833 (Sens: 0.4674, Spec: 0.7280) | Best: 0.6783
#   Ep  80 | Tune G-mean: 0.5820 (Sens: 0.4457, Spec: 0.7601) | Best: 0.6783
#   Ep 100 | Tune G-mean: 0.5505 (Sens: 0.4239, Spec: 0.7150) | Best: 0.6783
#   Ep 120 | Tune G-mean: 0.5840 (Sens: 0.4565, Spec: 0.7470) | Best: 0.6783
#
# [18/36] gamma=0.70, lr=5e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5911 (Sens: 0.4239, Spec: 0.8242) | Best: 0.6603
#   Ep  40 | Tune G-mean: 0.5457 (Sens: 0.3478, Spec: 0.8563) | Best: 0.6603
#   Ep  60 | Tune G-mean: 0.5399 (Sens: 0.3696, Spec: 0.7886) | Best: 0.6603
#   Ep  80 | Tune G-mean: 0.5389 (Sens: 0.3913, Spec: 0.7423) | Best: 0.6603
#   Ep 100 | Tune G-mean: 0.5510 (Sens: 0.4130, Spec: 0.7352) | Best: 0.6603
#   Ep 120 | Tune G-mean: 0.5493 (Sens: 0.4130, Spec: 0.7304) | Best: 0.6603
#
# [19/36] gamma=0.70, lr=5e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6356 (Sens: 0.6196, Spec: 0.6520) | Best: 0.6720
#   Ep  40 | Tune G-mean: 0.6083 (Sens: 0.4891, Spec: 0.7565) | Best: 0.6720
#   Ep  60 | Tune G-mean: 0.5308 (Sens: 0.3478, Spec: 0.8100) | Best: 0.6720
#   Ep  80 | Tune G-mean: 0.5444 (Sens: 0.3804, Spec: 0.7791) | Best: 0.6720
#   Ep 100 | Tune G-mean: 0.5747 (Sens: 0.4239, Spec: 0.7791) | Best: 0.6720
#   Ep 120 | Tune G-mean: 0.5835 (Sens: 0.4565, Spec: 0.7458) | Best: 0.6720
#
# [20/36] gamma=0.70, lr=5e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.6323 (Sens: 0.5326, Spec: 0.7506) | Best: 0.6429
#   Ep  40 | Tune G-mean: 0.5734 (Sens: 0.4239, Spec: 0.7755) | Best: 0.6429
#   Ep  60 | Tune G-mean: 0.5519 (Sens: 0.3696, Spec: 0.8242) | Best: 0.6429
#   Ep  80 | Tune G-mean: 0.5346 (Sens: 0.3587, Spec: 0.7969) | Best: 0.6429
#   Ep 100 | Tune G-mean: 0.5622 (Sens: 0.3913, Spec: 0.8076) | Best: 0.6429
#   Ep 120 | Tune G-mean: 0.6148 (Sens: 0.4674, Spec: 0.8088) | Best: 0.6429
#
# [21/36] gamma=0.70, lr=1e-03, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6484 (Sens: 0.5109, Spec: 0.8230) | Best: 0.6484
#   Ep  40 | Tune G-mean: 0.6130 (Sens: 0.5326, Spec: 0.7055) | Best: 0.6484
#   Ep  60 | Tune G-mean: 0.6090 (Sens: 0.4783, Spec: 0.7755) | Best: 0.6484
#   Ep  80 | Tune G-mean: 0.6051 (Sens: 0.4348, Spec: 0.8420) | Best: 0.6484
#   Ep 100 | Tune G-mean: 0.6290 (Sens: 0.4891, Spec: 0.8088) | Best: 0.6484
#   Ep 120 | Tune G-mean: 0.5594 (Sens: 0.3696, Spec: 0.8468) | Best: 0.6484
#   Ep 140 | Tune G-mean: 0.6021 (Sens: 0.4348, Spec: 0.8337) | Best: 0.6484
#
# [22/36] gamma=0.70, lr=1e-03, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.6506 (Sens: 0.5543, Spec: 0.7637) | Best: 0.6567
#   Ep  40 | Tune G-mean: 0.5974 (Sens: 0.4674, Spec: 0.7637) | Best: 0.6567
#   Ep  60 | Tune G-mean: 0.5754 (Sens: 0.4130, Spec: 0.8017) | Best: 0.6567
#   Ep  80 | Tune G-mean: 0.5690 (Sens: 0.4130, Spec: 0.7838) | Best: 0.6567
#   Ep 100 | Tune G-mean: 0.5873 (Sens: 0.4239, Spec: 0.8135) | Best: 0.6567
#   Ep 120 | Tune G-mean: 0.6076 (Sens: 0.4565, Spec: 0.8088) | Best: 0.6567
#
# [23/36] gamma=0.70, lr=1e-03, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6376 (Sens: 0.5217, Spec: 0.7791) | Best: 0.6713
#   Ep  40 | Tune G-mean: 0.6486 (Sens: 0.5217, Spec: 0.8064) | Best: 0.6713
#   Ep  60 | Tune G-mean: 0.6125 (Sens: 0.4565, Spec: 0.8219) | Best: 0.6713
#   Ep  80 | Tune G-mean: 0.6144 (Sens: 0.4674, Spec: 0.8076) | Best: 0.6713
#   Ep 100 | Tune G-mean: 0.6039 (Sens: 0.4457, Spec: 0.8183) | Best: 0.6713
#   Ep 120 | Tune G-mean: 0.6048 (Sens: 0.4674, Spec: 0.7827) | Best: 0.6713
#
# [24/36] gamma=0.70, lr=1e-03, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.6299 (Sens: 0.5652, Spec: 0.7019) | Best: 0.6656
#   Ep  40 | Tune G-mean: 0.5431 (Sens: 0.3696, Spec: 0.7981) | Best: 0.6656
#   Ep  60 | Tune G-mean: 0.5725 (Sens: 0.4239, Spec: 0.7732) | Best: 0.6656
#   Ep  80 | Tune G-mean: 0.5385 (Sens: 0.3478, Spec: 0.8337) | Best: 0.6656
#   Ep 100 | Tune G-mean: 0.5569 (Sens: 0.3587, Spec: 0.8646) | Best: 0.6656
#   Ep 120 | Tune G-mean: 0.5442 (Sens: 0.3478, Spec: 0.8515) | Best: 0.6656
#   Ep 140 | Tune G-mean: 0.5656 (Sens: 0.3804, Spec: 0.8409) | Best: 0.6656
#
# [25/36] gamma=0.90, lr=1e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6517 (Sens: 0.5435, Spec: 0.7815) | Best: 0.6735
#   Ep  40 | Tune G-mean: 0.6626 (Sens: 0.5652, Spec: 0.7767) | Best: 0.6735
#   Ep  60 | Tune G-mean: 0.6452 (Sens: 0.5326, Spec: 0.7815) | Best: 0.6735
#   Ep  80 | Tune G-mean: 0.6367 (Sens: 0.5435, Spec: 0.7458) | Best: 0.6735
#   Ep 100 | Tune G-mean: 0.5539 (Sens: 0.3804, Spec: 0.8064) | Best: 0.6735
#   Ep 120 | Tune G-mean: 0.5906 (Sens: 0.4457, Spec: 0.7827) | Best: 0.6735
#
# [26/36] gamma=0.90, lr=1e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.6211 (Sens: 0.4674, Spec: 0.8254) | Best: 0.6691
#   Ep  40 | Tune G-mean: 0.6275 (Sens: 0.5109, Spec: 0.7708) | Best: 0.6845
#   Ep  60 | Tune G-mean: 0.6178 (Sens: 0.5217, Spec: 0.7316) | Best: 0.6845
#   Ep  80 | Tune G-mean: 0.6222 (Sens: 0.5543, Spec: 0.6983) | Best: 0.6845
#   Ep 100 | Tune G-mean: 0.6161 (Sens: 0.5435, Spec: 0.6983) | Best: 0.6845
#   Ep 120 | Tune G-mean: 0.5998 (Sens: 0.5870, Spec: 0.6128) | Best: 0.6845
#   Ep 140 | Tune G-mean: 0.6023 (Sens: 0.5435, Spec: 0.6675) | Best: 0.6845
#
# [27/36] gamma=0.90, lr=1e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6542 (Sens: 0.5870, Spec: 0.7292) | Best: 0.6868
#   Ep  40 | Tune G-mean: 0.6495 (Sens: 0.5326, Spec: 0.7922) | Best: 0.6868
#   Ep  60 | Tune G-mean: 0.6099 (Sens: 0.4565, Spec: 0.8147) | Best: 0.6868
#   Ep  80 | Tune G-mean: 0.6168 (Sens: 0.5109, Spec: 0.7447) | Best: 0.6868
#   Ep 100 | Tune G-mean: 0.5839 (Sens: 0.4130, Spec: 0.8254) | Best: 0.6868
#   Ep 120 | Tune G-mean: 0.5676 (Sens: 0.3696, Spec: 0.8717) | Best: 0.6868
#
# [28/36] gamma=0.90, lr=1e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.6611 (Sens: 0.5326, Spec: 0.8207) | Best: 0.6674
#   Ep  40 | Tune G-mean: 0.6553 (Sens: 0.5217, Spec: 0.8230) | Best: 0.6759
#   Ep  60 | Tune G-mean: 0.6364 (Sens: 0.5000, Spec: 0.8100) | Best: 0.6759
#   Ep  80 | Tune G-mean: 0.6338 (Sens: 0.5109, Spec: 0.7862) | Best: 0.6759
#   Ep 100 | Tune G-mean: 0.6270 (Sens: 0.5000, Spec: 0.7862) | Best: 0.6759
#   Ep 120 | Tune G-mean: 0.6555 (Sens: 0.5761, Spec: 0.7458) | Best: 0.6759
#   Ep 140 | Tune G-mean: 0.6225 (Sens: 0.6087, Spec: 0.6366) | Best: 0.6759
#
# [29/36] gamma=0.90, lr=5e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6495 (Sens: 0.5326, Spec: 0.7922) | Best: 0.6807
#   Ep  40 | Tune G-mean: 0.6337 (Sens: 0.5543, Spec: 0.7245) | Best: 0.6807
#   Ep  60 | Tune G-mean: 0.6387 (Sens: 0.5326, Spec: 0.7660) | Best: 0.6807
#   Ep  80 | Tune G-mean: 0.6039 (Sens: 0.4674, Spec: 0.7803) | Best: 0.6807
#   Ep 100 | Tune G-mean: 0.5882 (Sens: 0.4348, Spec: 0.7957) | Best: 0.6807
#   Ep 120 | Tune G-mean: 0.5490 (Sens: 0.3804, Spec: 0.7922) | Best: 0.6807
#
# [30/36] gamma=0.90, lr=5e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.6126 (Sens: 0.4891, Spec: 0.7672) | Best: 0.6595
#   Ep  40 | Tune G-mean: 0.5712 (Sens: 0.4130, Spec: 0.7898) | Best: 0.6595
#   Ep  60 | Tune G-mean: 0.5315 (Sens: 0.3587, Spec: 0.7874) | Best: 0.6595
#   Ep  80 | Tune G-mean: 0.5385 (Sens: 0.3478, Spec: 0.8337) | Best: 0.6595
#   Ep 100 | Tune G-mean: 0.5293 (Sens: 0.3370, Spec: 0.8314) | Best: 0.6595
#   Ep 120 | Tune G-mean: 0.4930 (Sens: 0.2826, Spec: 0.8599) | Best: 0.6595
#
# [31/36] gamma=0.90, lr=5e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6631 (Sens: 0.7174, Spec: 0.6128) | Best: 0.6719
#   Ep  40 | Tune G-mean: 0.6412 (Sens: 0.5326, Spec: 0.7720) | Best: 0.6719
#   Ep  60 | Tune G-mean: 0.6193 (Sens: 0.5217, Spec: 0.7352) | Best: 0.6719
#   Ep  80 | Tune G-mean: 0.6332 (Sens: 0.5217, Spec: 0.7684) | Best: 0.6719
#   Ep 100 | Tune G-mean: 0.5959 (Sens: 0.4457, Spec: 0.7969) | Best: 0.6719
#   Ep 120 | Tune G-mean: 0.5694 (Sens: 0.4130, Spec: 0.7850) | Best: 0.6719
#
# [32/36] gamma=0.90, lr=5e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.5904 (Sens: 0.4348, Spec: 0.8017) | Best: 0.6378
#   Ep  40 | Tune G-mean: 0.5743 (Sens: 0.4239, Spec: 0.7779) | Best: 0.6378
#   Ep  60 | Tune G-mean: 0.5572 (Sens: 0.3913, Spec: 0.7933) | Best: 0.6378
#   Ep  80 | Tune G-mean: 0.5378 (Sens: 0.3696, Spec: 0.7827) | Best: 0.6378
#   Ep 100 | Tune G-mean: 0.5559 (Sens: 0.3913, Spec: 0.7898) | Best: 0.6378
#   Ep 120 | Tune G-mean: 0.5350 (Sens: 0.3696, Spec: 0.7743) | Best: 0.6378
#
# [33/36] gamma=0.90, lr=1e-03, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.5860 (Sens: 0.4130, Spec: 0.8314) | Best: 0.6520
#   Ep  40 | Tune G-mean: 0.5649 (Sens: 0.4022, Spec: 0.7933) | Best: 0.6520
#   Ep  60 | Tune G-mean: 0.5475 (Sens: 0.3913, Spec: 0.7660) | Best: 0.6520
#   Ep  80 | Tune G-mean: 0.5833 (Sens: 0.4348, Spec: 0.7827) | Best: 0.6520
#   Ep 100 | Tune G-mean: 0.5904 (Sens: 0.4565, Spec: 0.7637) | Best: 0.6520
#   Ep 120 | Tune G-mean: 0.5712 (Sens: 0.4130, Spec: 0.7898) | Best: 0.6520
#   Ep 140 | Tune G-mean: 0.5604 (Sens: 0.3804, Spec: 0.8254) | Best: 0.6520
#
# [34/36] gamma=0.90, lr=1e-03, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.6511 (Sens: 0.5543, Spec: 0.7648) | Best: 0.6803
#   Ep  40 | Tune G-mean: 0.6201 (Sens: 0.4891, Spec: 0.7862) | Best: 0.6803
#   Ep  60 | Tune G-mean: 0.5451 (Sens: 0.3696, Spec: 0.8040) | Best: 0.6803
#   Ep  80 | Tune G-mean: 0.5461 (Sens: 0.3587, Spec: 0.8314) | Best: 0.6803
#   Ep 100 | Tune G-mean: 0.5339 (Sens: 0.3478, Spec: 0.8195) | Best: 0.6803
#   Ep 120 | Tune G-mean: 0.5620 (Sens: 0.3804, Spec: 0.8302) | Best: 0.6803
#
# [35/36] gamma=0.90, lr=1e-03, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6413 (Sens: 0.6522, Spec: 0.6306) | Best: 0.6733
#   Ep  40 | Tune G-mean: 0.5510 (Sens: 0.3804, Spec: 0.7981) | Best: 0.6733
#   Ep  60 | Tune G-mean: 0.5281 (Sens: 0.3478, Spec: 0.8017) | Best: 0.6733
#   Ep  80 | Tune G-mean: 0.5359 (Sens: 0.3913, Spec: 0.7340) | Best: 0.6733
#   Ep 100 | Tune G-mean: 0.5475 (Sens: 0.3696, Spec: 0.8112) | Best: 0.6733
#   Ep 120 | Tune G-mean: 0.5524 (Sens: 0.4130, Spec: 0.7387) | Best: 0.6733
#
# [36/36] gamma=0.90, lr=1e-03, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.6089 (Sens: 0.5109, Spec: 0.7257) | Best: 0.6568
#   Ep  40 | Tune G-mean: 0.5928 (Sens: 0.4457, Spec: 0.7886) | Best: 0.6568
#   Ep  60 | Tune G-mean: 0.6143 (Sens: 0.5109, Spec: 0.7387) | Best: 0.6568
#   Ep  80 | Tune G-mean: 0.6007 (Sens: 0.4674, Spec: 0.7720) | Best: 0.6568
#   Ep 100 | Tune G-mean: 0.5873 (Sens: 0.4348, Spec: 0.7933) | Best: 0.6568
#   Ep 120 | Tune G-mean: 0.5877 (Sens: 0.4239, Spec: 0.8147) | Best: 0.6568
#
# ================================================================================
# TOP 5 HYPERPARAMETERS
# ================================================================================
# 1. Select G-mean: 0.6555 | Tune Best: 0.6568 | Params: {'gamma': 0.9, 'lr': 0.001, 'epsilon_decay': 0.995, 'batch_size': 64}
# 2. Select G-mean: 0.6496 | Tune Best: 0.6484 | Params: {'gamma': 0.7, 'lr': 0.001, 'epsilon_decay': 0.99, 'batch_size': 32}
# 3. Select G-mean: 0.6390 | Tune Best: 0.6764 | Params: {'gamma': 0.5, 'lr': 0.001, 'epsilon_decay': 0.99, 'batch_size': 32}
# 4. Select G-mean: 0.6373 | Tune Best: 0.7137 | Params: {'gamma': 0.5, 'lr': 0.0001, 'epsilon_decay': 0.99, 'batch_size': 64}
# 5. Select G-mean: 0.6318 | Tune Best: 0.6759 | Params: {'gamma': 0.9, 'lr': 0.0001, 'epsilon_decay': 0.995, 'batch_size': 64}
#
# ================================================================================
# BEST HYPERPARAMETERS
# ================================================================================
# gamma: 0.9
# lr: 0.001
# epsilon_decay: 0.995
# batch_size: 64
# Best Selection G-mean: 0.6555
# ================================================================================
#
# Training with best hyperparameters...
# Episode  10 | Train Reward:  0.47495 | Valid G-mean: 0.5400 (Sens: 0.4857, Spec: 0.6005) | Best G: 0.5400
# Episode  20 | Train Reward:  5.43315 | Valid G-mean: 0.5511 (Sens: 0.4714, Spec: 0.6443) | Best G: 0.5511
# Episode  30 | Train Reward:  8.85225 | Valid G-mean: 0.5289 (Sens: 0.3857, Spec: 0.7252) | Best G: 0.5511
# Episode  40 | Train Reward: 11.55820 | Valid G-mean: 0.5213 (Sens: 0.4143, Spec: 0.6559) | Best G: 0.5511
# Episode  50 | Train Reward: 13.95315 | Valid G-mean: 0.5039 (Sens: 0.3857, Spec: 0.6582) | Best G: 0.5511
# Episode  60 | Train Reward: 21.56649 | Valid G-mean: 0.5552 (Sens: 0.4571, Spec: 0.6744) | Best G: 0.5552
# Episode  70 | Train Reward: 25.58018 | Valid G-mean: 0.5446 (Sens: 0.4000, Spec: 0.7413) | Best G: 0.5552
# Episode  80 | Train Reward: 30.82234 | Valid G-mean: 0.5613 (Sens: 0.4429, Spec: 0.7113) | Best G: 0.5613
# Episode  90 | Train Reward: 37.24468 | Valid G-mean: 0.5337 (Sens: 0.3714, Spec: 0.7667) | Best G: 0.5613
# Episode 100 | Train Reward: 28.44144 | Valid G-mean: 0.4982 (Sens: 0.3143, Spec: 0.7898) | Best G: 0.5613
# Episode 110 | Train Reward: 33.35928 | Valid G-mean: 0.5193 (Sens: 0.3571, Spec: 0.7552) | Best G: 0.5613
# Episode 120 | Train Reward: 41.76613 | Valid G-mean: 0.5288 (Sens: 0.3714, Spec: 0.7529) | Best G: 0.5613
# Episode 130 | Train Reward: 41.14775 | Valid G-mean: 0.5320 (Sens: 0.3714, Spec: 0.7621) | Best G: 0.5613
# Episode 140 | Train Reward: 46.48757 | Valid G-mean: 0.5165 (Sens: 0.3714, Spec: 0.7182) | Best G: 0.5613
# Episode 150 | Train Reward: 53.62162 | Valid G-mean: 0.5190 (Sens: 0.3714, Spec: 0.7252) | Best G: 0.5613
# Episode 160 | Train Reward: 48.24505 | Valid G-mean: 0.5246 (Sens: 0.3857, Spec: 0.7136) | Best G: 0.5613
# Episode 170 | Train Reward: 57.37477 | Valid G-mean: 0.5129 (Sens: 0.3571, Spec: 0.7367) | Best G: 0.5613
# Episode 180 | Train Reward: 59.70270 | Valid G-mean: 0.5342 (Sens: 0.3571, Spec: 0.7991) | Best G: 0.5613
# Episode 190 | Train Reward: 63.51279 | Valid G-mean: 0.5416 (Sens: 0.3714, Spec: 0.7898) | Best G: 0.5613
# Episode 200 | Train Reward: 58.50523 | Valid G-mean: 0.5296 (Sens: 0.3714, Spec: 0.7552) | Best G: 0.5613
# Episode 210 | Train Reward: 62.20432 | Valid G-mean: 0.5923 (Sens: 0.4429, Spec: 0.7921) | Best G: 0.5923
# Episode 220 | Train Reward: 67.40000 | Valid G-mean: 0.5914 (Sens: 0.4429, Spec: 0.7898) | Best G: 0.5923
# Episode 230 | Train Reward: 67.36072 | Valid G-mean: 0.5604 (Sens: 0.4000, Spec: 0.7852) | Best G: 0.5923
# Episode 240 | Train Reward: 71.56721 | Valid G-mean: 0.5888 (Sens: 0.4429, Spec: 0.7829) | Best G: 0.5923
# Episode 250 | Train Reward: 65.16973 | Valid G-mean: 0.5503 (Sens: 0.3857, Spec: 0.7852) | Best G: 0.5923
# Episode 260 | Train Reward: 72.35784 | Valid G-mean: 0.5748 (Sens: 0.4571, Spec: 0.7229) | Best G: 0.5923
# Episode 270 | Train Reward: 74.17333 | Valid G-mean: 0.5416 (Sens: 0.3714, Spec: 0.7898) | Best G: 0.5923
# Episode 280 | Train Reward: 75.86018 | Valid G-mean: 0.5695 (Sens: 0.4143, Spec: 0.7829) | Best G: 0.5923
# Episode 290 | Train Reward: 71.65369 | Valid G-mean: 0.5272 (Sens: 0.3429, Spec: 0.8106) | Best G: 0.5923
# Episode 300 | Train Reward: 69.91640 | Valid G-mean: 0.5227 (Sens: 0.3429, Spec: 0.7968) | Best G: 0.5923
# Episode 310 | Train Reward: 67.64613 | Valid G-mean: 0.5884 (Sens: 0.4714, Spec: 0.7344) | Best G: 0.5923
# Episode 320 | Train Reward: 83.80324 | Valid G-mean: 0.5670 (Sens: 0.4000, Spec: 0.8037) | Best G: 0.5923
# Episode 330 | Train Reward: 87.78667 | Valid G-mean: 0.5249 (Sens: 0.3571, Spec: 0.7714) | Best G: 0.5923
# Episode 340 | Train Reward: 88.56937 | Valid G-mean: 0.5495 (Sens: 0.3857, Spec: 0.7829) | Best G: 0.5923
# Episode 350 | Train Reward: 81.79928 | Valid G-mean: 0.5876 (Sens: 0.4571, Spec: 0.7552) | Best G: 0.5923
# Episode 360 | Train Reward: 75.79387 | Valid G-mean: 0.5520 (Sens: 0.3857, Spec: 0.7898) | Best G: 0.5923
# Episode 370 | Train Reward: 78.34018 | Valid G-mean: 0.5729 (Sens: 0.4143, Spec: 0.7921) | Best G: 0.5923
# Episode 380 | Train Reward: 73.86883 | Valid G-mean: 0.5858 (Sens: 0.4571, Spec: 0.7506) | Best G: 0.5923
# Episode 390 | Train Reward: 91.17730 | Valid G-mean: 0.5544 (Sens: 0.3857, Spec: 0.7968) | Best G: 0.5923
# Episode 400 | Train Reward: 82.77766 | Valid G-mean: 0.5057 (Sens: 0.3286, Spec: 0.7783) | Best G: 0.5923
# Episode 410 | Train Reward: 90.13910 | Valid G-mean: 0.5678 (Sens: 0.4000, Spec: 0.8060) | Best G: 0.5923
# Episode 420 | Train Reward: 93.63351 | Valid G-mean: 0.5645 (Sens: 0.4143, Spec: 0.7691) | Best G: 0.5923
# Episode 430 | Train Reward: 85.76000 | Valid G-mean: 0.4896 (Sens: 0.3000, Spec: 0.7991) | Best G: 0.5923
# Episode 440 | Train Reward: 98.13477 | Valid G-mean: 0.5408 (Sens: 0.3714, Spec: 0.7875) | Best G: 0.5923
# Episode 450 | Train Reward: 86.42595 | Valid G-mean: 0.5233 (Sens: 0.3571, Spec: 0.7667) | Best G: 0.5923
# Episode 460 | Train Reward: 86.66703 | Valid G-mean: 0.5306 (Sens: 0.3857, Spec: 0.7298) | Best G: 0.5923
# Episode 470 | Train Reward: 81.70991 | Valid G-mean: 0.5389 (Sens: 0.3857, Spec: 0.7529) | Best G: 0.5923
# Episode 480 | Train Reward: 85.98450 | Valid G-mean: 0.5073 (Sens: 0.3429, Spec: 0.7506) | Best G: 0.5923
# Episode 490 | Train Reward: 93.56360 | Valid G-mean: 0.5393 (Sens: 0.3714, Spec: 0.7829) | Best G: 0.5923
# Episode 500 | Train Reward: 88.42523 | Valid G-mean: 0.5568 (Sens: 0.4143, Spec: 0.7483) | Best G: 0.5923
# Episode 510 | Train Reward: 86.10559 | Valid G-mean: 0.5057 (Sens: 0.3429, Spec: 0.7460) | Best G: 0.5923
# Episode 520 | Train Reward: 92.61658 | Valid G-mean: 0.5575 (Sens: 0.4286, Spec: 0.7252) | Best G: 0.5923
# Episode 530 | Train Reward: 90.25622 | Valid G-mean: 0.5073 (Sens: 0.3429, Spec: 0.7506) | Best G: 0.5923
# Episode 540 | Train Reward: 86.78919 | Valid G-mean: 0.5585 (Sens: 0.4429, Spec: 0.7044) | Best G: 0.5923
# Episode 550 | Train Reward: 98.31099 | Valid G-mean: 0.4645 (Sens: 0.2857, Spec: 0.7552) | Best G: 0.5923
# Episode 560 | Train Reward: 93.19784 | Valid G-mean: 0.4935 (Sens: 0.3286, Spec: 0.7413) | Best G: 0.5923
# Episode 570 | Train Reward: 97.03640 | Valid G-mean: 0.5042 (Sens: 0.3429, Spec: 0.7413) | Best G: 0.5923
# Episode 580 | Train Reward: 93.84072 | Valid G-mean: 0.5314 (Sens: 0.3857, Spec: 0.7321) | Best G: 0.5923
# Episode 590 | Train Reward: 97.22198 | Valid G-mean: 0.5264 (Sens: 0.3714, Spec: 0.7460) | Best G: 0.5923
# Episode 600 | Train Reward: 98.77369 | Valid G-mean: 0.5496 (Sens: 0.4000, Spec: 0.7552) | Best G: 0.5923
# Episode 610 | Train Reward: 93.34306 | Valid G-mean: 0.5282 (Sens: 0.4000, Spec: 0.6975) | Best G: 0.5923
# Episode 620 | Train Reward: 102.70667 | Valid G-mean: 0.5129 (Sens: 0.3571, Spec: 0.7367) | Best G: 0.5923
# Episode 630 | Train Reward: 94.23207 | Valid G-mean: 0.5339 (Sens: 0.4286, Spec: 0.6651) | Best G: 0.5923
# Episode 640 | Train Reward: 100.62883 | Valid G-mean: 0.5272 (Sens: 0.3857, Spec: 0.7206) | Best G: 0.5923
# Episode 650 | Train Reward: 90.85405 | Valid G-mean: 0.5658 (Sens: 0.4429, Spec: 0.7229) | Best G: 0.5923
# Episode 660 | Train Reward: 94.98811 | Valid G-mean: 0.5640 (Sens: 0.4429, Spec: 0.7182) | Best G: 0.5923
# Episode 670 | Train Reward: 88.67495 | Valid G-mean: 0.5558 (Sens: 0.4429, Spec: 0.6975) | Best G: 0.5923
# Episode 680 | Train Reward: 93.62667 | Valid G-mean: 0.5739 (Sens: 0.4571, Spec: 0.7206) | Best G: 0.5923
# Episode 690 | Train Reward: 94.60685 | Valid G-mean: 0.5429 (Sens: 0.4000, Spec: 0.7367) | Best G: 0.5923
# Episode 700 | Train Reward: 90.01802 | Valid G-mean: 0.5411 (Sens: 0.4000, Spec: 0.7321) | Best G: 0.5923
# Episode 710 | Train Reward: 83.75532 | Valid G-mean: 0.5584 (Sens: 0.4286, Spec: 0.7275) | Best G: 0.5923
# Episode 720 | Train Reward: 95.07604 | Valid G-mean: 0.5557 (Sens: 0.4286, Spec: 0.7206) | Best G: 0.5923
# Episode 730 | Train Reward: 95.07928 | Valid G-mean: 0.5454 (Sens: 0.4000, Spec: 0.7436) | Best G: 0.5923
# Episode 740 | Train Reward: 94.48144 | Valid G-mean: 0.5437 (Sens: 0.4000, Spec: 0.7390) | Best G: 0.5923
# Episode 750 | Train Reward: 90.74739 | Valid G-mean: 0.5658 (Sens: 0.4429, Spec: 0.7229) | Best G: 0.5923
# Episode 760 | Train Reward: 98.41441 | Valid G-mean: 0.5667 (Sens: 0.4429, Spec: 0.7252) | Best G: 0.5923
# Episode 770 | Train Reward: 95.85514 | Valid G-mean: 0.5694 (Sens: 0.4429, Spec: 0.7321) | Best G: 0.5923
# Episode 780 | Train Reward: 98.43315 | Valid G-mean: 0.5715 (Sens: 0.4714, Spec: 0.6928) | Best G: 0.5923
# Episode 790 | Train Reward: 94.81117 | Valid G-mean: 0.5800 (Sens: 0.4714, Spec: 0.7136) | Best G: 0.5923
# Episode 800 | Train Reward: 88.80577 | Valid G-mean: 0.5558 (Sens: 0.4429, Spec: 0.6975) | Best G: 0.5923
# 최종 학습 완료
# Best checkpoint restored: epoch=210, valid_gmean=0.5923
#
# ============================================================
# TEST SET - DDQN 분류 모델 최종 성능 평가
# ============================================================
#
# G-mean: 0.5231
#
# Confusion Matrix:
# [[588 144]
#  [ 60  31]]
#
# TN: 588, FP: 144
# FN: 60, TP: 31
#
# 분류 리포트:
#                     precision    recall  f1-score   support
#
# Class 0 (Negative)       0.91      0.80      0.85       732
# Class 1 (Positive)       0.18      0.34      0.23        91
#
#           accuracy                           0.75       823
#          macro avg       0.54      0.57      0.54       823
#       weighted avg       0.83      0.75      0.78       823
# 상세 메트릭 (Test Set):
# Sensitivity (Recall for Class 1): 0.3407
# Specificity (Recall for Class 0): 0.8033
# Precision (Class 1): 0.1771
# F1-Score: 0.2331
# ============================================================
#
# ============================================================
# VALIDATION SET vs TEST SET 성능 비교
# ============================================================
#
# Validation(Selection) Set - G-mean: 0.5923
# Test Set - G-mean: 0.5231
# Difference (Valid - Test): 0.0692
#
# Validation Confusion Matrix:
# [[343  90]
#  [ 39  31]]
#
# Test Confusion Matrix:
# [[588 144]
#  [ 60  31]]
# ============================================================

# %%
# 전체 데이터의 날짜 인덱스
all_dates = dat.index

# 전체 데이터 피처를 스케일링
# 학습 데이터로 fit된 scaler를 사용하여 전체 데이터를 변환합니다.
full_feature_raw = dat[feature_cols].fillna(0.0).to_numpy()
full_feature = scaler.transform(full_feature_raw).astype(np.float32)

# 최종 모델로 전체 feature에 대한 예측 수행
all_final_predictions = predict_labels_argmax(agent.online_net, full_feature)

# 날짜와 예측된 행동을 포함하는 DataFrame 생성
all_predicted_actions_df = pd.DataFrame({
    'Date': all_dates,
    'Predicted_Action': all_final_predictions
})

# 결과를 새로운 CSV 파일로 저장
output_all_csv_path = '../../data/processed/data_DDQN_predicted.csv'
all_predicted_actions_df.to_csv(output_all_csv_path, index=False)

print(f"전체 데이터에 대한 예측된 행동이 '{output_all_csv_path}' 파일로 성공적으로 저장되었습니다.")
display(all_predicted_actions_df.head())
# Out:
# 전체 데이터에 대한 예측된 행동이 '../../data/processed/data_DDQN_predicted.csv' 파일로 성공적으로 저장되었습니다.
#          Date  Predicted_Action
# 0  2009-04-17                 0
# 1  2009-04-20                 1
# 2  2009-04-21                 1
# 3  2009-04-22                 0
# 4  2009-04-23                 0
