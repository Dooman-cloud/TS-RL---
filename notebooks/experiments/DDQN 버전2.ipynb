# %%
# 랜덤성 제어를 위한 표준 라이브러리 모듈을 불러옵니다.
import random
from collections import deque
from pathlib import Path
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import MinMaxScaler


# 데이터셋을 불러옵니다.
dat = pd.read_csv(Path("../../data/processed/data_selected.csv"), index_col=0)

# 재현 가능한 실험을 위해 시드 값을 고정합니다.
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# GPU가 있으면 CUDA를, 없으면 CPU를 사용하도록 장치를 설정합니다.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# DDQN에서 사용할 Q-Network 구조를 정의합니다.
# 데이터 수가 많지 않으므로 과적합 가능성을 염두에 두고 2개 은닉층을 사용합니다.
class QNetwork(nn.Module):
    def __init__(self, state_dim: int, action_dim: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 96),
            nn.ReLU(),
            nn.Linear(96, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim),
        )

    def forward(self, x):
        return self.net(x)                       # (batch, 2)

# 경험을 저장하고 무작위 샘플링하기 위한 리플레이 버퍼를 정의합니다.
class ReplayBuffer:
    def __init__(self, capacity: int):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size: int):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = map(np.array, zip(*batch))
        return (
            torch.FloatTensor(states).to(device),
            torch.LongTensor(actions).unsqueeze(1).to(device),
            torch.FloatTensor(rewards).unsqueeze(1).to(device),
            torch.FloatTensor(next_states).to(device),
            torch.FloatTensor(dones.astype(np.float32)).unsqueeze(1).to(device),
        )

    def __len__(self):
        return len(self.buffer)


# DDQN 에이전트를 정의합니다.
class DDQNAgent:
    def __init__(
        self,
        state_dim,
        action_dim,
        gamma=0.95,
        lr=5e-4,
        batch_size=64,
        memory_size=100_000,
        target_update=2000,
        epsilon_start=1.0,
        epsilon_end=0.05,
        epsilon_decay=0.995,
    ):
        self.action_dim = action_dim
        self.gamma = gamma
        self.batch_size = batch_size
        self.target_update = target_update

        self.epsilon = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay

        self.online_net = QNetwork(state_dim, action_dim).to(device)
        self.target_net = QNetwork(state_dim, action_dim).to(device)
        self.target_net.load_state_dict(self.online_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.online_net.parameters(), lr=lr)
        self.memory = ReplayBuffer(memory_size)
        self.total_steps = 0

    def act(self, state, epsilon: float = None):
        if epsilon is None:
            epsilon = self.epsilon

        if random.random() < epsilon:
            return random.randrange(self.action_dim)

        state_t = torch.FloatTensor(state).unsqueeze(0).to(device)
        with torch.no_grad():
            q_values = self.online_net(state_t)
        return int(torch.argmax(q_values, dim=1).item())

    def decay_epsilon(self):
        self.epsilon = max(self.epsilon_end, self.epsilon * self.epsilon_decay)

    def update(self):
        if len(self.memory) < self.batch_size:
            return None

        states, actions, rewards, next_states, dones = self.memory.sample(self.batch_size)
        
        #online_net에서 현재 Q값 계산
        q_values = self.online_net(states).gather(1, actions)
        #online_net에서 다음 행동 선택 
        next_actions = self.online_net(next_states).argmax(dim=1, keepdim=True)
        #target_net에서 다음 행동의 Q값 계산
        next_q_values = self.target_net(next_states).gather(1, next_actions)
        target_q = rewards + (1 - dones) * self.gamma * next_q_values
        loss = F.mse_loss(q_values, target_q.detach())
        
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.online_net.parameters(), max_norm=10.0)
        self.optimizer.step()
        self.total_steps += 1
        if self.total_steps % self.target_update == 0:
            self.target_net.load_state_dict(self.online_net.state_dict())
        return float(loss.item())

def encode_risk_labels(series):
    s = series.copy()
    # 문자열 타입이면 'High Risk' → 1, 'Low Risk' → 0 매핑
    if pd.api.types.is_object_dtype(s) or pd.api.types.is_string_dtype(s):
        s = s.map({'Low Risk': 0, 'High Risk': 1})
        if s.isna().any():
            raise ValueError(f"알 수 없는 라벨 값이 있습니다: {series[s.isna()].unique()}")
    # 숫자형이면 그냥 int 변환
    return s.fillna(0).astype(int).to_numpy()

# ---- 데이터 준비 (Train/Valid/Test Split 먼저, 그 후 Scaling) ----

risk_label_col = "Risk_Label"
feature_cols = [c for c in dat.select_dtypes(include=[np.number]).columns if c != risk_label_col]
if len(feature_cols) == 0:
    raise ValueError("학습에 사용할 수치형 feature가 없습니다.")

risk_label_data = encode_risk_labels(dat[risk_label_col])
feature_data_raw = dat[feature_cols].fillna(0.0).to_numpy()
n_steps = len(dat)

train_ratio, valid_ratio, test_ratio = 0.45, 0.35, 0.2
n_train = int(n_steps * train_ratio)
n_valid = int(n_steps * valid_ratio)

train_indices = np.arange(0, n_train)
valid_indices = np.arange(n_train, n_train + n_valid)
test_indices = np.arange(n_train + n_valid, n_steps)

train_feature_raw = feature_data_raw[train_indices]
train_label = risk_label_data[train_indices]

valid_feature_raw = feature_data_raw[valid_indices]
valid_label = risk_label_data[valid_indices]
if len(valid_label) < 2:
    raise ValueError("Validation set 길이가 너무 짧아 tuning/selection 분할이 불가능합니다. split 비율을 조정하세요.")
valid_split_point = int(len(valid_label) * 0.65)
valid_tune_feature_raw = valid_feature_raw[:valid_split_point]
valid_tune_label = valid_label[:valid_split_point]
valid_select_feature_raw = valid_feature_raw[valid_split_point:]
valid_select_label = valid_label[valid_split_point:]

test_feature_raw = feature_data_raw[test_indices]
test_label = risk_label_data[test_indices]

def summarize_class_ratio(name, y):
    n_total = len(y)
    n0 = int((y == 0).sum())
    n1 = int((y == 1).sum())
    r0 = n0 / n_total if n_total > 0 else 0.0
    r1 = n1 / n_total if n_total > 0 else 0.0
    imbalance = (n1 / max(n0, 1)) if n_total > 0 else 0.0
    print(f"{name:>5} | n={n_total:4d} | class0={n0:4d} ({r0:.2%}) | class1={n1:4d} ({r1:.2%}) | c1/c0={imbalance:.4f})")
    if n0 == 0 or n1 == 0:
        raise ValueError(f"{name} set에 클래스 0 또는 1이 없습니다. split 비율 또는 기간을 조정하세요.")

print("Class Ratio Summary (Before ADASYN)")
summarize_class_ratio("Train", train_label)
summarize_class_ratio("ValTun", valid_tune_label)
summarize_class_ratio("ValSel", valid_select_label)
summarize_class_ratio("Test", test_label)

# 보상 계산에 사용할 class_ratio는 원본 train 기준으로 고정합니다.
n_negative_original = (train_label == 0).sum()
n_positive_original = (train_label == 1).sum()
class_ratio_reward = n_positive_original / max(n_negative_original, 1)
print(f"Reward class ratio (original train): {class_ratio_reward:.4f}")

# ---- ADASYN을 적용하지 않고 원본 학습 데이터를 그대로 사용 ----
train_feature = train_feature_raw.astype(np.float32)
train_label = train_label.astype(np.int64)

scaler = MinMaxScaler()
scaler.fit(train_feature)

train_feature = scaler.transform(train_feature).astype(np.float32)
valid_tune_feature = scaler.transform(valid_tune_feature_raw).astype(np.float32)
valid_select_feature = scaler.transform(valid_select_feature_raw).astype(np.float32)
test_feature = scaler.transform(test_feature_raw).astype(np.float32)

print("=" * 60)
print("Data Split Information")
print("=" * 60)
print(f"Total samples: {n_steps}")
print(f"Train set: {len(train_label)} samples")
print(f"  - Class 0: {(train_label==0).sum()}, Class 1: {(train_label==1).sum()}")
print(f"Valid(Tune) set: {len(valid_tune_label)} samples")
print(f"  - Class 0: {(valid_tune_label==0).sum()}, Class 1: {(valid_tune_label==1).sum()}")
print(f"Valid(Select) set: {len(valid_select_label)} samples")
print(f"  - Class 0: {(valid_select_label==0).sum()}, Class 1: {(valid_select_label==1).sum()}")
print(f"Test set: {len(test_indices)} samples ({test_ratio*100:.1f}%)")
print(f"  - Class 0: {(test_label==0).sum()}, Class 1: {(test_label==1).sum()}")

# 원본 학습 세트의 클래스 비율을 그대로 사용합니다.
n_negative = (train_label == 0).sum()
n_positive = (train_label == 1).sum()
class_ratio = class_ratio_reward

print(f"\nClass ratio (train set): {n_positive / max(n_negative, 1):.4f}")
print(f"Class ratio used for reward: {class_ratio:.4f}")
print("=" * 60)

state_dim = len(feature_cols)
action_dim = 2

def compute_reward(action, actual_label, class_ratio):
    action = int(action)
    actual_label = int(actual_label)
    if actual_label == 0:
        if action == 0:
            return class_ratio
        else:
            return -class_ratio*2
    else:
        if action == 1:
            return 1
        else:
            return -1.2
        
# ↓ 여기에 새 함수 추가
# train_label에서 High Risk 인덱스를 미리 계산
high_risk_indices = np.where(train_label == 1)[0]
print(f"High Risk 인덱스 수 (train): {len(high_risk_indices)}")


def get_balanced_start_idx(max_steps, high_risk_prob=0.7):
    """
    high_risk_prob 확률로 High Risk가 윈도우 안에
    반드시 포함되는 start_idx를 반환.
    
    나머지 확률로는 기존 랜덤 방식 사용.
    시계열 순서는 항상 유지됨.
    
    Parameters:
        max_steps: 에피소드 길이 (500)
        high_risk_prob: High Risk 포함 윈도우 선택 확률
    
    Returns:
        start_idx: 에피소드 시작 인덱스
    """
    n = len(train_feature)
    max_start = n - max_steps - 1
    
    if np.random.random() < high_risk_prob:
        # High Risk 인덱스 중 하나를 무작위 선택
        hr_idx = np.random.choice(high_risk_indices)
        
        # 이 hr_idx가 윈도우 안에 포함되는
        # start_idx의 유효 범위 계산:
        # 조건: start_idx <= hr_idx <= start_idx + max_steps - 1
        # → low = hr_idx - max_steps + 1
        # → high = hr_idx
        low  = max(0, hr_idx - max_steps + 1)
        high = min(max_start, hr_idx)
        
        if low > high:
            # 유효 범위가 없으면 (데이터 끝부분 등) 랜덤
            return np.random.randint(0, max_start + 1)
        
        # 유효 범위 안에서 랜덤 선택
        # → High Risk가 윈도우 앞/중간/뒤 어디든 포함됨
        return int(np.random.randint(low, high + 1))
    
    else:
        # 기존 방식: 완전 랜덤
        return int(np.random.randint(0, max_start + 1))
# Out:
# Class Ratio Summary (Before ADASYN)
# Train | n=1848 | class0=1638 (88.64%) | class1= 210 (11.36%) | c1/c0=0.1282)
# ValTun | n= 934 | class0= 829 (88.76%) | class1= 105 (11.24%) | c1/c0=0.1267)
# ValSel | n= 503 | class0= 426 (84.69%) | class1=  77 (15.31%) | c1/c0=0.1808)
#  Test | n= 823 | class0= 724 (87.97%) | class1=  99 (12.03%) | c1/c0=0.1367)
# Reward class ratio (original train): 0.1282
# ============================================================
# Data Split Information
# ============================================================
# Total samples: 4108
# Train set: 1848 samples
#   - Class 0: 1638, Class 1: 210
# Valid(Tune) set: 934 samples
#   - Class 0: 829, Class 1: 105
# Valid(Select) set: 503 samples
#   - Class 0: 426, Class 1: 77
# Test set: 823 samples (20.0%)
#   - Class 0: 724, Class 1: 99
#
# Class ratio (train set): 0.1282
# Class ratio used for reward: 0.1282
# ============================================================
# High Risk 인덱스 수 (train): 210

# %%
# ---- Validation 기반 하이퍼파라미터 Grid Search ----
from itertools import product

param_grid = {
    'gamma': [0.7, 0.9],
    'lr': [1e-4,1e-3],
    'epsilon_decay': [0.99, 0.995],
    'batch_size': [32, 64],
}

def compute_gmean(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0
    gmean = float(np.sqrt(sensitivity * specificity))
    return gmean, sensitivity, specificity

def predict_labels_argmax(model, features):
    preds = []
    with torch.no_grad():
        for t in range(len(features)):
            state_t = torch.FloatTensor(features[t]).unsqueeze(0).to(device)
            q_values = model(state_t)
            preds.append(int(torch.argmax(q_values, dim=1).item()))
    return np.array(preds)

def evaluate_argmax(model, x_valid, y_valid):
    preds = predict_labels_argmax(model, x_valid)
    gmean, sensitivity, specificity = compute_gmean(y_valid, preds)
    return gmean, sensitivity, specificity


#그리드 서치 학습 =============================================
tol = 1e-4
def is_better_metric(new_gmean, new_recall, best_gmean, best_recall):
    return (new_gmean > best_gmean) or (
        new_gmean == best_gmean and new_recall > best_recall
    )

grid_search_results = []
param_combinations = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

print("\n" + "=" * 80)
print(f"HYPERPARAMETER GRID SEARCH (Total: {len(param_combinations)} combinations)")
print("=" * 80)

patience = 25
min_episodes = 60
best_overall_select_gmean = -1.0
best_overall_select_recall = -1.0
best_overall_params = None

for idx, params in enumerate(param_combinations):
    param_dict = dict(zip(param_names, params))
    gamma, lr, epsilon_decay, batch_size = params
    # 각 조합마다 동일한 초기 조건으로 시작
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    print(f"\n[{idx+1}/{len(param_combinations)}] gamma={gamma:.2f}, lr={lr:.0e}, eps_decay={epsilon_decay:.3f}, bs={batch_size}")

    agent_tune = DDQNAgent(
        state_dim=state_dim,
        action_dim=action_dim,
        gamma=gamma,
        lr=lr,
        batch_size=batch_size,
        memory_size=50_000,
        target_update=2000,
        epsilon_start=1.0,
        epsilon_end=0.05,
        epsilon_decay=epsilon_decay,
    )

    episodes_tune = 200
    max_steps_tune = 500
    best_tune_gmean = 0.0
    best_tune_state_dict = None
    patience_counter = 0

    for ep in range(1, episodes_tune + 1):
        start_idx = get_balanced_start_idx(max_steps_tune, high_risk_prob=0.7)
        episode_reward = 0.0

        for i in range(max_steps_tune):
            state = train_feature[start_idx + i]
            next_state = train_feature[start_idx + i + 1] if start_idx + i + 1 < len(train_feature) else train_feature[start_idx + i]
            actual_label = train_label[start_idx + i]

            action = agent_tune.act(state)
            reward = compute_reward(action, actual_label, class_ratio)
            done = i == (max_steps_tune - 1)

            agent_tune.memory.push(state, action, reward, next_state, done)
            _ = agent_tune.update()
            episode_reward += reward

        agent_tune.decay_epsilon()

    # 5 에피소드마다 tune 데이터로 검증을 수행하여 G-mean이 개선되는지 확인=================================
        if ep % 5 == 0:
            agent_tune.online_net.eval()
            tune_gmean, tune_sensitivity, tune_specificity = evaluate_argmax(
                agent_tune.online_net, valid_tune_feature, valid_tune_label
            )
            agent_tune.online_net.train()

            if tune_gmean > best_tune_gmean:
                best_tune_gmean = tune_gmean
                patience_counter = 0
                best_tune_state_dict = {k: v.detach().cpu().clone() for k, v in agent_tune.online_net.state_dict().items()}
            else:
                patience_counter += 1

            if ep % 20 == 0:
                print(f"  Ep {ep:3d} | Tune G-mean: {tune_gmean:.4f} (Sens: {tune_sensitivity:.4f}, Spec: {tune_specificity:.4f}) | Best: {best_tune_gmean:.4f}")

            if ep > min_episodes and patience_counter >= patience:
                break
# Tune에서 가장 좋은 모델로 Selection 데이터에 대한 최종 평가를 수행합니다====================

    agent_tune.online_net.eval()
    if best_tune_state_dict is not None:
        agent_tune.online_net.load_state_dict(best_tune_state_dict)
    select_gmean, select_sensitivity, select_specificity = evaluate_argmax(
        agent_tune.online_net, valid_select_feature, valid_select_label
    )

    grid_search_results.append({
        'params': param_dict,
        'best_tune_gmean': best_tune_gmean,
        'select_gmean': select_gmean,
        'select_sensitivity': select_sensitivity,
        'select_specificity': select_specificity,
    })

    if is_better_metric(
        select_gmean,
        select_sensitivity,
        best_overall_select_gmean,
        best_overall_select_recall
    ):
        best_overall_select_gmean = select_gmean
        best_overall_select_recall = select_sensitivity
        best_overall_params = param_dict

grid_search_results.sort(key=lambda x: x['select_gmean'], reverse=True)

print("\n" + "=" * 80)
print("TOP 5 HYPERPARAMETERS")
print("=" * 80)
for i, result in enumerate(grid_search_results[:5]):
    print(f"{i+1}. Select G-mean: {result['select_gmean']:.4f} | Tune Best: {result['best_tune_gmean']:.4f} | Params: {result['params']}")

print("\n" + "=" * 80)
print("BEST HYPERPARAMETERS")
print("=" * 80)
for k, v in best_overall_params.items():
    print(f"{k}: {v}")
print(f"Best Selection G-mean: {best_overall_select_gmean:.4f}")
print("=" * 80)

# ---- 최적 파라미터로 본 학습 ----
print("\nTraining with best hyperparameters...")
agent = DDQNAgent(
    state_dim=state_dim,
    action_dim=action_dim,
    gamma=best_overall_params['gamma'],
    lr=best_overall_params['lr'],
    batch_size=best_overall_params['batch_size'],
    memory_size=50_000,
    target_update=2000,
    epsilon_start=1.0,
    epsilon_end=0.05,
    epsilon_decay=best_overall_params['epsilon_decay'],
)

episodes = 800
max_steps = 500
scores = []
valid_scores = []
best_ckpt_valid_gmean = -1.0
best_ckpt_epoch = 0
best_ckpt_state_dict = None

for ep in range(1, episodes + 1):
    episode_reward = 0.0
    start_idx = get_balanced_start_idx(max_steps, high_risk_prob=0.7)

    for i in range(max_steps):
        state = train_feature[start_idx + i]
        next_state = train_feature[start_idx + i + 1] if start_idx + i + 1 < len(train_feature) else train_feature[start_idx + i]
        actual_label = train_label[start_idx + i]

        action = agent.act(state)
        reward = compute_reward(action, actual_label, class_ratio)
        done = i == (max_steps - 1)

        agent.memory.push(state, action, reward, next_state, done)
        _ = agent.update()
        episode_reward += reward

    agent.decay_epsilon()
    scores.append(episode_reward)

    if ep % 10 == 0:
        agent.online_net.eval()
        valid_gmean, valid_sensitivity, valid_specificity = evaluate_argmax(
            agent.online_net, valid_select_feature, valid_select_label
        )
        valid_scores.append(valid_gmean)

        if valid_gmean > best_ckpt_valid_gmean:
            best_ckpt_valid_gmean = valid_gmean
            best_ckpt_epoch = ep
            best_ckpt_state_dict = {k: v.detach().cpu().clone() for k, v in agent.online_net.state_dict().items()}
        agent.online_net.train()

        print(f"Episode {ep:3d} | Train Reward: {np.mean(scores[-10:]):8.5f} | Valid G-mean: {valid_gmean:.4f} (Sens: {valid_sensitivity:.4f}, Spec: {valid_specificity:.4f}) | Best G: {best_ckpt_valid_gmean:.4f}")

print("최종 학습 완료")
if best_ckpt_state_dict is not None:
    agent.online_net.load_state_dict(best_ckpt_state_dict)
    agent.target_net.load_state_dict(best_ckpt_state_dict)
    print(f"Best checkpoint restored: epoch={best_ckpt_epoch}, valid_gmean={best_ckpt_valid_gmean:.4f}")

agent.online_net.eval()

# ---- Test 평가 ----
test_predictions = predict_labels_argmax(agent.online_net, test_feature)

cm_test = confusion_matrix(test_label, test_predictions, labels=[0, 1])
tn, fp, fn, tp = cm_test.ravel()
sensitivity_test = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity_test = tn / (tn + fp) if (tn + fp) > 0 else 0
gmean_test = np.sqrt(sensitivity_test * specificity_test)

print("\n" + "=" * 60)
print("TEST SET - DDQN 분류 모델 최종 성능 평가")
print("=" * 60)
print(f"\nG-mean: {gmean_test:.4f}")
print(f"\nConfusion Matrix:")
print(cm_test)
print(f"\nTN: {cm_test[0, 0]}, FP: {cm_test[0, 1]}")
print(f"FN: {cm_test[1, 0]}, TP: {cm_test[1, 1]}")

print(f"\n분류 리포트:")
print(classification_report(test_label, test_predictions,
                          labels=[0, 1],
                          target_names=['Class 0 (Negative)', 'Class 1 (Positive)'],
                          zero_division=0))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax1 = axes[0]
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Blues', cbar=False, ax=ax1,
            xticklabels=['Pred 0', 'Pred 1'],
            yticklabels=['Actual 0', 'Actual 1'])
ax1.set_title('Test Set - Confusion Matrix (Count)', fontsize=12, fontweight='bold')
ax1.set_ylabel('True Label')
ax1.set_xlabel('Predicted Label')

cm_test_row_sums = cm_test.sum(axis=1, keepdims=True)
cm_test_percent = np.divide(cm_test.astype(float), cm_test_row_sums,
                             out=np.zeros_like(cm_test, dtype=float),
                             where=cm_test_row_sums != 0) * 100
ax2 = axes[1]
sns.heatmap(cm_test_percent, annot=True, fmt='.2f', cmap='Blues', cbar=True, ax=ax2,
            xticklabels=['Pred 0', 'Pred 1'],
            yticklabels=['Actual 0', 'Actual 1'],
            cbar_kws={'label': 'Percentage (%)'})
ax2.set_title('Test Set - Confusion Matrix (Percentage)', fontsize=12, fontweight='bold')
ax2.set_ylabel('True Label')
ax2.set_xlabel('Predicted Label')

plt.tight_layout()
plt.show()

precision = tp / (tp + fp) if (tp + fp) > 0 else 0
f1_score_val = 2 * (precision * sensitivity_test) / (precision + sensitivity_test) if (precision + sensitivity_test) > 0 else 0

print(f"\n상세 메트릭 (Test Set):")
print(f"Sensitivity (Recall for Class 1): {sensitivity_test:.4f}")
print(f"Specificity (Recall for Class 0): {specificity_test:.4f}")
print(f"Precision (Class 1): {precision:.4f}")
print(f"F1-Score: {f1_score_val:.4f}")
print("=" * 60)

print("\n" + "=" * 60)
print("VALIDATION SET vs TEST SET 성능 비교")
print("=" * 60)

agent.online_net.eval()
valid_predictions = predict_labels_argmax(agent.online_net, valid_select_feature)
cm_valid = confusion_matrix(valid_select_label, valid_predictions, labels=[0, 1])
tn_v, fp_v, fn_v, tp_v = cm_valid.ravel()
sensitivity_valid = tp_v / (tp_v + fn_v) if (tp_v + fn_v) > 0 else 0
specificity_valid = tn_v / (tn_v + fp_v) if (tn_v + fp_v) > 0 else 0
gmean_valid = np.sqrt(sensitivity_valid * specificity_valid)

print(f"\nValidation(Selection) Set - G-mean: {gmean_valid:.4f}")
print(f"Test Set - G-mean: {gmean_test:.4f}")
print(f"Difference (Valid - Test): {gmean_valid - gmean_test:.4f}")
print("\nValidation Confusion Matrix:")
print(cm_valid)
print("\nTest Confusion Matrix:")
print(cm_test)
print("=" * 60)
# Out:
# ================================================================================
# HYPERPARAMETER GRID SEARCH (Total: 16 combinations)
# ================================================================================
#
# [1/16] gamma=0.70, lr=1e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6420 (Sens: 0.5714, Spec: 0.7214) | Best: 0.6420
#   Ep  40 | Tune G-mean: 0.6106 (Sens: 0.4571, Spec: 0.8154) | Best: 0.6420
#   Ep  60 | Tune G-mean: 0.6298 (Sens: 0.4952, Spec: 0.8010) | Best: 0.6521
#   Ep  80 | Tune G-mean: 0.6418 (Sens: 0.5143, Spec: 0.8010) | Best: 0.6602
#   Ep 100 | Tune G-mean: 0.6576 (Sens: 0.5619, Spec: 0.7696) | Best: 0.6602
#   Ep 120 | Tune G-mean: 0.6155 (Sens: 0.4571, Spec: 0.8287) | Best: 0.6638
#   Ep 140 | Tune G-mean: 0.6388 (Sens: 0.4952, Spec: 0.8239) | Best: 0.6638
#   Ep 160 | Tune G-mean: 0.6363 (Sens: 0.5048, Spec: 0.8022) | Best: 0.6638
#   Ep 180 | Tune G-mean: 0.6355 (Sens: 0.4952, Spec: 0.8154) | Best: 0.6638
#   Ep 200 | Tune G-mean: 0.6244 (Sens: 0.5238, Spec: 0.7443) | Best: 0.6638
#
# [2/16] gamma=0.70, lr=1e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5914 (Sens: 0.4190, Spec: 0.8347) | Best: 0.6503
#   Ep  40 | Tune G-mean: 0.6535 (Sens: 0.5524, Spec: 0.7732) | Best: 0.6535
#   Ep  60 | Tune G-mean: 0.6340 (Sens: 0.5143, Spec: 0.7817) | Best: 0.6535
#   Ep  80 | Tune G-mean: 0.6687 (Sens: 0.5810, Spec: 0.7696) | Best: 0.6687
#   Ep 100 | Tune G-mean: 0.6461 (Sens: 0.5143, Spec: 0.8118) | Best: 0.6687
#   Ep 120 | Tune G-mean: 0.6298 (Sens: 0.4952, Spec: 0.8010) | Best: 0.6687
#   Ep 140 | Tune G-mean: 0.6360 (Sens: 0.5143, Spec: 0.7865) | Best: 0.6687
#   Ep 160 | Tune G-mean: 0.6484 (Sens: 0.5524, Spec: 0.7612) | Best: 0.6687
#   Ep 180 | Tune G-mean: 0.5965 (Sens: 0.4190, Spec: 0.8492) | Best: 0.6687
#   Ep 200 | Tune G-mean: 0.6537 (Sens: 0.5714, Spec: 0.7479) | Best: 0.6687
#
# [3/16] gamma=0.70, lr=1e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6035 (Sens: 0.4762, Spec: 0.7648) | Best: 0.6625
#   Ep  40 | Tune G-mean: 0.6052 (Sens: 0.4381, Spec: 0.8359) | Best: 0.6625
#   Ep  60 | Tune G-mean: 0.6659 (Sens: 0.6095, Spec: 0.7274) | Best: 0.6659
#   Ep  80 | Tune G-mean: 0.6406 (Sens: 0.4952, Spec: 0.8287) | Best: 0.6659
#   Ep 100 | Tune G-mean: 0.6584 (Sens: 0.5429, Spec: 0.7986) | Best: 0.6659
#   Ep 120 | Tune G-mean: 0.6638 (Sens: 0.6476, Spec: 0.6803) | Best: 0.6676
#   Ep 140 | Tune G-mean: 0.6467 (Sens: 0.5333, Spec: 0.7841) | Best: 0.6676
#   Ep 160 | Tune G-mean: 0.6301 (Sens: 0.5048, Spec: 0.7865) | Best: 0.6676
#   Ep 180 | Tune G-mean: 0.6182 (Sens: 0.4667, Spec: 0.8191) | Best: 0.6676
#   Ep 200 | Tune G-mean: 0.6389 (Sens: 0.5238, Spec: 0.7793) | Best: 0.6676
#
# [4/16] gamma=0.70, lr=1e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.6356 (Sens: 0.5429, Spec: 0.7443) | Best: 0.6483
#   Ep  40 | Tune G-mean: 0.6495 (Sens: 0.5714, Spec: 0.7382) | Best: 0.6515
#   Ep  60 | Tune G-mean: 0.6309 (Sens: 0.5238, Spec: 0.7600) | Best: 0.6515
#   Ep  80 | Tune G-mean: 0.6477 (Sens: 0.5333, Spec: 0.7865) | Best: 0.6515
#   Ep 100 | Tune G-mean: 0.6083 (Sens: 0.4571, Spec: 0.8094) | Best: 0.6515
#   Ep 120 | Tune G-mean: 0.6245 (Sens: 0.4762, Spec: 0.8191) | Best: 0.6515
#   Ep 140 | Tune G-mean: 0.6183 (Sens: 0.4952, Spec: 0.7720) | Best: 0.6515
#   Ep 160 | Tune G-mean: 0.6451 (Sens: 0.5619, Spec: 0.7407) | Best: 0.6515
#
# [5/16] gamma=0.70, lr=1e-03, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.5665 (Sens: 0.3619, Spec: 0.8866) | Best: 0.6965
#   Ep  40 | Tune G-mean: 0.6066 (Sens: 0.4190, Spec: 0.8782) | Best: 0.6965
#   Ep  60 | Tune G-mean: 0.6162 (Sens: 0.5238, Spec: 0.7250) | Best: 0.6965
#   Ep  80 | Tune G-mean: 0.5742 (Sens: 0.4571, Spec: 0.7214) | Best: 0.6965
#   Ep 100 | Tune G-mean: 0.5443 (Sens: 0.4190, Spec: 0.7069) | Best: 0.6965
#   Ep 120 | Tune G-mean: 0.5430 (Sens: 0.4476, Spec: 0.6586) | Best: 0.6965
#
# [6/16] gamma=0.70, lr=1e-03, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5588 (Sens: 0.3905, Spec: 0.7998) | Best: 0.6430
#   Ep  40 | Tune G-mean: 0.5486 (Sens: 0.3810, Spec: 0.7901) | Best: 0.6430
#   Ep  60 | Tune G-mean: 0.5626 (Sens: 0.4571, Spec: 0.6924) | Best: 0.6430
#   Ep  80 | Tune G-mean: 0.5643 (Sens: 0.4952, Spec: 0.6429) | Best: 0.6430
#   Ep 100 | Tune G-mean: 0.5886 (Sens: 0.4952, Spec: 0.6996) | Best: 0.6430
#   Ep 120 | Tune G-mean: 0.5915 (Sens: 0.5524, Spec: 0.6333) | Best: 0.6430
#
# [7/16] gamma=0.70, lr=1e-03, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6187 (Sens: 0.4667, Spec: 0.8203) | Best: 0.6819
#   Ep  40 | Tune G-mean: 0.5956 (Sens: 0.4095, Spec: 0.8661) | Best: 0.6819
#   Ep  60 | Tune G-mean: 0.6139 (Sens: 0.4476, Spec: 0.8420) | Best: 0.6819
#   Ep  80 | Tune G-mean: 0.6047 (Sens: 0.4952, Spec: 0.7382) | Best: 0.6819
#   Ep 100 | Tune G-mean: 0.5652 (Sens: 0.4190, Spec: 0.7624) | Best: 0.6819
#   Ep 120 | Tune G-mean: 0.5458 (Sens: 0.4095, Spec: 0.7274) | Best: 0.6819
#
# [8/16] gamma=0.70, lr=1e-03, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.5728 (Sens: 0.4000, Spec: 0.8203) | Best: 0.6401
#   Ep  40 | Tune G-mean: 0.6171 (Sens: 0.4857, Spec: 0.7841) | Best: 0.6401
#   Ep  60 | Tune G-mean: 0.5950 (Sens: 0.4667, Spec: 0.7587) | Best: 0.6401
#   Ep  80 | Tune G-mean: 0.5943 (Sens: 0.5238, Spec: 0.6743) | Best: 0.6401
#   Ep 100 | Tune G-mean: 0.5978 (Sens: 0.4857, Spec: 0.7358) | Best: 0.6401
#   Ep 120 | Tune G-mean: 0.5718 (Sens: 0.4857, Spec: 0.6731) | Best: 0.6401
#
# [9/16] gamma=0.90, lr=1e-04, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.6393 (Sens: 0.5714, Spec: 0.7153) | Best: 0.6479
#   Ep  40 | Tune G-mean: 0.6270 (Sens: 0.4857, Spec: 0.8094) | Best: 0.6479
#   Ep  60 | Tune G-mean: 0.6233 (Sens: 0.4857, Spec: 0.7998) | Best: 0.6479
#   Ep  80 | Tune G-mean: 0.6477 (Sens: 0.5238, Spec: 0.8010) | Best: 0.6723
#   Ep 100 | Tune G-mean: 0.6534 (Sens: 0.5429, Spec: 0.7865) | Best: 0.6723
#   Ep 120 | Tune G-mean: 0.6112 (Sens: 0.4381, Spec: 0.8528) | Best: 0.6723
#   Ep 140 | Tune G-mean: 0.6519 (Sens: 0.5143, Spec: 0.8263) | Best: 0.6723
#   Ep 160 | Tune G-mean: 0.6706 (Sens: 0.5524, Spec: 0.8142) | Best: 0.6723
#   Ep 180 | Tune G-mean: 0.6599 (Sens: 0.5429, Spec: 0.8022) | Best: 0.6723
#   Ep 200 | Tune G-mean: 0.6600 (Sens: 0.5714, Spec: 0.7624) | Best: 0.6757
#
# [10/16] gamma=0.90, lr=1e-04, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5889 (Sens: 0.4190, Spec: 0.8275) | Best: 0.6543
#   Ep  40 | Tune G-mean: 0.6479 (Sens: 0.5524, Spec: 0.7600) | Best: 0.6543
#   Ep  60 | Tune G-mean: 0.6418 (Sens: 0.5429, Spec: 0.7587) | Best: 0.6543
#   Ep  80 | Tune G-mean: 0.6634 (Sens: 0.5810, Spec: 0.7575) | Best: 0.6634
#   Ep 100 | Tune G-mean: 0.6312 (Sens: 0.4952, Spec: 0.8046) | Best: 0.6634
#   Ep 120 | Tune G-mean: 0.6574 (Sens: 0.5714, Spec: 0.7563) | Best: 0.6634
#   Ep 140 | Tune G-mean: 0.6535 (Sens: 0.5524, Spec: 0.7732) | Best: 0.6634
#   Ep 160 | Tune G-mean: 0.6546 (Sens: 0.6000, Spec: 0.7141) | Best: 0.6634
#   Ep 180 | Tune G-mean: 0.6073 (Sens: 0.4381, Spec: 0.8420) | Best: 0.6634
#   Ep 200 | Tune G-mean: 0.6299 (Sens: 0.5429, Spec: 0.7310) | Best: 0.6634
#
# [11/16] gamma=0.90, lr=1e-04, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.6212 (Sens: 0.4952, Spec: 0.7793) | Best: 0.6623
#   Ep  40 | Tune G-mean: 0.5986 (Sens: 0.4286, Spec: 0.8359) | Best: 0.6623
#   Ep  60 | Tune G-mean: 0.6543 (Sens: 0.5905, Spec: 0.7250) | Best: 0.6623
#   Ep  80 | Tune G-mean: 0.6250 (Sens: 0.4667, Spec: 0.8372) | Best: 0.6623
#   Ep 100 | Tune G-mean: 0.6624 (Sens: 0.5429, Spec: 0.8082) | Best: 0.6624
#   Ep 120 | Tune G-mean: 0.6656 (Sens: 0.5905, Spec: 0.7503) | Best: 0.6699
#   Ep 140 | Tune G-mean: 0.6531 (Sens: 0.5333, Spec: 0.7998) | Best: 0.6699
#   Ep 160 | Tune G-mean: 0.6585 (Sens: 0.5333, Spec: 0.8130) | Best: 0.6699
#   Ep 180 | Tune G-mean: 0.6570 (Sens: 0.5333, Spec: 0.8094) | Best: 0.6699
#   Ep 200 | Tune G-mean: 0.6688 (Sens: 0.5619, Spec: 0.7961) | Best: 0.6699
#
# [12/16] gamma=0.90, lr=1e-04, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.6451 (Sens: 0.5619, Spec: 0.7407) | Best: 0.6495
#   Ep  40 | Tune G-mean: 0.6549 (Sens: 0.5810, Spec: 0.7382) | Best: 0.6581
#   Ep  60 | Tune G-mean: 0.6453 (Sens: 0.5429, Spec: 0.7672) | Best: 0.6590
#   Ep  80 | Tune G-mean: 0.6477 (Sens: 0.5333, Spec: 0.7865) | Best: 0.6590
#   Ep 100 | Tune G-mean: 0.6579 (Sens: 0.5429, Spec: 0.7973) | Best: 0.6590
#   Ep 120 | Tune G-mean: 0.6407 (Sens: 0.5333, Spec: 0.7696) | Best: 0.6590
#   Ep 140 | Tune G-mean: 0.6360 (Sens: 0.5143, Spec: 0.7865) | Best: 0.6590
#   Ep 160 | Tune G-mean: 0.6252 (Sens: 0.5143, Spec: 0.7600) | Best: 0.6590
#   Ep 180 | Tune G-mean: 0.5894 (Sens: 0.4286, Spec: 0.8106) | Best: 0.6590
#
# [13/16] gamma=0.90, lr=1e-03, eps_decay=0.990, bs=32
#   Ep  20 | Tune G-mean: 0.5645 (Sens: 0.3619, Spec: 0.8806) | Best: 0.6341
#   Ep  40 | Tune G-mean: 0.5567 (Sens: 0.3619, Spec: 0.8565) | Best: 0.6341
#   Ep  60 | Tune G-mean: 0.5969 (Sens: 0.4667, Spec: 0.7636) | Best: 0.6341
#   Ep  80 | Tune G-mean: 0.6001 (Sens: 0.4762, Spec: 0.7563) | Best: 0.6341
#   Ep 100 | Tune G-mean: 0.5953 (Sens: 0.6095, Spec: 0.5814) | Best: 0.6341
#   Ep 120 | Tune G-mean: 0.5779 (Sens: 0.4381, Spec: 0.7624) | Best: 0.6341
#
# [14/16] gamma=0.90, lr=1e-03, eps_decay=0.990, bs=64
#   Ep  20 | Tune G-mean: 0.5853 (Sens: 0.4000, Spec: 0.8565) | Best: 0.6244
#   Ep  40 | Tune G-mean: 0.5720 (Sens: 0.4476, Spec: 0.7310) | Best: 0.6244
#   Ep  60 | Tune G-mean: 0.5497 (Sens: 0.4571, Spec: 0.6610) | Best: 0.6244
#   Ep  80 | Tune G-mean: 0.5611 (Sens: 0.4571, Spec: 0.6888) | Best: 0.6244
#   Ep 100 | Tune G-mean: 0.6012 (Sens: 0.5429, Spec: 0.6659) | Best: 0.6244
#   Ep 120 | Tune G-mean: 0.5929 (Sens: 0.5714, Spec: 0.6152) | Best: 0.6244
#
# [15/16] gamma=0.90, lr=1e-03, eps_decay=0.995, bs=32
#   Ep  20 | Tune G-mean: 0.5927 (Sens: 0.4190, Spec: 0.8384) | Best: 0.6728
#   Ep  40 | Tune G-mean: 0.6017 (Sens: 0.4381, Spec: 0.8263) | Best: 0.6728
#   Ep  60 | Tune G-mean: 0.5987 (Sens: 0.4571, Spec: 0.7841) | Best: 0.6728
#   Ep  80 | Tune G-mean: 0.5860 (Sens: 0.4857, Spec: 0.7069) | Best: 0.6728
#   Ep 100 | Tune G-mean: 0.5199 (Sens: 0.3524, Spec: 0.7672) | Best: 0.6728
#   Ep 120 | Tune G-mean: 0.5277 (Sens: 0.4381, Spec: 0.6357) | Best: 0.6728
#
# [16/16] gamma=0.90, lr=1e-03, eps_decay=0.995, bs=64
#   Ep  20 | Tune G-mean: 0.6553 (Sens: 0.5714, Spec: 0.7515) | Best: 0.6553
#   Ep  40 | Tune G-mean: 0.5907 (Sens: 0.4286, Spec: 0.8142) | Best: 0.6553
#   Ep  60 | Tune G-mean: 0.5596 (Sens: 0.4095, Spec: 0.7648) | Best: 0.6553
#   Ep  80 | Tune G-mean: 0.5551 (Sens: 0.4857, Spec: 0.6345) | Best: 0.6553
#   Ep 100 | Tune G-mean: 0.5564 (Sens: 0.4667, Spec: 0.6634) | Best: 0.6553
#   Ep 120 | Tune G-mean: 0.5727 (Sens: 0.4952, Spec: 0.6622) | Best: 0.6553
#   Ep 140 | Tune G-mean: 0.5840 (Sens: 0.4952, Spec: 0.6888) | Best: 0.6553
#
# ================================================================================
# TOP 5 HYPERPARAMETERS
# ================================================================================
# 1. Select G-mean: 0.6691 | Tune Best: 0.6515 | Params: {'gamma': 0.7, 'lr': 0.0001, 'epsilon_decay': 0.995, 'batch_size': 64}
# 2. Select G-mean: 0.6639 | Tune Best: 0.6430 | Params: {'gamma': 0.7, 'lr': 0.001, 'epsilon_decay': 0.99, 'batch_size': 64}
# 3. Select G-mean: 0.6639 | Tune Best: 0.6401 | Params: {'gamma': 0.7, 'lr': 0.001, 'epsilon_decay': 0.995, 'batch_size': 64}
# 4. Select G-mean: 0.6551 | Tune Best: 0.6244 | Params: {'gamma': 0.9, 'lr': 0.001, 'epsilon_decay': 0.99, 'batch_size': 64}
# 5. Select G-mean: 0.6520 | Tune Best: 0.6634 | Params: {'gamma': 0.9, 'lr': 0.0001, 'epsilon_decay': 0.99, 'batch_size': 64}
#
# ================================================================================
# BEST HYPERPARAMETERS
# ================================================================================
# gamma: 0.7
# lr: 0.0001
# epsilon_decay: 0.995
# batch_size: 64
# Best Selection G-mean: 0.6691
# ================================================================================
#
# Training with best hyperparameters...
# Episode  10 | Train Reward: -34.33846 | Valid G-mean: 0.6610 (Sens: 0.6623, Spec: 0.6596) | Best G: 0.6610
# Episode  20 | Train Reward: -26.91436 | Valid G-mean: 0.6374 (Sens: 0.6364, Spec: 0.6385) | Best G: 0.6610
# Episode  30 | Train Reward: -27.08821 | Valid G-mean: 0.6398 (Sens: 0.6364, Spec: 0.6432) | Best G: 0.6610
# Episode  40 | Train Reward: -21.01641 | Valid G-mean: 0.6135 (Sens: 0.5455, Spec: 0.6901) | Best G: 0.6610
# Episode  50 | Train Reward: -19.70205 | Valid G-mean: 0.6109 (Sens: 0.5195, Spec: 0.7183) | Best G: 0.6610
# Episode  60 | Train Reward: -15.60872 | Valid G-mean: 0.6208 (Sens: 0.5455, Spec: 0.7066) | Best G: 0.6610
# Episode  70 | Train Reward: -11.26513 | Valid G-mean: 0.6012 (Sens: 0.4935, Spec: 0.7324) | Best G: 0.6610
# Episode  80 | Train Reward: -5.29641 | Valid G-mean: 0.5835 (Sens: 0.4156, Spec: 0.8192) | Best G: 0.6610
# Episode  90 | Train Reward: -1.53897 | Valid G-mean: 0.6060 (Sens: 0.4935, Spec: 0.7441) | Best G: 0.6610
# Episode 100 | Train Reward: -4.80051 | Valid G-mean: 0.5984 (Sens: 0.5844, Spec: 0.6127) | Best G: 0.6610
# Episode 110 | Train Reward:  3.53590 | Valid G-mean: 0.5934 (Sens: 0.5455, Spec: 0.6455) | Best G: 0.6610
# Episode 120 | Train Reward:  2.86205 | Valid G-mean: 0.5863 (Sens: 0.5325, Spec: 0.6455) | Best G: 0.6610
# Episode 130 | Train Reward:  8.10769 | Valid G-mean: 0.5847 (Sens: 0.5455, Spec: 0.6268) | Best G: 0.6610
# Episode 140 | Train Reward:  9.37128 | Valid G-mean: 0.5786 (Sens: 0.4935, Spec: 0.6784) | Best G: 0.6610
# Episode 150 | Train Reward: 12.93026 | Valid G-mean: 0.5687 (Sens: 0.5065, Spec: 0.6385) | Best G: 0.6610
# Episode 160 | Train Reward: 17.17077 | Valid G-mean: 0.5837 (Sens: 0.4805, Spec: 0.7089) | Best G: 0.6610
# Episode 170 | Train Reward: 20.79487 | Valid G-mean: 0.5823 (Sens: 0.4675, Spec: 0.7254) | Best G: 0.6610
# Episode 180 | Train Reward: 17.00718 | Valid G-mean: 0.5866 (Sens: 0.4935, Spec: 0.6972) | Best G: 0.6610
# Episode 190 | Train Reward: 27.91487 | Valid G-mean: 0.5751 (Sens: 0.4545, Spec: 0.7277) | Best G: 0.6610
# Episode 200 | Train Reward: 26.71436 | Valid G-mean: 0.5581 (Sens: 0.5065, Spec: 0.6150) | Best G: 0.6610
# Episode 210 | Train Reward: 31.42667 | Valid G-mean: 0.5457 (Sens: 0.4286, Spec: 0.6948) | Best G: 0.6610
# Episode 220 | Train Reward: 32.88256 | Valid G-mean: 0.5603 (Sens: 0.5065, Spec: 0.6197) | Best G: 0.6610
# Episode 230 | Train Reward: 30.46667 | Valid G-mean: 0.5565 (Sens: 0.5195, Spec: 0.5962) | Best G: 0.6610
# Episode 240 | Train Reward: 28.08615 | Valid G-mean: 0.5362 (Sens: 0.4675, Spec: 0.6150) | Best G: 0.6610
# Episode 250 | Train Reward: 38.42103 | Valid G-mean: 0.5208 (Sens: 0.4156, Spec: 0.6526) | Best G: 0.6610
# Episode 260 | Train Reward: 34.82308 | Valid G-mean: 0.4884 (Sens: 0.3117, Spec: 0.7653) | Best G: 0.6610
# Episode 270 | Train Reward: 34.64974 | Valid G-mean: 0.5079 (Sens: 0.4026, Spec: 0.6408) | Best G: 0.6610
# Episode 280 | Train Reward: 53.58051 | Valid G-mean: 0.4904 (Sens: 0.3766, Spec: 0.6385) | Best G: 0.6610
# Episode 290 | Train Reward: 46.98103 | Valid G-mean: 0.4813 (Sens: 0.3247, Spec: 0.7136) | Best G: 0.6610
# Episode 300 | Train Reward: 42.46718 | Valid G-mean: 0.4790 (Sens: 0.3247, Spec: 0.7066) | Best G: 0.6610
# Episode 310 | Train Reward: 52.63795 | Valid G-mean: 0.4774 (Sens: 0.3247, Spec: 0.7019) | Best G: 0.6610
# Episode 320 | Train Reward: 58.87487 | Valid G-mean: 0.4811 (Sens: 0.3377, Spec: 0.6854) | Best G: 0.6610
# Episode 330 | Train Reward: 50.92923 | Valid G-mean: 0.4860 (Sens: 0.3377, Spec: 0.6995) | Best G: 0.6610
# Episode 340 | Train Reward: 46.90308 | Valid G-mean: 0.4819 (Sens: 0.3377, Spec: 0.6878) | Best G: 0.6610
# Episode 350 | Train Reward: 56.67641 | Valid G-mean: 0.4750 (Sens: 0.3247, Spec: 0.6948) | Best G: 0.6610
# Episode 360 | Train Reward: 52.45538 | Valid G-mean: 0.5011 (Sens: 0.3766, Spec: 0.6667) | Best G: 0.6610
# Episode 370 | Train Reward: 62.41641 | Valid G-mean: 0.5250 (Sens: 0.4286, Spec: 0.6432) | Best G: 0.6610
# Episode 380 | Train Reward: 61.31128 | Valid G-mean: 0.5288 (Sens: 0.4286, Spec: 0.6526) | Best G: 0.6610
# Episode 390 | Train Reward: 63.19231 | Valid G-mean: 0.5208 (Sens: 0.4026, Spec: 0.6737) | Best G: 0.6610
# Episode 400 | Train Reward: 62.14564 | Valid G-mean: 0.5172 (Sens: 0.4026, Spec: 0.6643) | Best G: 0.6610
# Episode 410 | Train Reward: 69.14923 | Valid G-mean: 0.5456 (Sens: 0.4935, Spec: 0.6033) | Best G: 0.6610
# Episode 420 | Train Reward: 64.53641 | Valid G-mean: 0.5560 (Sens: 0.5065, Spec: 0.6103) | Best G: 0.6610
# Episode 430 | Train Reward: 64.34256 | Valid G-mean: 0.5397 (Sens: 0.4416, Spec: 0.6596) | Best G: 0.6610
# Episode 440 | Train Reward: 73.19077 | Valid G-mean: 0.5310 (Sens: 0.4156, Spec: 0.6784) | Best G: 0.6610
# Episode 450 | Train Reward: 75.85590 | Valid G-mean: 0.5273 (Sens: 0.4156, Spec: 0.6690) | Best G: 0.6610
# Episode 460 | Train Reward: 77.15949 | Valid G-mean: 0.5406 (Sens: 0.4416, Spec: 0.6620) | Best G: 0.6610
# Episode 470 | Train Reward: 74.97385 | Valid G-mean: 0.5307 (Sens: 0.4286, Spec: 0.6573) | Best G: 0.6610
# Episode 480 | Train Reward: 73.82051 | Valid G-mean: 0.5357 (Sens: 0.4545, Spec: 0.6315) | Best G: 0.6610
# Episode 490 | Train Reward: 67.20769 | Valid G-mean: 0.5447 (Sens: 0.4805, Spec: 0.6174) | Best G: 0.6610
# Episode 500 | Train Reward: 68.71590 | Valid G-mean: 0.5280 (Sens: 0.4416, Spec: 0.6315) | Best G: 0.6610
# Episode 510 | Train Reward: 67.15846 | Valid G-mean: 0.5342 (Sens: 0.4675, Spec: 0.6103) | Best G: 0.6610
# Episode 520 | Train Reward: 79.22256 | Valid G-mean: 0.5279 (Sens: 0.4286, Spec: 0.6502) | Best G: 0.6610
# Episode 530 | Train Reward: 74.66256 | Valid G-mean: 0.5261 (Sens: 0.4416, Spec: 0.6268) | Best G: 0.6610
# Episode 540 | Train Reward: 69.05692 | Valid G-mean: 0.4941 (Sens: 0.3636, Spec: 0.6714) | Best G: 0.6610
# Episode 550 | Train Reward: 85.78000 | Valid G-mean: 0.5367 (Sens: 0.4545, Spec: 0.6338) | Best G: 0.6610
# Episode 560 | Train Reward: 83.36000 | Valid G-mean: 0.4811 (Sens: 0.3377, Spec: 0.6854) | Best G: 0.6610
# Episode 570 | Train Reward: 85.60718 | Valid G-mean: 0.4798 (Sens: 0.3247, Spec: 0.7089) | Best G: 0.6610
# Episode 580 | Train Reward: 78.17487 | Valid G-mean: 0.4835 (Sens: 0.3506, Spec: 0.6667) | Best G: 0.6610
# Episode 590 | Train Reward: 85.96513 | Valid G-mean: 0.5517 (Sens: 0.5065, Spec: 0.6009) | Best G: 0.6610
# Episode 600 | Train Reward: 87.40718 | Valid G-mean: 0.5006 (Sens: 0.3896, Spec: 0.6432) | Best G: 0.6610
# Episode 610 | Train Reward: 84.43538 | Valid G-mean: 0.4975 (Sens: 0.3636, Spec: 0.6808) | Best G: 0.6610
# Episode 620 | Train Reward: 93.04359 | Valid G-mean: 0.5015 (Sens: 0.3896, Spec: 0.6455) | Best G: 0.6610
# Episode 630 | Train Reward: 82.04564 | Valid G-mean: 0.5060 (Sens: 0.3896, Spec: 0.6573) | Best G: 0.6610
# Episode 640 | Train Reward: 75.56718 | Valid G-mean: 0.5383 (Sens: 0.4675, Spec: 0.6197) | Best G: 0.6610
# Episode 650 | Train Reward: 88.19641 | Valid G-mean: 0.5159 (Sens: 0.3896, Spec: 0.6831) | Best G: 0.6610
# Episode 660 | Train Reward: 81.93692 | Valid G-mean: 0.5060 (Sens: 0.3896, Spec: 0.6573) | Best G: 0.6610
# Episode 670 | Train Reward: 80.47949 | Valid G-mean: 0.5078 (Sens: 0.3896, Spec: 0.6620) | Best G: 0.6610
# Episode 680 | Train Reward: 88.84308 | Valid G-mean: 0.5114 (Sens: 0.3896, Spec: 0.6714) | Best G: 0.6610
# Episode 690 | Train Reward: 86.38667 | Valid G-mean: 0.5079 (Sens: 0.4026, Spec: 0.6408) | Best G: 0.6610
# Episode 700 | Train Reward: 89.78718 | Valid G-mean: 0.5098 (Sens: 0.4026, Spec: 0.6455) | Best G: 0.6610
# Episode 710 | Train Reward: 87.25795 | Valid G-mean: 0.5185 (Sens: 0.3896, Spec: 0.6901) | Best G: 0.6610
# Episode 720 | Train Reward: 83.00615 | Valid G-mean: 0.5159 (Sens: 0.3896, Spec: 0.6831) | Best G: 0.6610
# Episode 730 | Train Reward: 84.76615 | Valid G-mean: 0.5123 (Sens: 0.4156, Spec: 0.6315) | Best G: 0.6610
# Episode 740 | Train Reward: 77.91385 | Valid G-mean: 0.5181 (Sens: 0.4026, Spec: 0.6667) | Best G: 0.6610
# Episode 750 | Train Reward: 96.56769 | Valid G-mean: 0.5176 (Sens: 0.3766, Spec: 0.7113) | Best G: 0.6610
# Episode 760 | Train Reward: 89.98256 | Valid G-mean: 0.5105 (Sens: 0.3896, Spec: 0.6690) | Best G: 0.6610
# Episode 770 | Train Reward: 91.18718 | Valid G-mean: 0.5159 (Sens: 0.3766, Spec: 0.7066) | Best G: 0.6610
# Episode 780 | Train Reward: 89.75128 | Valid G-mean: 0.5289 (Sens: 0.4026, Spec: 0.6948) | Best G: 0.6610
# Episode 790 | Train Reward: 93.71897 | Valid G-mean: 0.5185 (Sens: 0.3896, Spec: 0.6901) | Best G: 0.6610
# Episode 800 | Train Reward: 85.13026 | Valid G-mean: 0.5063 (Sens: 0.3766, Spec: 0.6808) | Best G: 0.6610
# 최종 학습 완료
# Best checkpoint restored: epoch=10, valid_gmean=0.6610
#
# ============================================================
# TEST SET - DDQN 분류 모델 최종 성능 평가
# ============================================================
#
# G-mean: 0.6555
#
# Confusion Matrix:
# [[550 174]
#  [ 43  56]]
#
# TN: 550, FP: 174
# FN: 43, TP: 56
#
# 분류 리포트:
#                     precision    recall  f1-score   support
#
# Class 0 (Negative)       0.93      0.76      0.84       724
# Class 1 (Positive)       0.24      0.57      0.34        99
#
#           accuracy                           0.74       823
#          macro avg       0.59      0.66      0.59       823
#       weighted avg       0.85      0.74      0.78       823
# 상세 메트릭 (Test Set):
# Sensitivity (Recall for Class 1): 0.5657
# Specificity (Recall for Class 0): 0.7597
# Precision (Class 1): 0.2435
# F1-Score: 0.3404
# ============================================================
#
# ============================================================
# VALIDATION SET vs TEST SET 성능 비교
# ============================================================
#
# Validation(Selection) Set - G-mean: 0.6610
# Test Set - G-mean: 0.6555
# Difference (Valid - Test): 0.0055
#
# Validation Confusion Matrix:
# [[281 145]
#  [ 26  51]]
#
# Test Confusion Matrix:
# [[550 174]
#  [ 43  56]]
# ============================================================

# %%
# Test 구간 날짜 인덱스
test_dates = dat.index[test_indices]

# (이미 계산된) test_predictions를 사용해 Test 구간 결과만 저장
test_predicted_actions_df = pd.DataFrame({
    "Date": test_dates,
    "Predicted_Action": test_predictions
})

#test_predicted_actions_df에서 첫번째행을 빼기
test_predicted_actions_df = test_predicted_actions_df.iloc[1:].reset_index(drop=True)

# CSV 저장
output_test_csv_path = "../../results/DDQN_predicted_G2.csv"
test_predicted_actions_df.to_csv(output_test_csv_path, index=False)

print(f"Test 구간 예측 결과가 '{output_test_csv_path}' 파일로 저장되었습니다.")
display(test_predicted_actions_df.head())
# Out:
# Test 구간 예측 결과가 '../../results/DDQN_predicted_G2.csv' 파일로 저장되었습니다.
#          Date  Predicted_Action
# 0  2022-10-17                 0
# 1  2022-10-18                 1
# 2  2022-10-19                 1
# 3  2022-10-20                 1
# 4  2022-10-21                 0
